# %%
from IPython.display import display, HTML
from datetime import datetime, timedelta
from lxml import html, etree, objectify
import pandas as pd
import requests
import threading
import queue
import pytz
import math
import csv
import os

# %%
def get_symbols():
    with open("n16_symbols.csv", "r") as f:
        symbols = f.read().split()
    return list(set(symbols))
symbols = get_symbols()
len(symbols)
# Out:
# 3198

# %% [markdown]
# <h3>1. We need to get data from Nasdaq</h3>

# %%
def get_text_val(t):
    """
    Helper function
    converts scrapped values into the right numeric representation
    None -> 0
    1,000 -> 1000
    """
    string_value = ("0" if t is None else t).replace(",", "")
    return float(string_value) if string_value.isnumeric() else string_value


get_text_val("1,400")
# Out:
# 1400.0

# %% [markdown]
# <h3>Let's show where the scrapped values will come from</h3>
#
# <h4>Price</h4>
# <img width="600px" align="left" src="price.png">

# %% [markdown]
# <h4>Institutional Ownership</h4>
# <img width="600px" align="left" src="institutional_ownership.png">

# %% [markdown]
# <h4>Active positions</h4>
# <img width="600px" align="left" src="active_positions.png">

# %% [markdown]
# <h4>New and sold out positions</h4>
# <img width="600px" align="left" src="new_and_sold_out_positions.png">

# %%
def get_nasdaq_data(symbol):
    """
    Pull some data for a symbol from its nasdaq detail page
    Returns: dict like {total_shares: 1, institutional_ownership: 2, ..}
    """
    url = "http://www.nasdaq.com/symbol/{}/institutional-holdings".format(symbol.lower())
    page = requests.get(url)
    tree = html.fromstring(page.content)    
    
    data = {}
    # Price 
    div = tree.find('.//div[@id="qwidget_lastsale"]')
    if div is not None:
        data["price"] = div.text
    
    # Institutional Ownership
    table = tree.find('.//div[@class="infoTable marginT15px marginL15px"]')
    if table is not None:
        for row in table.findall('.//tr'):
            th_cell, td_cell = row
            title, value = th_cell.text, get_text_val(td_cell.text)
            if title == "Total Shares Outstanding (millions)":
                data["total_shares"] = value
            elif title == "Institutional Ownership":
                data["institutional_ownership"] = value
    
    # Active positions
    table = tree.find('.//div[@class="infoTable paddingT5px"]')
    if table is not None:
        for row in table.findall('.//tr'):
            first, second, third = row
            label, holders, shares = first.text, get_text_val(second.text), get_text_val(third.text)
            if label == "Increased Positions":
                data["increased_holders"] = holders
                data["increased_shares"] = shares
            elif label == "Decreased Positions":
                data["decreased_holders"] = holders
                data["decreased_shares"] = shares
            elif label == "Held Positions":
                data["held_holders"] = holders
                data["held_shares"] = shares
    
    # New and sold out positions    
    table = tree.find('.//div[@class="infoTable floatL marginT15px"]')
    if table is not None:
        for row in table.findall('.//tr'):
            first, second, third = row
            label, holders, shares = first.text, get_text_val(second.text), get_text_val(third.text)
            if label == "New Positions":
                data["new_holders"] = holders
                data["new_shares"] = shares
            elif label == "Sold Out Positions":
                data["sold_holders"] = holders
                data["sold_shares"] = shares
            
    return data

get_nasdaq_data("TSLA")
# Out:
# {'decreased_holders': 322.0,
#  'decreased_shares': 8505097.0,
#  'held_holders': 153.0,
#  'held_shares': 80150177.0,
#  'increased_holders': 375.0,
#  'increased_shares': 10999115.0,
#  'institutional_ownership': '58.69%',
#  'new_holders': 109.0,
#  'new_shares': 800485.0,
#  'price': '$304.34',
#  'sold_holders': 92.0,
#  'sold_shares': 2277425.0,
#  'total_shares': 170.0}

# %% [markdown]
# <h3>For the last table we will need some data from yahoo.com</h3>

# %%
DATA_TIMEZONE = pytz.timezone("US/Eastern")

def get_the_quarter_days():
    now = datetime.now()
    this_quarter_num = math.ceil(now.month / 3)
    
    if this_quarter_num == 1:
        quarter_num = 4 
        year = now.year - 1
    else:
        quarter_num = this_quarter_num - 1
        year = now.year
        
    start_day = datetime(year, 3 * quarter_num - 2, 1, 9, 30, 0, tzinfo=DATA_TIMEZONE)
    end_day = datetime(year, 3 * this_quarter_num - 2, 1, 13, 30, 0, tzinfo=DATA_TIMEZONE) - timedelta(days=1)
    
    return start_day, end_day
    
get_the_quarter_days()
# Out:
# (datetime.datetime(2018, 1, 1, 9, 30, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>),
#  datetime.datetime(2018, 3, 31, 13, 30, tzinfo=<DstTzInfo 'US/Eastern' LMT-1 day, 19:04:00 STD>))

# %%
def get_data_yahoo(symbol, start, end):
    url = "https://query1.finance.yahoo.com/v7/finance/chart/{}?period1={:.0f}&period2={:.0f}"\
          "&interval=1d&indicators=quote&includeTimestamps=true&"\
          "events=div%7Csplit%7Cearn".format(symbol, start.timestamp(), end.timestamp())
    page = requests.get(url)
    result = page.json()['chart']['result']
    if not result:
        print(symbol, page.json())
        return
    
    data = result[0]
    quote = data['indicators']['quote'][0]
    if 'timestamp' not in data:
        print("Unexpected response for {}".format(symbol))
        return
    
    result = pd.DataFrame(
        index=pd.Index(data=[datetime.fromtimestamp(t).date() for t in data['timestamp']], name="Date"),
        data=dict(
            Open=quote["open"],
            High=quote["high"],
            Low=quote["low"],
            Close=quote["close"],
            Volume=quote["volume"],
        )
    ) 
    return result

start, end = get_the_quarter_days()
yh_df = get_data_yahoo('BAC', start, end)
yh_df
# Out:
#                 Close       High        Low       Open     Volume
# Date
# 2018-01-02  29.900000  29.900000  29.610001  29.750000   57121600
# 2018-01-03  29.799999  29.940001  29.690001  29.900000   57865700
# 2018-01-04  30.190001  30.440001  29.879999  29.969999   76512500
# 2018-01-05  30.330000  30.420000  30.049999  30.370001   56445200
# 2018-01-08  30.120001  30.270000  30.049999  30.230000   42914800
# 2018-01-09  30.270000  30.540001  30.129999  30.200001   69479100
# 2018-01-10  30.549999  30.730000  30.309999  30.370001   63532800
# 2018-01-11  30.660000  30.690001  30.450001  30.660000   59318300
# 2018-01-12  31.190001  31.200001  30.770000  30.879999   66371600
# 2018-01-16  31.240000  31.790001  31.030001  31.740000  104467900
# 2018-01-17  31.180000  31.290001  30.340000  31.000000  124382900
# 2018-01-18  31.480000  31.709999  31.209999  31.330000   76463800
# 2018-01-19  31.719999  31.740000  31.459999  31.580000   66491000
# 2018-01-22  31.940001  31.940001  31.580000  31.670000   53848800
# 2018-01-23  31.920000  32.130001  31.790001  31.860001   56531400
# 2018-01-24  32.090000  32.209999  31.820000  32.009998   81585000
# 2018-01-25  32.090000  32.250000  31.930000  32.240002   62265800
def get_all_data(symbol):
    symbol_data = get_nasdaq_data(symbol)
    if symbol_data:
        symbol_data["symbol"] = symbol
        yahoo_df = get_data_yahoo(symbol, quarter_start, quearter_end)
        if yahoo_df is not None:
            symbol_data["avg_price_for_quarter"] = yahoo_df.Close.mean()
            symbol_data["total_volume_for_quarter"] = yahoo_df.Volume.sum()
        return symbol_data

# %%
start = datetime.now()
# now we can pull all the data from nasdaq into the data list
data = []
quarter_start, quearter_end = get_the_quarter_days()
for symbol in symbols[:10]:
    symbol_data = get_all_data(symbol)
    if symbol_data:
        data.append(symbol_data)
df = pd.DataFrame.from_records(data)
print(datetime.now() - start, ", so pulling data in a simple cycle takes too long")
df[:10]
# Out:
# 0:00:20.006456 , so pulling data in a simple cycle takes too long
#    avg_price_for_quarter  decreased_holders  decreased_shares  held_holders  \
# 0               2.385410               26.0         2108211.0          16.0
# 1             253.711967              338.0         7909378.0         106.0
# 2               1.332934                5.0          163494.0           0.0
# 3              10.384098               38.0          616770.0          29.0
# 4              41.438360                3.0           22726.0           2.0
# 5              25.381639                0.0               0.0           1.0
# 6              33.324754               20.0          213691.0          12.0
# 7              40.885410               27.0          882470.0           5.0
# 8              86.623771               80.0         1199833.0          30.0
# 9              70.133442               12.0           61055.0           6.0
#
#    held_shares  increased_holders  increased_shares institutional_ownership  \
# 0   3.2816e+07               22.0         5332613.0                  82.56%
# 1  6.11359e+07              289.0         4740124.0                  90.08%
# 2      (95211)                2.0           18277.0                  00.86%
# 3   1.9451e+07               58.0         2097822.0                  81.64%
# 4       410120                5.0           15306.0                  04.54%
# 5         8611                1.0              27.0                  00.24%
# 6  3.44936e+06               34.0          151383.0                  48.69%
# 7   6.8968e+06               39.0         1451252.0                  21.47%
# 8  9.54759e+06               94.0         1586649.0                  98.66%
# 9       374518               14.0           53962.0                  33.76%
#
#    new_holders  new_shares    price  sold_holders  sold_shares symbol  \
# 0          9.0   1417226.0     $1.5          10.0      82250.0   DXLG
# 1         84.0    733226.0  $268.47          56.0    1126100.0   ORLY
# 2          2.0     18277.0    $1.13           2.0     153032.0   DELT
# 3         14.0   1104735.0   $12.27           3.0       3524.0   DGII
# 4          3.0     15014.0   $34.27           1.0         21.0   CYAD
# 5          0.0         0.0   $25.36           0.0          0.0  OXLCO
# 6          8.0     37140.0   $30.78           4.0      27546.0   BWFG
# 7         12.0    250993.0    $41.5           6.0      62106.0   OMAB
# 8         30.0    259086.0   $83.75          22.0     273837.0   ALOG
# 9          5.0      6313.0      $70           0.0          0.0    PYZ
#
#    total_shares  total_volume_for_quarter
# 0          49.0                   6248900
# 1          82.0                  56493800
# 2          10.0                  61542900
# 3          27.0                   6683300
# 4          10.0                    242100
# 5           4.0                    142500
# 6           8.0                    676100
# 7          43.0                   5481300
# 8          13.0                   9269000
# 9           1.0                    331200

# %%
def save_data_in_parallel(symbols):
    
    num_worker_threads = 20
    input_queue = queue.Queue()
    responses_queue = queue.Queue()
    
    def worker():
        while True:
            symbol = input_queue.get()
            if symbol is None:
                break
                
            data = get_all_data(symbol)
            if data:
                responses_queue.put(data)
                
            input_queue.task_done()

    threads = []
    for i in range(num_worker_threads):
        t = threading.Thread(target=worker)
        t.start()
        threads.append(t)

    for symbol in symbols:
        input_queue.put(symbol)

    # block until all tasks are done
    input_queue.join()

    # stop workers
    for i in range(num_worker_threads):
        input_queue.put(None)
    
    # join threads
    for t in threads:
        t.join()
    
    data = []
    while True:
        try:
            result = responses_queue.get_nowait()
        except queue.Empty:
            break
        else:
            data.append(result)
    return pd.DataFrame.from_records(data)
        
df = save_data_in_parallel(symbols)
df[:10]
# Out:
# Unexpected response for FVE
# MRDNW {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for MPACW
# Unexpected response for KAACW
# Unexpected response for NHLDW
# Unexpected response for EACQU
# MEET {'chart': {'result': None, 'error': {'description': "Data doesn't exist for startDate = 1514816760, endDate = 1522520760", 'code': 'Bad Request'}}}
# Unexpected response for INSY
# Unexpected response for STLRU
# Unexpected response for VEACW
# Unexpected response for NXTDW
# IVFGC {'chart': {'result': None, 'error': {'description': "Data doesn't exist for startDate = 1514816760, endDate = 1522520760", 'code': 'Bad Request'}}}
# Unexpected response for GAINM
# ITEK {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for GLPI
# Unexpected response for WYIG
# DSGX {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# TRUP {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for SBNYW
# LTEA {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for ZSAN
# Unexpected response for QQQ
# AEZS {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for BHACU
# Unexpected response for CERCW
# Unexpected response for ANGO
# AMRB {'chart': {'result': None, 'error': {'description': "Data doesn't exist for startDate = 1514816760, endDate = 1522520760", 'code': 'Bad Request'}}}
# Unexpected response for BPFHW
# CTG {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for ORMP
# Unexpected response for KIRKUnexpected response for TANNZ
#
# Unexpected response for TWNKW
# Unexpected response for SFST
# Unexpected response for NEOT
# WTBA {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for ELECU
# Unexpected response for JASNW
# Unexpected response for ONCE
# Unexpected response for LMNR
# Unexpected response for IBTX
# SKLN {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# ONTX {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# IVTY {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for HUNTU
# Unexpected response for LCAHW
# Unexpected response for NXEOW
# PCLN {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# MIIIW {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for FNTEW
# Unexpected response for CYRXW
# Unexpected response for LMFAW
# Unexpected response for FFBCW
# Unexpected response for WHLRW
# Unexpected response for VEACU
# Unexpected response for ROSEW
# Unexpected response for MMDMW
# Unexpected response for IMRNW
# ITCI {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for ONSIZ
# MCHX {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for OPGNW
# SNGXW {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for JRVR
# Unexpected response for ZIONZ
# FH {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for EYESW
# Unexpected response for EACQW
# Unexpected response for MPACU
# TSBK {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# ASRVP {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for ZNWAA
# Unexpected response for FITBI
# Unexpected response for MMDMU
# Unexpected response for AHPAW
# Unexpected response for BHACR
# Unexpected response for ESCA
# Unexpected response for EAGLW
# AVIR {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# CLNT {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for CYTXW
# ONCS {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for ROSE
# LEXEB {'chart': {'result': None, 'error': {'description': "Data doesn't exist for startDate = 1514816760, endDate = 1522520760", 'code': 'Bad Request'}}}
# Unexpected response for WAFDW
# DAX {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# FNTEU {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for MOMO
# Unexpected response for MMDMR
# INCR {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for SUMR
# Unexpected response for CLIRW
# Unexpected response for SCACW
# Unexpected response for RXIIW
# Unexpected response for GSHTU
# FMCIW {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for APDNW
# NVGN {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# SRUNW {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for ABEOW
# FRSH {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# VIA {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# MSDI {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# HOTR {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# IVENC {'chart': {'result': None, 'error': {'description': "Data doesn't exist for startDate = 1514816760, endDate = 1522520760", 'code': 'Bad Request'}}}
# Unexpected response for EXFO
# Unexpected response for PAVMW
# RDIB {'chart': {'result': None, 'error': {'description': "Data doesn't exist for startDate = 1514816760, endDate = 1522520760", 'code': 'Bad Request'}}}
# Unexpected response for GECC
# Unexpected response for XGTIW
# Unexpected response for MACQW
# Unexpected response for GSHTW
# Unexpected response for KTOVW
# Unexpected response for GFNSL
# Unexpected response for WTFCW
# Unexpected response for CHEKW
# Unexpected response for AMBCW
# Unexpected response for LINDW
# GALE {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for LOGM
# WPCS {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# ROSEU {'chart': {'result': None, 'error': {'description': "Data doesn't exist for startDate = 1514816760, endDate = 1522520760", 'code': 'Bad Request'}}}
# ZUMZ {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for SGLBW
# Unexpected response for SHLDW
# Unexpected response for CETXW
# Unexpected response for GBLIL
# Unexpected response for CNAT
# PPHMP {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for STLRW
# ASRV {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# MSDIW {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for SNOAW
# Unexpected response for MDVXW
# Unexpected response for VKTXW
# Unexpected response for CLRBZ
# WYIGW {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# CUBN {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for ONSIW
# Unexpected response for SHIPW
# Unexpected response for RNVA
# Unexpected response for TICCL
# Unexpected response for CAC
# Unexpected response for AQMS
# Unexpected response for GTYHW
# INOD {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for CYHHZ
# Unexpected response for CATYW
# Unexpected response for BHACW
# Unexpected response for TLT
# Unexpected response for CLRBW
# Unexpected response for HUNTW
# Unexpected response for ZIONW
# PPHM {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# GPAC {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for DRIOW
# Unexpected response for EYEGW
# Unexpected response for DSKEW
# GPACW {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# CUR {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for KBLMU
# Unexpected response for KELYB
# PBMD {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# ADHD {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# WPPGY {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for BNTCW
# Unexpected response for SGC
# CSX {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for AGFSW
# Unexpected response for AFHBL
# Unexpected response for AHPAU
# FFWM {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for TCBIW
# Unexpected response for CORI
# Unexpected response for BVXVW
# SLNOW {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# SONS {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for ICPT
# CMFN {'chart': {'result': None, 'error': {'description': "Data doesn't exist for startDate = 1514816760, endDate = 1522520760", 'code': 'Bad Request'}}}
# Unexpected response for SYRS
# NUROW {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for JSYNR
# Unexpected response for APOPW
# CFCOW {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# CRZO {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for MTFBW
# AXDX {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# NESRW {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# FMCI {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for AEMD
# Unexpected response for CFFN
# CFCO {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for SNHNL
# SLGN {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for RIBTW
# CLNE {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for EBSB
# INSM {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for ONTXW
# SYMX {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for WING
# Unexpected response for TACOW
# MLNK {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for SAIA
# ABY {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for MMAC
# ESIO {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for DGLT
# Unexpected response for DJCO
# SRTSW {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for DXGE
# Unexpected response for JSYNW
# Unexpected response for KAACU
# ADXSW Unexpected response for ELECW
# {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
# Unexpected response for OXBRW
# Unexpected response for XOMA
# Unexpected response for KOSS
# AMRN {'chart': {'result': None, 'error': {'description': 'No data found, symbol may be delisted', 'code': 'Not Found'}}}
#    avg_price_for_quarter  decreased_holders  decreased_shares  held_holders  \
# 0              25.381639                0.0               0.0           1.0
# 1               1.332934                5.0          163494.0           0.0
# 2              25.572771                0.0               0.0           0.0
# 3              70.133442               12.0           61055.0           6.0
# 4              20.222787                7.0           18000.0           6.0
# 5              41.438360                3.0           22726.0           2.0
# 6               2.385410               26.0         2108211.0          16.0
# 7              33.324754               20.0          213691.0          12.0
# 8                    NaN               23.0          622977.0          25.0
# 9              10.384098               38.0          616770.0          29.0
#
#    held_shares  increased_holders  increased_shares institutional_ownership  \
# 0         8611                1.0              27.0                  00.24%
# 1      (95211)                2.0           18277.0                  00.86%
# 2            0                0.0               0.0                      0%
# 3       374518               14.0           53962.0                  33.76%
# 4       552595               20.0          342219.0                  04.86%
# 5       410120                5.0           15306.0                  04.54%
# 6   3.2816e+07               22.0         5332613.0                  82.56%
# 7  3.44936e+06               34.0          151383.0                  48.69%
# 8  9.47388e+06               15.0          421427.0                  20.81%
# 9   1.9451e+07               58.0         2097822.0                  81.64%
#
#    new_holders  new_shares   price  sold_holders  sold_shares symbol  \
# 0          0.0         0.0  $25.36           0.0          0.0  OXLCO
# 1          2.0     18277.0   $1.12           2.0     153032.0   DELT
# 2          0.0         0.0  $25.31           0.0          0.0  HBHCL
# 3          5.0      6313.0     $70           0.0          0.0    PYZ
# 4          8.0    190884.0   $25.1           4.0       9315.0   COOL
# 5          3.0     15014.0  $34.27           1.0         21.0   CYAD
# 6          9.0   1417226.0    $1.5          10.0      82250.0   DXLG
# 7          8.0     37140.0  $30.78           4.0      27546.0   BWFG
# 8          7.0    203654.0    $1.2           5.0     193923.0    FVE
# 9         14.0   1104735.0  $12.27           3.0       3524.0   DGII
#
#    total_shares  total_volume_for_quarter
# 0           4.0                  142500.0
# 1          10.0                61542900.0
# 2           6.0                  575900.0
# 3           1.0                  331200.0
# 4          19.0                 7940500.0
# 5          10.0                  242100.0
# 6          49.0                 6248900.0
# 7           8.0                  676100.0
# 8          51.0                       NaN
# 9          27.0                 6683300.0

# %%
def draw_table(sub_df, headers, fields):
    """
    Makes an html table
    """
    s = "<table><tr><th>" + "</th><th>".join(headers) + "</th></tr>"
    for r in sub_df.itertuples():
        s += "<tr><td>" + "</td><td>".join(str(getattr(r, f)) for f in fields) + "</td></tr>"
    s += "</table>"
    display(HTML(s))
    
draw_table(df[:10], ("Stock symbol", "It's price"), ("symbol", "price"))
# Out:
# <table><tr><th>Stock symbol</th><th>It's price</th></tr><tr><td>OXLCO</td><td>$25.36</td></tr><tr><td>DELT</td><td>$1.12</td></tr><tr><td>HBHCL</td><td>$25.31</td></tr><tr><td>PYZ</td><td>$70</td></tr><tr><td>COOL</td><td>$25.1</td></tr><tr><td>CYAD</td><td>$34.27</td></tr><tr><td>DXLG</td><td>$1.5</td></tr><tr><td>BWFG</td><td>$30.78</td></tr><tr><td>FVE</td><td>$1.2</td></tr><tr><td>DGII</td><td>$12.27</td></tr></table>

# %%
df["ratio"] = (df.increased_holders - df.decreased_holders) / df.held_holders
df.sort_values("ratio", ascending=False, inplace=True)
display(HTML("<h3>Top 100 stocks by Active Bullish Activity By Number of Funds((Increased – Decreased)/Held)</h3>"))

draw_table(
    df[:100], 
    ("Stock", "Share price", "Inst.Ownership", "Increased", "Decreased", "Held", "Ratio"),
    ("symbol", "price", "institutional_ownership", "increased_holders", "decreased_holders", "held_holders", "ratio")
)
# Out:
# <h3>Top 100 stocks by Active Bullish Activity By Number of Funds((Increased – Decreased)/Held)</h3>
# <table><tr><th>Stock</th><th>Share price</th><th>Inst.Ownership</th><th>Increased</th><th>Decreased</th><th>Held</th><th>Ratio</th></tr><tr><td>YECO</td><td>$3.5</td><td>01.27%</td><td>4.0</td><td>0.0</td><td>0.0</td><td>inf</td></tr><tr><td>PAVMW</td><td>$0.39</td><td>0%</td><td>2.0</td><td>0.0</td><td>0.0</td><td>inf</td></tr><tr><td>HLG</td><td>$77.73</td><td>00.01%</td><td>7.0</td><td>1.0</td><td>0.0</td><td>inf</td></tr><tr><td>FTFT</td><td>$2.1</td><td>00.12%</td><td>5.0</td><td>3.0</td><td>0.0</td><td>inf</td></tr><tr><td>UDBI</td><td>$31.4199</td><td>00.11%</td><td>2.0</td><td>0.0</td><td>0.0</td><td>inf</td></tr><tr><td>NFEC</td><td>$2.179</td><td>00.55%</td><td>4.0</td><td>3.0</td><td>0.0</td><td>inf</td></tr><tr><td
</td><td>1.0</td><td>0.0</td><td>inf</td></tr><tr><td>FFBCW</td><td>$20.58</td><td>0%</td><td>100.0</td><td>0.0</td><td>inf</td></tr><tr><td>MTFBW</td><td>$3.5</td><td>0%</td><td>97200.0</td><td>0.0</td><td>inf</td></tr><tr><td>JXSB</td><td>$33.5002</td><td>26.79%</td><td>127137.0</td><td>0.0</td><td>inf</td></tr><tr><td>UDBI</td><td>$31.4199</td><td>00.11%</td><td>112.0</td><td>0.0</td><td>inf</td></tr><tr><td>DRIOW</td><td>$0.2</td><td>0%</td><td>20000.0</td><td>0.0</td><td>inf</td></tr><tr><td>NXTDW</td><td>$0.349</td><td>0%</td><td>45603.0</td><td>0.0</td><td>inf</td></tr><tr><td>GENY</td><td>$36.0802</td><td>45.45%</td><td>27266.0</td><td>0.0</td><td>inf</td></tr><tr><td>MACQW</td><td>$0.8</td><td>0%</td><td>29700.0</td><td>0.0</td><td>inf</td></tr><tr><td>HUNTU</td><td>$10.15</td><td>03.63%</td><td>493402.0</td><td>0.0</td><td>inf</td></tr><tr><td>RDIB</td><td>$22</td><td>07.24%</td><td>1.0</td><td>0.0</td><td>inf</td></tr><tr><td>IMRN</td><td>$8.75</td><td>01.58%</td><td>400.0</td><td>0.0</td><td>inf</td></tr><tr><td>PTNR</td><td>$4.14</td><td>02.35%</td><td>752680.0</td><td>0.0</td><td>inf</td ...

# %%
df["incoming_flow"] = (df.increased_shares + df.new_shares) * df.avg_price_for_quarter
df["outgoing_flow"] = (df.decreased_shares + df.sold_shares) * df.avg_price_for_quarter
df["net_flow"] = df.incoming_flow - df.outgoing_flow
df["ratio"] = df.net_flow / df.total_volume_for_quarter * df.avg_price_for_quarter

df.sort_values("ratio", ascending=False, inplace=True)
display(HTML("<h3>Top 100 stocks by New Bullish Activity By Shares (New / Sold Out)</h3>"))

draw_table(
    df[:100], 
    ("Stock", "Share price", "Inst.Ownership", "Incoming flow", "Outgoing flow",
     "Avg Price", "Total Volume", "Bullish Ratio"),
    ("symbol", "price", "institutional_ownership", "incoming_flow", "outgoing_flow", 
     "avg_price_for_quarter", "total_volume_for_quarter", "ratio")
)
# Out:
# <h3>Top 100 stocks by New Bullish Activity By Shares (New / Sold Out)</h3>
# <table><tr><th>Stock</th><th>Share price</th><th>Inst.Ownership</th><th>Incoming flow</th><th>Outgoing flow</th><th>Avg Price</th><th>Total Volume</th><th>Bullish Ratio</th></tr><tr><td>USATP</td><td>$26.15</td><td>12.69%</td><td>5289.600173950195</td><td>0.0</td><td>23.200000762939453</td><td>0.0</td><td>inf</td></tr><tr><td>ISRL</td><td>$92.8278</td><td>08.74%</td><td>23050852.322628085</td><td>217006.59177486232</td><td>105.13885260409997</td><td>31500.0</td><td>76213.47113272808</td></tr><tr><td>LOXO</td><td>$133.5</td><td>417.95%</td><td>10884586587.504025</td><td>429907396.8871948</td><td>106.36327887363122</td><td>23662900.0</td><td>46993.1393990562</td></tr><tr><td>GOOGL</td><td>$1106</td><td>80.36%</td><td>16709910994.675415</td><td>11957331366.208704</td><td>1108.8877123222976</td><td>136344900.0</td><td>38652.543306276995</td></tr><tr><td>UHAL</td><td>$343.37</td><td>36.74%</td><td>753033727.0905097</td><td>347610274.07595825</td><td>355.4693458432057</td><td>4524200.0</td><td>31854.38522447642</td></tr><tr><td>HWBK</td><td>$21.65</td><td>