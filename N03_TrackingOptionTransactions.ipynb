# %%
from datetime import datetime as dt, timedelta as td
import requests

# %%
url = "https://query1.finance.yahoo.com/v7/finance/options/BAC"
#?formatted=true&crumb=bCkXlpLUQ.w&lang=en-US&region=US&date=1484265600&corsDomain=finance.yahoo.com

# %%
page = requests.get(url)
response = page.json()
if response['optionChain']['error']:
    print(response['optionChain']['error'])

results = response['optionChain']['result']
results
# Out:
# [{'expirationDates': [1486684800,
#    1487289600,
#    1487894400,
#    1488499200,
#    1489104000,
#    1489708800,
#    1490313600,
#    1492732800,
#    1495152000,
#    1497571200,
#    1503014400,
#    1510876800,
#    1513296000,
#    1516320000,
#    1547769600],
#   'hasMiniOptions': False,
#   'options': [{'calls': [{'ask': 9.55,
#       'bid': 7.75,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170210C00015000',
#       'currency': 'USD',
#       'expiration': 1486684800,
#       'impliedVolatility': 2.605472236328125,
#       'inTheMoney': True,
#       'lastPrice': 8.2,
#       'lastTradeDate': 1484369493,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 15.0,
#       'volume': 1},
#      {'ask': 8.0,
#       'bid': 7.2,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170210C00015500',
#       'currency': 'USD',
#       'expiration': 1486684800,
#       'impliedVolatility': 2.1250046874999997,
#       'inTheMoney': True,
#       'lastPrice': 7.36,
#       'lastTradeDate': 1485879420,
#       'openInterest': 2,
#       'percentChange': 0.0,
#       'strike': 15.5,
#       'volume': 21},
#      {'ask': 4.0,
#       'bid': 3.8,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170210C00019500',
#       'currency': 'USD',
#       'expiration': 1486684800,
#       'impliedVolatility': 0.9414068359375,
#       'inTheMoney': True,
#       'lastPrice': 3.66,
#       'lastTradeDate': 1485578957,
#       'openInterest': 10,
#       'percentChange': 0.0,
#       'strike': 19.5,
#       'volume': 10},
#      {'ask': 3.3,
#       'bid': 3.25,
#       'change': 0.5700002,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170210C00020000',
#       'currency': 'USD',
#       'expiration': 1486684800,
#       'impliedVolatility': 0.51562984375,
#       'inTheMoney': True,
#       'lastPrice': 3.17,
#       'lastTradeDate': 1486136367,
#       'openInterest': 487,
#       'percentChange': 21.923084,
#       'strike': 20.0,
#       'volume': 13},
#      {'ask': 2.79,
#       'bid': 2.77,
#       'change': 0.71000004,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170210C00020500',
#       'currency': 'USD',
#       'expiration': 1486684800,
#       'impliedVolatility': 0.2500075,
#       'inTheMoney': True,
#       'lastPrice': 2.76,
#       'lastTradeDate': 1486143184,
#       'openInterest': 322,
#       'percentChange': 34.634148,
#       'strike': 20.5,
#       'volume': 121},
#      {'ask': 2.3,
#       'bid': 2.27,
#       'change': 0.53999996,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170210C00021000',
#       'currency': 'USD',
#       'expiration': 1486684800,
#       'impliedVolatility': 0.37500625,
#       'inTheMoney': True,
#       'lastPrice': 2.29,
#       'lastTradeDate': 1486155257,
#       'openInterest': 676,
#       'percentChange': 30.85714,
#       'strike': 21.0,
#       'volume': 714},
#      {'ask': 1.8,
#       'bid': 1.77,
#       'change': 0.63,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170210C00021500',
#       'currency': 'USD',
#       'expiration': 1486684800,
#       'impliedVolatility': 0.29688203124999996,
#       'inTheMoney': True,
#       'lastPrice': 1.83,
#       'lastTradeDate': 1486152998,
#       'openInterest': 9321,
#       'percentChange': 52.499996,
#       'strike': 21.5,
#       'volume': 1020},
#      {'ask': 1.31,
#       'bid': 1.29,
#       'change': 0.49999994,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170210C00022000',
#       'currency': 'USD',
#       'expiration': 1486684800,
#       'impliedVolatility': 0.257819921875,
#       'inTheMoney': True,
#       'lastPrice': 1.31,
#       'lastTradeDate': 1486155484,
#       'openInterest': 9386,
#       'percentChange': 61.72839,
#       'strike': 22.0,
#       'volume': 6997},
#      {'ask': 0.85,
#       'bid': 0.83,
#       'change': 0.41000003,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170210C00022500',
#       'currency': 'USD',
#       'expiration': 1486684800,
#       'impliedVolatility': 0.242195078125,
#       'inTheMoney': True,
#       'lastPrice': 0.85,
#       'lastTradeDate': 1486155597,
#       'openInterest': 4774,
#       'percentChange': 93.18182,
#       'strike': 22.5,
#       'volume': 3550},
#      {'ask': 0.47,
#       'bid': 0.44,
#       'change': 0.24999999,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170210C00023000',
#       'currency': 'USD',
#       'expiration': 1486684800,
#       'impliedVolatility': 0.23633576171874998,
#       'inTheMoney': True,
#       'lastPrice': 0.45,
#       'lastTradeDate': 1486155592,
#       'openInterest': 10685,
#       'percentChange': 124.999985,
#       'strike': 23.0,
#       'volume': 15209},
#      {'ask': 0.2,
#       'bid': 0.19,
#       'change': 0.11,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170210C00023500',
#       'currency': 'USD',
#       'expiration': 1486684800,
#       'impliedVolatility': 0.22657023437499998,
#       'inTheMoney': False,
#       'lastPrice': 0.19,
#       'lastTradeDate': 1486155588,
#       'openInterest': 12442,
#       'percentChange': 137.5,
#       'strike': 23.5,
#       'volume': 41701},
#      {'ask': 0.07,
#       'bid': 0.06,
#       'change': 0.05,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170210C00024000',
#       'currency': 'USD',
#       'expiration': 1486684800,
#       'impliedVolatility': 0.2304764453125,
#       'inTheMoney': False,
#       'lastPrice': 0.07,
#       'lastTradeDate': 1486155580,
#       'openInterest': 43500,
#       'percentChange': 250.0,
#       'strike': 24.0,
#       'volume': 25258},
#      {'ask': 0.03,
#       'bid': 0.02,
#       'change': 0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170210C00024500',
#       'currency': 'USD',
#       'expiration': 1486684800,
#       'impliedVolatility': 0.257819921875,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1486154914,
#       'openInterest': 11177,
#       'percentChange': 100.0,
#       'strike': 24.5,
#       'volume': 15253},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170210C00025000',
#       'currency': 'USD',
#       'expiration': 1486684800,
#       'impliedVolatility': 0.304694453125,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1486148337,
#       'openInterest': 14547,
#       'percentChange': 0.0,
#       'strike': 25.0,
#       'volume': 30},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': -0.12,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170210C00025500',
#       'currency': 'USD',
#       'expiration': 1486684800,
#       'impliedVolatility': 0.37500625,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1486146943,
#       'openInterest': 4,
#       'percentChange': -92.30769,
#       'strike': 25.5,
#       'volume': 18},
#      {'ask': 0.06,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170210C00026000',
#       'currency': 'USD',
#       'expiration': 1486684800,
#       'impliedVolatility': 0.5468795312500001,
#       'inTheMoney': False,
#       'lastPrice': 0.03,
#       'lastTradeDate': 1484673805,
#       'openInterest': 14,
#       'percentChange': 0.0,
#       'strike': 26.0,
#       'volume': 5}],
#     'expirationDate': 1486684800,
#     'hasMiniOptions': False,
#     'puts': [{'ask': 0.04,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170210P00015000',
#       'currency': 'USD',
#       'expiration': 1486684800,
#       'impliedVolatility': 1.46875265625,
#       'inTheMoney': False,
#       'lastPrice': 0.03,
#       'lastTradeDate': 1485578078,
#       'openInterest': 14,
#       'percentChange': 0.0,
#       'strike': 15.0,
#       'volume': 14},
#      {'ask': 0.03,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170210P00018000',
#       'currency': 'USD',
#       'expiration': 1486684800,
#       'impliedVolatility': 0.87500125,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1485354653,
#       'openInterest': 34,
#       'percentChange': 0.0,
#       'strike': 18.0,
#       'volume': 10},
#      {'ask': 0.04,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170210P00019000',
#       'currency': 'USD',
#       'expiration': 1486684800,
#       'impliedVolatility': 0.7500025,
#       'inTheMoney': False,
#       'lastPrice': 0.04,
#       'lastTradeDate': 1485797809,
#       'openInterest': 73,
#       'percentChange': 0.0,
#       'strike': 19.0,
#       'volume': 10},
#      {'ask': 0.09,
#       'bid': 0.01,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170210P00019500',
#       'currency': 'USD',
#       'expiration': 1486684800,
#       'impliedVolatility': 0.789064609375,
#       'inTheMoney': False,
#       'lastPrice': 0.08,
#       'lastTradeDate': 1484369515,
#       'openInterest': 10,
#       'percentChange': 0.0,
#       'strike': 19.5,
#       'volume': 10},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170210P00020000',
#       'currency': 'USD',
#       'expiration': 1486684800,
#       'impliedVolatility': 0.51562984375,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1486068944,
#       'openInterest': 3396,
#       'percentChange': 0.0,
#       'strike': 20.0,
#       'volume': 32},
#      {'ask': 0.06,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170210P00020500',
#       'currency': 'USD',
#       'expiration': 1486684800,
#       'impliedVolatility': 0.5390671093750001,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1486049895,
#       'openInterest': 1233,
#       'percentChange': 0.0,
#       'strike': 20.5,
#       'volume': 270},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170210P00021000',
#       'currency': 'USD',
#       'expiration': 1486684800,
#       'impliedVolatility': 0.37500625,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1486153459,
#       'openInterest': 6320,
#       'percentChange': -50.0,
#       'strike': 21.0,
#       'volume': 12},
#      {'ask': 0.02,
#       'bid': 0.01,
#       'change': -0.03,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170210P00021500',
#       'currency': 'USD',
#       'expiration': 1486684800,
#       'impliedVolatility': 0.3437565625,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1486152522,
#       'openInterest': 10037,
#       'percentChange': -75.0,
#       'strike': 21.5,
#       'volume': 78},
#      {'ask': 0.03,
#       'bid': 0.01,
#       'change': -0.08,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170210P00022000',
#       'currency': 'USD',
#       'expiration': 1486684800,
#       'impliedVolatility': 0.28516339843749994,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1486155133,
#       'openInterest': 5356,
#       'percentChange': -79.99999,
#       'strike': 22.0,
#       'volume': 1296},
#      {'ask': 0.07,
#       'bid': 0.06,
#       'change': -0.16999999,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170210P00022500',
#       'currency': 'USD',
#       'expiration': 1486684800,
#       'impliedVolatility': 0.25391371093750004,
#       'inTheMoney': False,
#       'lastPrice': 0.07,
#       'lastTradeDate': 1486155588,
#       'openInterest': 7547,
#       'percentChange': -70.83333,
#       'strike': 22.5,
#       'volume': 4384},
#      {'ask': 0.18,
#       'bid': 0.17,
#       'change': -0.31,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170210P00023000',
#       'currency': 'USD',
#       'expiration': 1486684800,
#       'impliedVolatility': 0.23633576171874998,
#       'inTheMoney': False,
#       'lastPrice': 0.19,
#       'lastTradeDate': 1486155582,
#       'openInterest': 4205,
#       'percentChange': -62.0,
#       'strike': 23.0,
#       'volume': 14447},
#      {'ask': 0.42,
#       'bid': 0.41,
#       'change': -0.43000004,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170210P00023500',
#       'currency': 'USD',
#       'expiration': 1486684800,
#       'impliedVolatility': 0.23438265625,
#       'inTheMoney': True,
#       'lastPrice': 0.42,
#       'lastTradeDate': 1486155555,
#       'openInterest': 2494,
#       'percentChange': -50.588238,
#       'strike': 23.5,
#       'volume': 2548},
#      {'ask': 0.8,
#       'bid': 0.78,
#       'change': -0.5400001,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170210P00024000',
#       'currency': 'USD',
#       'expiration': 1486684800,
#       'impliedVolatility': 0.25391371093750004,
#       'inTheMoney': True,
#       'lastPrice': 0.78,
#       'lastTradeDate': 1486155481,
#       'openInterest': 1231,
#       'percentChange': -40.909096,
#       'strike': 24.0,
#       'volume': 402},
#      {'ask': 1.26,
#       'bid': 1.23,
#       'change': -0.65999997,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170210P00024500',
#       'currency': 'USD',
#       'expiration': 1486684800,
#       'impliedVolatility': 0.2929758203124999,
#       'inTheMoney': True,
#       'lastPrice': 1.23,
#       'lastTradeDate': 1486153631,
#       'openInterest': 284,
#       'percentChange': -34.92063,
#       'strike': 24.5,
#       'volume': 674},
#      {'ask': 1.74,
#       'bid': 1.72,
#       'change': -0.6700001,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170210P00025000',
#       'currency': 'USD',
#       'expiration': 1486684800,
#       'impliedVolatility': 0.3320379296875,
#       'inTheMoney': True,
#       'lastPrice': 1.71,
#       'lastTradeDate': 1486155339,
#       'openInterest': 106,
#       'percentChange': -28.151262,
#       'strike': 25.0,
#       'volume': 172},
#      {'ask': 2.24,
#       'bid': 2.21,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170210P00025500',
#       'currency': 'USD',
#       'expiration': 1486684800,
#       'impliedVolatility': 0.4062559375,
#       'inTheMoney': True,
#       'lastPrice': 2.25,
#       'lastTradeDate': 1486183475,
#       'openInterest': 203,
#       'percentChange': 0.0,
#       'strike': 25.5,
#       'volume': 22},
#      {'ask': 2.74,
#       'bid': 2.71,
#       'change': -0.6500001,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170210P00026000',
#       'currency': 'USD',
#       'expiration': 1486684800,
#       'impliedVolatility': 0.4687553125,
#       'inTheMoney': True,
#       'lastPrice': 2.73,
#       'lastTradeDate': 1486146980,
#       'openInterest': 3,
#       'percentChange': -19.23077,
#       'strike': 26.0,
#       'volume': 33}]}],
#   'quote': {'ask': 23.29,
#    'askSize': 9,
#    'averageDailyVolume10Day': 91139625,
#    'averageDailyVolume3Month': 121157835,
#    'bid': 23.28,
#    'bidSize': 107,
#    'bookValue': 24.187,
#    'currency': 'USD',
#    'dividendDate': 1490918400,
#    'earningsTimestamp': 1484332200,
#    'earningsTimestampEnd': 1492446600,
#    'earningsTimestampStart': 1492014600,
#    'epsForward': 1.62,
#    'epsTrailingTwelveMonths': 1.367,
#    'exchange': 'NYQ',
#    'exchangeTimezoneName': 'America/New_York',
#    'exchangeTimezoneShortName': 'EST',
#    'fiftyDayAverage': 22.727575,
#    'fiftyDayAverageChange': 0.5624256,
#    'fiftyDayAverageChangePercent': 0.024746398,
#    'fiftyTwoWeekHigh': 23.55,
#    'fiftyTwoWeekHighChange': -0.25999832,
#    'fiftyTwoWeekHighChangePercent': -0.0110402685,
#    'fiftyTwoWeekLow': 10.99,
#    'fiftyTwoWeekLowChange': 12.300001,
#    'fiftyTwoWeekLowChangePercent': 1.1191994,
#    'forwardPE': 14.376544,
#    'fullExchangeName': 'NYSE',
#    'gmtOffSetMilliseconds': -18000000,
#    'longName': 'Bank of America Corporation',
#    'market': 'us_market',
#    'marketCap': 234125066240,
#    'marketState': 'CLOSED',
#    'messageBoardId': 'finmb_19049',
#    'postMarketChange': 0.0099983215,
#    'postMarketChangePercent': 0.042929675,
#    'postMarketPrice': 23.3,
#    'postMarketTime': 1486170000,
#    'priceToBook': 0.962914,
#    'quoteSourceName': 'NYSE Real Time Price',
#    'quoteType': 'EQUITY',
#    'regularMarketChange': 0.5700016,
#    'regularMarketChangePercent': 2.50881,
#    'regularMarketDayHigh': 23.35,
#    'regularMarketDayLow': 22.95,
#    'regularMarketOpen': 23.15,
#    'regularMarketPreviousClose': 22.72,
#    'regularMarketPrice': 23.29,
#    'regularMarketTime': 1486155648,
#    'regularMarketVolume': 116035108,
#    'sharesOutstanding': 10052600000,
#    'shortName': 'Bank of America Corporation',
#    'sourceInterval': 15,
#    'symbol': 'BAC',
#    'trailingAnnualDividendRate': 0.225,
#    'trailingPE': 17.03731,
#    'twoHundredDayAverage': 18.311295,
#    'twoHundredDayAverageChange': 4.9787064,
#    'twoHundredDayAverageChangePercent': 0.27189264},
#   'strikes': [15.0,
#    15.5,
#    18.0,
#    19.0,
#    19.5,
#    20.0,
#    20.5,
#    21.0,
#    21.5,
#    22.0,
#    22.5,
#    23.0,
#    23.5,
#    24.0,
#    24.5,
#    25.0,
#    25.5,
#    26.0],
#   'underlyingSymbol': 'BAC'}]

# %%
result = results[0]
dates = [dt.fromtimestamp(tm) for tm in result['expirationDates']]
# we can use these dates to get data for a specific expiration date
# an example url: https://query1.finance.yahoo.com/v7/finance/options/BAC?date=1484265600 
# the first date is default
dates
# Out:
# [datetime.datetime(2017, 2, 10, 2, 0),
#  datetime.datetime(2017, 2, 17, 2, 0),
#  datetime.datetime(2017, 2, 24, 2, 0),
#  datetime.datetime(2017, 3, 3, 2, 0),
#  datetime.datetime(2017, 3, 10, 2, 0),
#  datetime.datetime(2017, 3, 17, 2, 0),
#  datetime.datetime(2017, 3, 24, 2, 0),
#  datetime.datetime(2017, 4, 21, 3, 0),
#  datetime.datetime(2017, 5, 19, 3, 0),
#  datetime.datetime(2017, 6, 16, 3, 0),
#  datetime.datetime(2017, 8, 18, 3, 0),
#  datetime.datetime(2017, 11, 17, 2, 0),
#  datetime.datetime(2017, 12, 15, 2, 0),
#  datetime.datetime(2018, 1, 19, 2, 0),
#  datetime.datetime(2019, 1, 18, 2, 0)]

# %%
option = result['options'][0]
calls = option['calls']
calls[:2]
# Out:
# [{'ask': 9.55,
#   'bid': 7.75,
#   'change': 0.0,
#   'contractSize': 'REGULAR',
#   'contractSymbol': 'BAC170210C00015000',
#   'currency': 'USD',
#   'expiration': 1486684800,
#   'impliedVolatility': 2.605472236328125,
#   'inTheMoney': True,
#   'lastPrice': 8.2,
#   'lastTradeDate': 1484369493,
#   'openInterest': 0,
#   'percentChange': 0.0,
#   'strike': 15.0,
#   'volume': 1},
#  {'ask': 8.0,
#   'bid': 7.2,
#   'change': 0.0,
#   'contractSize': 'REGULAR',
#   'contractSymbol': 'BAC170210C00015500',
#   'currency': 'USD',
#   'expiration': 1486684800,
#   'impliedVolatility': 2.1250046874999997,
#   'inTheMoney': True,
#   'lastPrice': 7.36,
#   'lastTradeDate': 1485879420,
#   'openInterest': 2,
#   'percentChange': 0.0,
#   'strike': 15.5,
#   'volume': 21}]

# %%
puts = option['puts']
puts[-2:]
# Out:
# [{'ask': 2.24,
#   'bid': 2.21,
#   'change': 0.0,
#   'contractSize': 'REGULAR',
#   'contractSymbol': 'BAC170210P00025500',
#   'currency': 'USD',
#   'expiration': 1486684800,
#   'impliedVolatility': 0.4062559375,
#   'inTheMoney': True,
#   'lastPrice': 2.25,
#   'lastTradeDate': 1486183475,
#   'openInterest': 203,
#   'percentChange': 0.0,
#   'strike': 25.5,
#   'volume': 22},
#  {'ask': 2.74,
#   'bid': 2.71,
#   'change': -0.6500001,
#   'contractSize': 'REGULAR',
#   'contractSymbol': 'BAC170210P00026000',
#   'currency': 'USD',
#   'expiration': 1486684800,
#   'impliedVolatility': 0.4687553125,
#   'inTheMoney': True,
#   'lastPrice': 2.73,
#   'lastTradeDate': 1486146980,
#   'openInterest': 3,
#   'percentChange': -19.23077,
#   'strike': 26.0,
#   'volume': 33}]

# %% [markdown]
# # Implementation

# %%
# There is a lot of data to load every minute, so we have to do this in parrallel
# 'threading' module fits well for this purpose
# I'm going to use two queues to connect our main programm and thread workers: 
# the first is for tasks, the other - for results
# You can find some examples of using 'queue'-module here
# https://docs.python.org/3/library/queue.html#queue.Queue.join
import queue
import requests
import threading


def load_data(time):
    
    num_worker_threads = 1000
    
    def worker():
        while True:
            args = q.get()
            if args is None:
                break
            get_transactions(q, r, *args)  # <-- see definition of this function below
            q.task_done()

    q = queue.Queue() # queue with arguments for the 'get_transactions' function
    r = queue.Queue() # queue with raw responses

    threads = []
    for i in range(num_worker_threads):
        t = threading.Thread(target=worker)
        t.start()
        threads.append(t)

    for stock in STOCKS:
        q.put((stock, None))

    # block until all tasks are done
    q.join()

    # stop workers
    for i in range(num_worker_threads):
        q.put(None)

    for t in threads:
        t.join()
        
    save_rows(r, time)
    
    
def get_transactions(queue, resp_queue, stock, date=None):     
    base_url = "https://query1.finance.yahoo.com/v7/finance/options/{}".format(stock)
    if date is not None:
        url = "{}?date={}".format(base_url, date)
    else:
        url = base_url
    try:
        page = requests.get(url)
    except Exception as e:
        print(e)
    else:
        try:
            response = page.json()
        except Exception as e:  # network problems or wrong server answers
            print(e)
        else:
            if response['optionChain']['error']: # if any error
                print(response['optionChain']['error'])

            else:
                results = response['optionChain']['result']
                for result in results:
                    price = result['quote']['regularMarketPrice']
                    for option in result['options']:
                        resp_queue.put(
                            (stock, price, option['calls'], option['puts'])
                        )

                    if date is None:
                        for tm in result['expirationDates'][1:]:
                            queue.put((stock, tm))

# %%
# Functions which take response from the response queue and put to the 'largest_transactions' list
def save_rows(q, time):
    while True:
        try:
            stock, price, calls, puts = q.get(block=False)
        except queue.Empty:
            break
        else:
            for call in calls:
                save_row(stock, price, 'Calls', time, call)
            for put in puts:
                save_row(stock, price, 'Puts', time, put)

def save_row(s, price, t, time, raw):
    contact = raw['contractSymbol']    
    previous_volume = transaction_volumes.get(contact)
    volume = raw['volume']
    transaction_volumes[contact] = volume
    
    if previous_volume is not None:        
        volume_diff = volume - previous_volume
        if volume_diff > 0:
            last_price = raw['lastPrice']
            strike = raw['strike']
            ask = raw['ask']
            bid = raw['bid']
            largest_transactions.append(
                dict(
                    stock=s,
                    price=price,
                    type=t,
                    time=time,
                    expiration=dt.fromtimestamp(raw['expiration']),
                    strike=strike,
                    contact=contact,
                    last_price=last_price,
                    bid=bid,
                    ask=ask,
                    volume=volume,
                    open_interest=raw['openInterest'],
                    implied_volatility=raw['impliedVolatility'],
                    volume_diff=volume_diff,
                    cost=volume_diff * 100 * last_price,
                    strike_div_price=(strike / price - 1) * 100,
                    last_price_position="{:.0f}".format((1 - (ask-last_price) / (ask-bid)) * 100) if ask != bid else None
                )
            )

# %%
# This function will display the table
from IPython.display import clear_output, display, HTML

headers = (
    "Stock", "Share $", "Options", "Volume", "Open Interest", "Strike", "S / S", 
    "Expiration", "Last price", "Bid", "Ask", "Position",  "Value", "Time of trade",
)
row = """
<td>{stock}</td><td>{price}</td><td>{type}</td><td>{volume_diff}</td><td>{open_interest}</td>
<td>{strike}</td><td>{strike_div_price:.2f}%</td><td>{expiration:%b %d, %Y}</td>
<td>{last_price}</td><td>{bid}</td><td>{ask}</td><td>{last_price_position}%</td>
<td>${cost:,.0f}</td><td>{time:%I:%M%p}</td>
"""

def display_data():    
    table_rows = (row.format(**row_data) for row_data in largest_transactions)           
    clear_output()
    display(
        HTML(
            '<table><tr><th>{}</th></tr><tr>{}</tr></table>'.format(
                "</th><th>".join(headers),
                "</tr><tr>".join(table_rows)
            )
        )
    )

# %%
from datetime import datetime as dt, timedelta as td
from pytz import timezone
from time import sleep
import heapq

tz = timezone('America/Los_Angeles')  # timezone produces time with PST or PDT tzname depending on the date
STOCKS = ['AAPL', 'BAC', 'NVDA', 'AMZN', 'FB']

last_time = None
count = 1
largest_transactions = []  # here we will store top entries
transaction_volumes = {}  # latest volumes for transactions

while True:    
    now = dt.now(tz=tz)
    start = now.replace(hour=6, minute=30, second=0, microsecond=0)
    stop = start.replace(hour=13, minute=0)
    
    if start <= now <= stop: # proper time for getting data
        
        if last_time: # no more often than once per minute
            diff = 60 - (now - last_time).seconds            
            if diff > 0:
                sleep(diff)  
        
        # the main functionality
        load_data(now)
        # it's efficient way to keep only top 20 entries in the 'largest_transactions' list
        largest_transactions = heapq.nlargest(20, largest_transactions, key=lambda i: i['cost'])
        display_data()
        
        # some statistics
        print("last update", now)
        print("prev update", last_time) 
        print("update time", dt.now(tz=tz) - now)
        print("iterations", count)        
        count += 1        
        last_time = now        
    else:
        largest_transactions = [] # drop transactions
        if now < start:
            diff = start - now
            print("time to start:", diff)
            
        else:
            start_tommorow = start + td(days=1)
            print("start tommorow at", start_tommorow)
            diff = start_tommorow - now
        
        sleep(diff.seconds + diff.microseconds * 0.1 ** 6)
# Out:
# <table><tr><th>Stock</th><th>Share $</th><th>Options</th><th>Volume</th><th>Open Interest</th><th>Strike</th><th>S / S</th><th>Expiration</th><th>Last price</th><th>Bid</th><th>Ask</th><th>Position</th><th>Value</th><th>Time of trade</th></tr><tr>
# <td>AMZN</td><td>810.2</td><td>Puts</td><td>5</td><td>16</td>
# <td>1100.0</td><td>35.77%</td><td>Jan 18, 2019</td>
# <td>321.95</td><td>313.0</td><td>317.05</td><td>221%</td>
# <td>$160,975</td><td>02:46AM</td>
# </tr><tr>
# <td>AMZN</td><td>810.2</td><td>Puts</td><td>2</td><td>842</td>
# <td>1100.0</td><td>35.77%</td><td>Jan 19, 2018</td>
# <td>293.35</td><td>294.75</td><td>296.55</td><td>-78%</td>
# <td>$58,670</td><td>02:46AM</td>
# </tr><tr>
# <td>FB</td><td>130.88</td><td>Puts</td><td>27</td><td>1069</td>
# <td>145.0</td><td>10.79%</td><td>Jan 19, 2018</td>
# <td>19.77</td><td>20.55</td><td>20.75</td><td>-390%</td>
# <td>$53,379</td><td>02:47AM</td>
# </tr><tr>
# <td>AMZN</td><td>810.2</td><td>Calls</td><td>2</td><td>138</td>
# <td>590.0</td><td>-27.18%</td><td>Jan 19, 2018</td>
# <td>246.23</td><td>241.65</td><td>243.3</td><td>278%</td>
# <td>$49,246</td><td>02:46AM</td>
# </tr><tr>
# <td>AAPL</td><td>129.08</td><td>Puts</td><td>41</td><td>320</td>
# <td>135.0</td><td>4.59%</td><td>Jul 21, 2017</td>
# <td>10.8</td><td>10.1</td><td>10.25</td><td>467%</td>
# <td>$44,280</td><td>02:46AM</td>
# </tr><tr>
# <td>AMZN</td><td>810.2</td><td>Calls</td><td>2</td><td>45</td>
# <td>680.0</td><td>-16.07%</td><td>Feb 17, 2017</td>
# <td>132.57</td><td>128.95</td><td>131.5</td><td>142%</td>
# <td>$26,514</td><td>02:47AM</td>
# </tr><tr>
# <td>AMZN</td><td>810.2</td><td>Calls</td><td>1</td><td>5</td>
# <td>630.0</td><td>-22.24%</td><td>Jan 18, 2019</td>
# <td>256.77</td><td>244.5</td><td>248.5</td><td>307%</td>
# <td>$25,677</td><td>02:47AM</td>
# </tr><tr>
# <td>AMZN</td><td>810.2</td><td>Puts</td><td>1</td><td>23</td>
# <td>830.0</td><td>2.44%</td><td>Jan 18, 2019</td>
# <td>131.38</td><td>128.7</td><td>130.65</td><td>137%</td>
# <td>$13,138</td><td>02:47AM</td>
# </tr><tr>
# <td>AMZN</td><td>810.2</td><td>Puts</td><td>7</td><td>2</td>
# <td>620.0</td><td>-23.48%</td><td>Dec 15, 2017</td>
# <td>18.68</td><td>17.45</td><td>18.25</td><td>154%</td>
# <td>$13,076</td><td>02:46AM</td>
# </tr><tr>
# <td>BAC</td><td>23.29</td><td>Puts</td><td>10</td><td>23</td>
# <td>34.0</td><td>45.99%</td><td>Apr 21, 2017</td>
# <td>11.14</td><td>10.65</td><td>11.0</td><td>140%</td>
# <td>$11,140</td><td>02:46AM</td>
# </tr><tr>
# <td>BAC</td><td>23.29</td><td>Puts</td><td>285</td><td>4222</td>
# <td>18.0</td><td>-22.71%</td><td>Aug 18, 2017</td>
# <td>0.36</td><td>0.29</td><td>0.31</td><td>350%</td>
# <td>$10,260</td><td>02:46AM</td>
# </tr><tr>
# <td>NVDA</td><td>114.38</td><td>Calls</td><td>2</td><td>1422</td>
# <td>65.0</td><td>-43.17%</td><td>Mar 17, 2017</td>
# <td>50.5</td><td>47.65</td><td>50.65</td><td>95%</td>
# <td>$10,100</td><td>02:46AM</td>
# </tr><tr>
# <td>FB</td><td>130.88</td><td>Calls</td><td>3</td><td>19</td>
# <td>105.0</td><td>-19.77%</td><td>Sep 15, 2017</td>
# <td>30.69</td><td>28.8</td><td>29.05</td><td>756%</td>
# <td>$9,207</td><td>02:47AM</td>
# </tr><tr>
# <td>BAC</td><td>23.29</td><td>Puts</td><td>32</td><td>1201</td>
# <td>26.0</td><td>11.64%</td><td>Feb 17, 2017</td>
# <td>2.86</td><td>2.72</td><td>2.74</td><td>700%</td>
# <td>$9,152</td><td>02:46AM</td>
# </tr><tr>
# <td>NVDA</td><td>114.38</td><td>Puts</td><td>29</td><td>83</td>
# <td>98.0</td><td>-14.32%</td><td>Mar 03, 2017</td>
# <td>1.56</td><td>1.26</td><td>1.35</td><td>333%</td>
# <td>$4,524</td><td>02:46AM</td>
# </tr><tr>
# <td>AMZN</td><td>810.2</td><td>Puts</td><td>2</td><td>83</td>
# <td>715.0</td><td>-11.75%</td><td>Jul 21, 2017</td>
# <td>18.06</td><td>17.8</td><td>18.6</td><td>32%</td>
# <td>$3,612</td><td>02:46AM</td>
# </tr><tr>
# <td>AMZN</td><td>810.2</td><td>Calls</td><td>1</td><td>0</td>
# <td>777.5</td><td>-4.04%</td><td>Feb 17, 2017</td>
# <td>35.17</td><td>34.05</td><td>35.3</td><td>90%</td>
# <td>$3,517</td><td>02:46AM</td>
# </tr><tr>
# <td>AMZN</td><td>810.2</td><td>Puts</td><td>77</td><td>1005</td>
# <td>260.0</td><td>-67.91%</td><td>Jan 19, 2018</td>
# <td>0.3</td><td>0.2</td><td>0.25</td><td>200%</td>
# <td>$2,310</td><td>02:46AM</td>
# </tr><tr>
# <td>AMZN</td><td>810.2</td><td>Calls</td><td>1</td><td>4</td>
# <td>802.5</td><td>-0.95%</td><td>Mar 03, 2017</td>
# <td>22.64</td><td>21.1</td><td>21.75</td><td>237%</td>
# <td>$2,264</td><td>02:47AM</td>
# </tr><tr>
# <td>BAC</td><td>23.29</td><td>Calls</td><td>4</td><td>12761</td>
# <td>19.0</td><td>-18.42%</td><td>Apr 21, 2017</td>
# <td>4.2</td><td>4.3</td><td>4.4</td><td>-100%</td>
# <td>$1,680</td><td>02:47AM</td>
# </tr></table>
# last update 2017-02-04 02:47:01.844229-08:00
# prev update 2017-02-04 02:46:08.503845-08:00
# update time 0:00:13.229551
# iterations 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-73c31eda4456> in <module>()
#      22             diff = 60 - (now - last_time).seconds
#      23             if diff > 0:
# ---> 24                 sleep(diff)
#      25
#      26         # the main functionality
#
# KeyboardInterrupt:
