# %%
from datetime import datetime as dt, timedelta as td
import requests

# %%
url = "https://query1.finance.yahoo.com/v7/finance/options/BAC"
#?formatted=true&crumb=bCkXlpLUQ.w&lang=en-US&region=US&date=1484265600&corsDomain=finance.yahoo.com

# %%
page = requests.get(url)
response = page.json()
if response['optionChain']['error']:
    print(response['optionChain']['error'])

results = response['optionChain']['result']
results
# Out:
# [{'expirationDates': [1525996800,
#    1526601600,
#    1527206400,
#    1527811200,
#    1528416000,
#    1529020800,
#    1529625600,
#    1532044800,
#    1534464000,
#    1537488000,
#    1539907200,
#    1542326400,
#    1545350400,
#    1547769600,
#    1561075200,
#    1579219200],
#   'hasMiniOptions': False,
#   'options': [{'calls': [{'ask': 8.15,
#       'bid': 7.6,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511C00022500',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 2.8496122509765627,
#       'inTheMoney': True,
#       'lastPrice': 7.64,
#       'lastTradeDate': 1524158478,
#       'openInterest': 2,
#       'percentChange': 0.0,
#       'strike': 22.5,
#       'volume': 2},
#      {'ask': 6.45,
#       'bid': 6.3,
#       'change': 0.4000001,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511C00023500',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 1.75000125,
#       'inTheMoney': True,
#       'lastPrice': 7.0,
#       'lastTradeDate': 1523677528,
#       'openInterest': 2,
#       'percentChange': 5.7142873,
#       'strike': 23.5,
#       'volume': 2},
#      {'ask': 5.25,
#       'bid': 5.15,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511C00025000',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 1.865235048828125,
#       'inTheMoney': True,
#       'lastPrice': 5.1,
#       'lastTradeDate': 1524596018,
#       'openInterest': 17,
#       'percentChange': 0.0,
#       'strike': 25.0,
#       'volume': 16},
#      {'ask': 3.85,
#       'bid': 3.75,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511C00025500',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 4.85,
#       'lastTradeDate': 1525101414,
#       'openInterest': 147,
#       'percentChange': 0.0,
#       'strike': 25.5,
#       'volume': 147},
#      {'ask': 3.35,
#       'bid': 3.25,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511C00026000',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 3.65,
#       'lastTradeDate': 1525290306,
#       'openInterest': 215,
#       'percentChange': 0.0,
#       'strike': 26.0,
#       'volume': 190},
#      {'ask': 0.0,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511C00026500',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 3.13,
#       'lastTradeDate': 1525720779,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 26.5,
#       'volume': 6},
#      {'ask': 0.0,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511C00027000',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 2.61,
#       'lastTradeDate': 1525719142,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 27.0,
#       'volume': 148},
#      {'ask': 0.0,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511C00027500',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 2.1,
#       'lastTradeDate': 1525721227,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 27.5,
#       'volume': 139},
#      {'ask': 0.0,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511C00028000',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 1.59,
#       'lastTradeDate': 1525720480,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 28.0,
#       'volume': 1862},
#      {'ask': 0.0,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511C00028500',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 1.14,
#       'lastTradeDate': 1525722685,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 28.5,
#       'volume': 437},
#      {'ask': 0.0,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511C00029000',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 0.7,
#       'lastTradeDate': 1525723135,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 29.0,
#       'volume': 2303},
#      {'ask': 0.0,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511C00029500',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 0.33,
#       'lastTradeDate': 1525723177,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 29.5,
#       'volume': 7696},
#      {'ask': 0.0,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511C00030000',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 0.0312596875,
#       'inTheMoney': False,
#       'lastPrice': 0.1,
#       'lastTradeDate': 1525723189,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 30.0,
#       'volume': 39115},
#      {'ask': 0.0,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511C00030500',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 0.062509375,
#       'inTheMoney': False,
#       'lastPrice': 0.03,
#       'lastTradeDate': 1525723189,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 30.5,
#       'volume': 6739},
#      {'ask': 0.0,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511C00031000',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 0.12500875,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1525720277,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 31.0,
#       'volume': 113},
#      {'ask': 0.0,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511C00031500',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 0.12500875,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1525716599,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 31.5,
#       'volume': 25},
#      {'ask': 0.01,
#       'bid': 0.01,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511C00032000',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 0.367193828125,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1525456977,
#       'openInterest': 2239,
#       'percentChange': 0.0,
#       'strike': 32.0,
#       'volume': 20},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511C00032500',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 0.476567734375,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1525279104,
#       'openInterest': 709,
#       'percentChange': 0.0,
#       'strike': 32.5,
#       'volume': 56},
#      {'ask': 0.06,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511C00033000',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 0.585941640625,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1525451242,
#       'openInterest': 1716,
#       'percentChange': -50.0,
#       'strike': 33.0,
#       'volume': 10},
#      {'ask': 0.06,
#       'bid': 0.01,
#       'change': 0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511C00033500',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 0.6640658593750002,
#       'inTheMoney': False,
#       'lastPrice': 0.03,
#       'lastTradeDate': 1524249212,
#       'openInterest': 131,
#       'percentChange': 50.0,
#       'strike': 33.5,
#       'volume': 2},
#      {'ask': 0.04,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511C00034000',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 0.6640658593750002,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1524061011,
#       'openInterest': 33,
#       'percentChange': 0.0,
#       'strike': 34.0,
#       'volume': 10},
#      {'ask': 0.05,
#       'bid': 0.01,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511C00034500',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 0.773439765625,
#       'inTheMoney': False,
#       'lastPrice': 0.04,
#       'lastTradeDate': 1523677529,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 34.5,
#       'volume': 3},
#      {'ask': 0.04,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511C00035000',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 0.7812521875,
#       'inTheMoney': False,
#       'lastPrice': 0.03,
#       'lastTradeDate': 1523677529,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 35.0,
#       'volume': 15},
#      {'ask': 0.04,
#       'bid': 0.02,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511C00035500',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 0.8906260937499999,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1523677529,
#       'openInterest': 2,
#       'percentChange': 0.0,
#       'strike': 35.5,
#       'volume': 1},
#      {'ask': 0.03,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511C00036500',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 0.9062509375,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1522875066,
#       'openInterest': 1,
#       'percentChange': 0.0,
#       'strike': 36.5,
#       'volume': 1}],
#     'expirationDate': 1525996800,
#     'hasMiniOptions': False,
#     'puts': [{'ask': 0.04,
#       'bid': 0.01,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511P00023000',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 1.1875040625,
#       'inTheMoney': False,
#       'lastPrice': 0.03,
#       'lastTradeDate': 1522875080,
#       'openInterest': 1,
#       'percentChange': 0.0,
#       'strike': 23.0,
#       'volume': 1},
#      {'ask': 0.03,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511P00024000',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 0.937500625,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1525187120,
#       'openInterest': 5,
#       'percentChange': 0.0,
#       'strike': 24.0,
#       'volume': 3},
#      {'ask': 0.12,
#       'bid': 0.05,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511P00024500',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 1.171879140625,
#       'inTheMoney': False,
#       'lastPrice': 0.09,
#       'lastTradeDate': 1522381926,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 24.5,
#       'volume': 30},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511P00025000',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 0.73437765625,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1523991286,
#       'openInterest': 252,
#       'percentChange': 0.0,
#       'strike': 25.0,
#       'volume': 15},
#      {'ask': 0.03,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511P00025500',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 0.70312796875,
#       'inTheMoney': False,
#       'lastPrice': 0.03,
#       'lastTradeDate': 1523900393,
#       'openInterest': 1,
#       'percentChange': 0.0,
#       'strike': 25.5,
#       'volume': 1},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': 0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511P00026000',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 0.5937540625000001,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1525458324,
#       'openInterest': 334,
#       'percentChange': 100.0,
#       'strike': 26.0,
#       'volume': 7},
#      {'ask': 0.01,
#       'bid': 0.01,
#       'change': -0.02,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511P00026500',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 0.51562984375,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1525462168,
#       'openInterest': 214,
#       'percentChange': -66.66667,
#       'strike': 26.5,
#       'volume': 15},
#      {'ask': 0.0,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511P00027000',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 0.2500075,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1525705375,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 27.0,
#       'volume': 1},
#      {'ask': 0.0,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511P00027500',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 0.2500075,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1525720229,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 27.5,
#       'volume': 1190},
#      {'ask': 0.0,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511P00028000',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 0.12500875,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1525723172,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 28.0,
#       'volume': 4330},
#      {'ask': 0.0,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511P00028500',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 0.12500875,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1525722540,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 28.5,
#       'volume': 7718},
#      {'ask': 0.0,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511P00029000',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 0.062509375,
#       'inTheMoney': False,
#       'lastPrice': 0.07,
#       'lastTradeDate': 1525723189,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 29.0,
#       'volume': 17987},
#      {'ask': 0.0,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511P00029500',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 0.015634843750000002,
#       'inTheMoney': False,
#       'lastPrice': 0.2,
#       'lastTradeDate': 1525723185,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 29.5,
#       'volume': 7266},
#      {'ask': 0.0,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511P00030000',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 0.47,
#       'lastTradeDate': 1525723199,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 30.0,
#       'volume': 1718},
#      {'ask': 0.0,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511P00030500',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 0.92,
#       'lastTradeDate': 1525720612,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 30.5,
#       'volume': 261},
#      {'ask': 0.0,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511P00031000',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 1.39,
#       'lastTradeDate': 1525723172,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 31.0,
#       'volume': 59},
#      {'ask': 0.0,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511P00031500',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 1.81,
#       'lastTradeDate': 1525718642,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 31.5,
#       'volume': 112},
#      {'ask': 0.0,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511P00032500',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 2.9,
#       'lastTradeDate': 1525719142,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 32.5,
#       'volume': 21},
#      {'ask': 0.0,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511P00033000',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 3.4,
#       'lastTradeDate': 1525760350,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 33.0,
#       'volume': 5},
#      {'ask': 0.0,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511P00033500',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 3.9,
#       'lastTradeDate': 1525760350,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 33.5,
#       'volume': 2},
#      {'ask': 4.2,
#       'bid': 4.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511P00034000',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 4.4,
#       'lastTradeDate': 1522875081,
#       'openInterest': 5,
#       'percentChange': 0.0,
#       'strike': 34.0,
#       'volume': 5},
#      {'ask': 4.3,
#       'bid': 4.2,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511P00034500',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 4.35,
#       'lastTradeDate': 1524282421,
#       'openInterest': 1,
#       'percentChange': 0.0,
#       'strike': 34.5,
#       'volume': 1},
#      {'ask': 5.75,
#       'bid': 5.65,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC180511P00035000',
#       'currency': 'USD',
#       'expiration': 1525996800,
#       'impliedVolatility': 1.453127734375,
#       'inTheMoney': True,
#       'lastPrice': 4.85,
#       'lastTradeDate': 1524282421,
#       'openInterest': 6,
#       'percentChange': 0.0,
#       'strike': 35.0,
#       'volume': 1}]}],
#   'quote': {'ask': 0.0,
#    'askSize': 0,
#    'averageDailyVolume10Day': 65291966,
#    'averageDailyVolume3Month': 72456116,
#    'bid': 0.0,
#    'bidSize': 0,
#    'bookValue': 23.799,
#    'currency': 'USD',
#    'dividendDate': 1522368000,
#    'earningsTimestamp': 1531723500,
#    'earningsTimestampEnd': 1516023000,
#    'earningsTimestampStart': 1515677400,
#    'epsForward': 2.9,
#    'epsTrailingTwelveMonths': 1.559,
#    'esgPopulated': False,
#    'exchange': 'NYQ',
#    'exchangeDataDelayedBy': 0,
#    'exchangeTimezoneName': 'America/New_York',
#    'exchangeTimezoneShortName': 'EDT',
#    'fiftyDayAverage': 30.077715,
#    'fiftyDayAverageChange': -0.43771553,
#    'fiftyDayAverageChangePercent': -0.014552819,
#    'fiftyTwoWeekHigh': 33.05,
#    'fiftyTwoWeekHighChange': -3.4099998,
#    'fiftyTwoWeekHighChangePercent': -0.103177,
#    'fiftyTwoWeekLow': 22.07,
#    'fiftyTwoWeekLowChange': 7.5699997,
#    'fiftyTwoWeekLowChangePercent': 0.34299955,
#    'fiftyTwoWeekRange': '22.07 - 33.05',
#    'financialCurrency': 'USD',
#    'forwardPE': 10.220689,
#    'fullExchangeName': 'NYSE',
#    'gmtOffSetMilliseconds': -14400000,
#    'language': 'en-US',
#    'longName': 'Bank of America Corporation',
#    'market': 'us_market',
#    'marketCap': 300531810304,
#    'marketState': 'PREPRE',
#    'messageBoardId': 'finmb_19049',
#    'postMarketChange': -0.010000229,
#    'postMarketChangePercent': -0.033738963,
#    'postMarketPrice': 29.63,
#    'postMarketTime': 1525737545,
#    'priceHint': 2,
#    'priceToBook': 1.2454305,
#    'quoteSourceName': 'Delayed Quote',
#    'quoteType': 'EQUITY',
#    'regularMarketChange': 0.34000015,
#    'regularMarketChangePercent': 1.1604102,
#    'regularMarketDayHigh': 29.7879,
#    'regularMarketDayLow': 29.33,
#    'regularMarketDayRange': '29.33 - 29.7879',
#    'regularMarketOpen': 29.44,
#    'regularMarketPreviousClose': 29.3,
#    'regularMarketPrice': 29.64,
#    'regularMarketTime': 1525723218,
#    'regularMarketVolume': 46765219,
#    'sharesOutstanding': 10139400192,
#    'shortName': 'Bank of America Corporation',
#    'sourceInterval': 15,
#    'symbol': 'BAC',
#    'tradeable': True,
#    'trailingAnnualDividendRate': 0.39,
#    'trailingAnnualDividendYield': 0.0133105805,
#    'trailingPE': 19.012186,
#    'twoHundredDayAverage': 29.901323,
#    'twoHundredDayAverageChange': -0.26132393,
#    'twoHundredDayAverageChangePercent': -0.008739544},
#   'strikes': [22.5,
#    23.0,
#    23.5,
#    24.0,
#    24.5,
#    25.0,
#    25.5,
#    26.0,
#    26.5,
#    27.0,
#    27.5,
#    28.0,
#    28.5,
#    29.0,
#    29.5,
#    30.0,
#    30.5,
#    31.0,
#    31.5,
#    32.0,
#    32.5,
#    33.0,
#    33.5,
#    34.0,
#    34.5,
#    35.0,
#    35.5,
#    36.5],
#   'underlyingSymbol': 'BAC'}]

# %%
result = results[0]
dates = [dt.fromtimestamp(tm) for tm in result['expirationDates']]
# we can use these dates to get data for a specific expiration date
# an example url: https://query1.finance.yahoo.com/v7/finance/options/BAC?date=1484265600 
# the first date is default
dates
# Out:
# [datetime.datetime(2018, 5, 11, 0, 0),
#  datetime.datetime(2018, 5, 18, 0, 0),
#  datetime.datetime(2018, 5, 25, 0, 0),
#  datetime.datetime(2018, 6, 1, 0, 0),
#  datetime.datetime(2018, 6, 8, 0, 0),
#  datetime.datetime(2018, 6, 15, 0, 0),
#  datetime.datetime(2018, 6, 22, 0, 0),
#  datetime.datetime(2018, 7, 20, 0, 0),
#  datetime.datetime(2018, 8, 17, 0, 0),
#  datetime.datetime(2018, 9, 21, 0, 0),
#  datetime.datetime(2018, 10, 19, 0, 0),
#  datetime.datetime(2018, 11, 16, 0, 0),
#  datetime.datetime(2018, 12, 21, 0, 0),
#  datetime.datetime(2019, 1, 18, 0, 0),
#  datetime.datetime(2019, 6, 21, 0, 0),
#  datetime.datetime(2020, 1, 17, 0, 0)]

# %%
option = result['options'][0]
calls = option['calls']
calls[:2]
# Out:
# [{'ask': 8.15,
#   'bid': 7.6,
#   'change': 0.0,
#   'contractSize': 'REGULAR',
#   'contractSymbol': 'BAC180511C00022500',
#   'currency': 'USD',
#   'expiration': 1525996800,
#   'impliedVolatility': 2.8496122509765627,
#   'inTheMoney': True,
#   'lastPrice': 7.64,
#   'lastTradeDate': 1524158478,
#   'openInterest': 2,
#   'percentChange': 0.0,
#   'strike': 22.5,
#   'volume': 2},
#  {'ask': 6.45,
#   'bid': 6.3,
#   'change': 0.4000001,
#   'contractSize': 'REGULAR',
#   'contractSymbol': 'BAC180511C00023500',
#   'currency': 'USD',
#   'expiration': 1525996800,
#   'impliedVolatility': 1.75000125,
#   'inTheMoney': True,
#   'lastPrice': 7.0,
#   'lastTradeDate': 1523677528,
#   'openInterest': 2,
#   'percentChange': 5.7142873,
#   'strike': 23.5,
#   'volume': 2}]

# %%
puts = option['puts']
puts[-2:]
# Out:
# [{'ask': 4.3,
#   'bid': 4.2,
#   'change': 0.0,
#   'contractSize': 'REGULAR',
#   'contractSymbol': 'BAC180511P00034500',
#   'currency': 'USD',
#   'expiration': 1525996800,
#   'impliedVolatility': 1.0000000000000003e-05,
#   'inTheMoney': True,
#   'lastPrice': 4.35,
#   'lastTradeDate': 1524282421,
#   'openInterest': 1,
#   'percentChange': 0.0,
#   'strike': 34.5,
#   'volume': 1},
#  {'ask': 5.75,
#   'bid': 5.65,
#   'change': 0.0,
#   'contractSize': 'REGULAR',
#   'contractSymbol': 'BAC180511P00035000',
#   'currency': 'USD',
#   'expiration': 1525996800,
#   'impliedVolatility': 1.453127734375,
#   'inTheMoney': True,
#   'lastPrice': 4.85,
#   'lastTradeDate': 1524282421,
#   'openInterest': 6,
#   'percentChange': 0.0,
#   'strike': 35.0,
#   'volume': 1}]

# %% [markdown]
# # Implementation

# %%
# There is a lot of data to load every minute, so we have to do this in parrallel
# 'threading' module fits well for this purpose
# I'm going to use two queues to connect our main programm and thread workers: 
# the first is for tasks, the other - for results
# You can find some examples of using 'queue'-module here
# https://docs.python.org/3/library/queue.html#queue.Queue.join
import queue
import requests
import threading


def load_data(time):
    
    num_worker_threads = 1000
    
    def worker():
        while True:
            args = q.get()
            if args is None:  # None argument is passed to stop any worker that gets it
                break
            get_transactions(q, r, *args)  # <-- see definition of this function below
            q.task_done()

    q = queue.Queue() # queue with arguments for the 'get_transactions' function
    r = queue.Queue() # queue with raw responses

    threads = []
    for i in range(num_worker_threads):
        t = threading.Thread(target=worker)
        t.start()
        threads.append(t)

    for stock in STOCKS:
        q.put((stock, None))

    # block until all tasks are done
    q.join()

    # stop workers
    for i in range(num_worker_threads):
        q.put(None)

    for t in threads:
        t.join()
        
    save_rows(r, time)
    
    
def get_transactions(queue, resp_queue, stock, date=None):     
    base_url = "https://query1.finance.yahoo.com/v7/finance/options/{}".format(stock)
    if date is not None:
        url = "{}?date={}".format(base_url, date)
    else:
        url = base_url
    
    try:
        page = requests.get(url)
    except Exception as e:
        print(e)
    else:
        try:
            response = page.json()
        except Exception as e:  # network problems or wrong server answers
            print(e)
        else:
            if response['optionChain']['error']: # if any error
                print(response['optionChain']['error'])

            else:
                results = response['optionChain']['result']
                for result in results:
                    price = result['quote']['regularMarketPrice']
                    for option in result['options']:
                        resp_queue.put(
                            (stock, price, option['calls'], option['puts'])
                        )

                    if date is None:
                        for tm in result['expirationDates'][1:]:
                            queue.put((stock, tm))

# %%
# Functions which take response from the response queue and put to the 'largest_transactions' list
def save_rows(q, time):
    while True:
        try:
            stock, price, calls, puts = q.get(block=False)
        except queue.Empty:
            break
        else:
            for call in calls:
                save_row(stock, price, 'Calls', time, call)
            for put in puts:
                save_row(stock, price, 'Puts', time, put)

def save_row(s, price, t, time, raw):
    contact = raw['contractSymbol']    
    previous_volume = transaction_volumes.get(contact)
    volume = raw['volume']
    transaction_volumes[contact] = volume
    
    if previous_volume is not None:        
        volume_diff = volume - previous_volume
        if volume_diff > 0:
            last_price = raw['lastPrice']
            strike = raw['strike']
            ask = raw['ask']
            bid = raw['bid']
            largest_transactions.append(
                dict(
                    stock=s,
                    price=price,
                    type=t,
                    time=time,
                    expiration=dt.fromtimestamp(raw['expiration']),
                    strike=strike,
                    contact=contact,
                    last_price=last_price,
                    bid=bid,
                    ask=ask,
                    volume=volume,
                    open_interest=raw['openInterest'],
                    implied_volatility=raw['impliedVolatility'],
                    volume_diff=volume_diff,
                    cost=volume_diff * 100 * last_price,
                    strike_div_price=(strike / price - 1) * 100,
                    last_price_position="{:.0f}".format((1 - (ask-last_price) / (ask-bid)) * 100) if ask != bid else None
                )
            )

# %%
# This function will display the table
from IPython.display import clear_output, display, HTML

headers = (
    "Stock", "Share $", "Options", "Volume", "Open Interest", "Strike", "S / S", 
    "Expiration", "Last price", "Bid", "Ask", "Position",  "Value", "Time of trade",
)
row = """
<td>{stock}</td><td>{price}</td><td>{type}</td><td>{volume_diff}</td><td>{open_interest}</td>
<td>{strike}</td><td>{strike_div_price:.2f}%</td><td>{expiration:%b %d, %Y}</td>
<td>{last_price}</td><td>{bid}</td><td>{ask}</td><td>{last_price_position}%</td>
<td>${cost:,.0f}</td><td>{time:%I:%M%p}</td>
"""

def display_data():    
    table_rows = (row.format(**row_data) for row_data in largest_transactions)           
    clear_output()
    display(
        HTML(
            '<table><tr><th>{}</th></tr><tr>{}</tr></table>'.format(
                "</th><th>".join(headers),
                "</tr><tr>".join(table_rows)
            )
        )
    )

# %%
from datetime import datetime as dt, timedelta as td
from pytz import timezone
from time import sleep
import heapq

tz = timezone('America/Los_Angeles')  # timezone produces time with PST or PDT tzname depending on the date
STOCKS = ['AAPL', 'BAC', 'NVDA', 'AMZN', 'FB']

last_time = None
count = 1
largest_transactions = []  # here we will store top entries
transaction_volumes = {}  # latest volumes for transactions

while True:    
    now = dt.now(tz=tz)
    start = now.replace(hour=6, minute=30, second=0, microsecond=0)
    stop = start.replace(hour=13, minute=0)
    
    if start <= now <= stop: # proper time for getting data
        
        if last_time: # no more often than once per minute
            diff = 60 - (now - last_time).seconds            
            if diff > 0:
                sleep(diff)  
        
        # the main functionality
        load_data(now)
        # it's efficient way to keep only top 20 entries in the 'largest_transactions' list
        largest_transactions = heapq.nlargest(20, largest_transactions, key=lambda i: i['cost'])
        display_data()
        
        # some statistics
        print("last update", now)
        print("prev update", last_time) 
        print("update time", dt.now(tz=tz) - now)
        print("iterations", count)        
        count += 1        
        last_time = now        
    else:
        largest_transactions = [] # drop transactions
        if now < start:
            diff = start - now
            print("time to start:", diff)
            
        else:
            start_tommorow = start + td(days=1)
            print("start tommorow at", start_tommorow)
            diff = start_tommorow - now
        
        sleep(diff.seconds + diff.microseconds * 0.1 ** 6)
# Out:
# <table><tr><th>Stock</th><th>Share $</th><th>Options</th><th>Volume</th><th>Open Interest</th><th>Strike</th><th>S / S</th><th>Expiration</th><th>Last price</th><th>Bid</th><th>Ask</th><th>Position</th><th>Value</th><th>Time of trade</th></tr><tr>
# <td>AMZN</td><td>1600.14</td><td>Puts</td><td>3</td><td>252</td>
# <td>1460.0</td><td>-8.76%</td><td>Jan 18, 2019</td>
# <td>82.97</td><td>82.7</td><td>84.7</td><td>13%</td>
# <td>$24,891</td><td>09:00AM</td>
# </tr><tr>
# <td>BAC</td><td>29.64</td><td>Puts</td><td>216</td><td>641</td>
# <td>25.0</td><td>-15.65%</td><td>Jun 01, 2018</td>
# <td>0.03</td><td>0.02</td><td>0.04</td><td>50%</td>
# <td>$648</td><td>09:00AM</td>
# </tr><tr>
# <td>AMZN</td><td>1600.14</td><td>Puts</td><td>9</td><td>110</td>
# <td>410.0</td><td>-74.38%</td><td>Jan 18, 2019</td>
# <td>0.3</td><td>0.0</td><td>0.75</td><td>40%</td>
# <td>$270</td><td>09:00AM</td>
# </tr></table>
# last update 2018-05-07 09:00:00-07:53
# prev update 2018-05-07 09:00:00-07:53
# update time 14:02:11.894572
# iterations 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-3204e7608d6a> in <module>()
#      23             diff = 60 - (now - last_time).seconds
#      24             if diff > 0:
# ---> 25                 sleep(diff)
#      26
#      27         # the main functionality
#
# KeyboardInterrupt:
