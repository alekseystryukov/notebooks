# %%
from datetime import datetime as dt, timedelta as td
import requests

# %%
url = "https://query1.finance.yahoo.com/v7/finance/options/BAC"
#?formatted=true&crumb=bCkXlpLUQ.w&lang=en-US&region=US&date=1484265600&corsDomain=finance.yahoo.com

# %%
page = requests.get(url)
response = page.json()
if response['optionChain']['error']:
    print(response['optionChain']['error'])

results = response['optionChain']['result']
results
# Out:
# [{'expirationDates': [1484870400,
#    1485475200,
#    1486080000,
#    1486684800,
#    1487289600,
#    1487894400,
#    1488499200,
#    1489708800,
#    1492732800,
#    1495152000,
#    1497571200,
#    1503014400,
#    1513296000,
#    1516320000,
#    1547769600],
#   'hasMiniOptions': False,
#   'options': [{'calls': [{'ask': 17.75,
#       'bid': 17.65,
#       'change': 0.010000229,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00005000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.500005,
#       'inTheMoney': True,
#       'lastPrice': 17.87,
#       'lastTradeDate': 1484930558,
#       'openInterest': 261,
#       'percentChange': 0.055992324,
#       'strike': 5.0,
#       'volume': 210},
#      {'ask': 10.85,
#       'bid': 10.3,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00006000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 10.4,
#       'lastTradeDate': 1476885202,
#       'openInterest': 2,
#       'percentChange': 0.0,
#       'strike': 6.0,
#       'volume': 2},
#      {'ask': 15.75,
#       'bid': 15.65,
#       'change': 2.4499998,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00007000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.500005,
#       'inTheMoney': True,
#       'lastPrice': 15.8,
#       'lastTradeDate': 1484931768,
#       'openInterest': 60,
#       'percentChange': 18.352058,
#       'strike': 7.0,
#       'volume': 60},
#      {'ask': 14.8,
#       'bid': 14.6,
#       'change': 0.22999954,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00008000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 9.75000390625,
#       'inTheMoney': True,
#       'lastPrice': 14.75,
#       'lastTradeDate': 1484934699,
#       'openInterest': 2406,
#       'percentChange': 1.5840187,
#       'strike': 8.0,
#       'volume': 3},
#      {'ask': 13.95,
#       'bid': 13.6,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00009000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 7.87500015625,
#       'inTheMoney': True,
#       'lastPrice': 13.28,
#       'lastTradeDate': 1484750915,
#       'openInterest': 187,
#       'percentChange': 0.0,
#       'strike': 9.0,
#       'volume': 40},
#      {'ask': 12.7,
#       'bid': 12.65,
#       'change': 0.21000004,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00010000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 12.75,
#       'lastTradeDate': 1484934486,
#       'openInterest': 10169,
#       'percentChange': 1.6746415,
#       'strike': 10.0,
#       'volume': 996},
#      {'ask': 11.75,
#       'bid': 11.6,
#       'change': 0.09999943,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00011000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.500005,
#       'inTheMoney': True,
#       'lastPrice': 11.7,
#       'lastTradeDate': 1484925081,
#       'openInterest': 569,
#       'percentChange': 0.862064,
#       'strike': 11.0,
#       'volume': 10},
#      {'ask': 10.95,
#       'bid': 10.6,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00012000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 5.62500296875,
#       'inTheMoney': True,
#       'lastPrice': 10.47,
#       'lastTradeDate': 1484751464,
#       'openInterest': 443,
#       'percentChange': 0.0,
#       'strike': 12.0,
#       'volume': 202},
#      {'ask': 9.75,
#       'bid': 9.6,
#       'change': 0.32999992,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00013000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.500005,
#       'inTheMoney': True,
#       'lastPrice': 9.85,
#       'lastTradeDate': 1484932906,
#       'openInterest': 22174,
#       'percentChange': 3.4663856,
#       'strike': 13.0,
#       'volume': 7915},
#      {'ask': 8.75,
#       'bid': 8.6,
#       'change': 0.29999924,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00014000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.500005,
#       'inTheMoney': True,
#       'lastPrice': 8.9,
#       'lastTradeDate': 1484928764,
#       'openInterest': 2984,
#       'percentChange': 3.488363,
#       'strike': 14.0,
#       'volume': 33},
#      {'ask': 7.7,
#       'bid': 7.55,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00014500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 7.45,
#       'lastTradeDate': 1483038300,
#       'openInterest': 31,
#       'percentChange': 0.0,
#       'strike': 14.5,
#       'volume': 32},
#      {'ask': 7.7,
#       'bid': 7.65,
#       'change': 0.13000011,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00015000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 7.65,
#       'lastTradeDate': 1484935500,
#       'openInterest': 62057,
#       'percentChange': 1.7287248,
#       'strike': 15.0,
#       'volume': 3218},
#      {'ask': 7.55,
#       'bid': 7.45,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00015500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 5.64062794921875,
#       'inTheMoney': True,
#       'lastPrice': 7.5,
#       'lastTradeDate': 1484166763,
#       'openInterest': 144,
#       'percentChange': 0.0,
#       'strike': 15.5,
#       'volume': 13},
#      {'ask': 6.7,
#       'bid': 6.65,
#       'change': 0.13000011,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00016000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 6.65,
#       'lastTradeDate': 1484935604,
#       'openInterest': 57553,
#       'percentChange': 1.9938668,
#       'strike': 16.0,
#       'volume': 463},
#      {'ask': 6.55,
#       'bid': 6.45,
#       'change': 0.14999962,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00016500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 4.906253867187499,
#       'inTheMoney': True,
#       'lastPrice': 6.45,
#       'lastTradeDate': 1484333383,
#       'openInterest': 160,
#       'percentChange': 2.3809462,
#       'strike': 16.5,
#       'volume': 27},
#      {'ask': 5.7,
#       'bid': 5.65,
#       'change': 0.17000008,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00017000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 5.69,
#       'lastTradeDate': 1484935301,
#       'openInterest': 297263,
#       'percentChange': 3.0797114,
#       'strike': 17.0,
#       'volume': 4962},
#      {'ask': 5.55,
#       'bid': 5.45,
#       'change': 0.25,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00017500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 4.20312974609375,
#       'inTheMoney': True,
#       'lastPrice': 5.6,
#       'lastTradeDate': 1484326813,
#       'openInterest': 107,
#       'percentChange': 4.6728973,
#       'strike': 17.5,
#       'volume': 119},
#      {'ask': 4.7,
#       'bid': 4.65,
#       'change': 0.14999962,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00018000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 4.68,
#       'lastTradeDate': 1484935376,
#       'openInterest': 115233,
#       'percentChange': 3.3112497,
#       'strike': 18.0,
#       'volume': 1495},
#      {'ask': 4.25,
#       'bid': 4.1,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00018500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.500005,
#       'inTheMoney': True,
#       'lastPrice': 4.0,
#       'lastTradeDate': 1484839061,
#       'openInterest': 188,
#       'percentChange': 0.0,
#       'strike': 18.5,
#       'volume': 12},
#      {'ask': 3.7,
#       'bid': 3.65,
#       'change': 0.22000003,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00019000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 3.74,
#       'lastTradeDate': 1484934769,
#       'openInterest': 222897,
#       'percentChange': 6.250001,
#       'strike': 19.0,
#       'volume': 228},
#      {'ask': 3.2,
#       'bid': 3.15,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00019500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 2.98,
#       'lastTradeDate': 1484839056,
#       'openInterest': 1241,
#       'percentChange': 0.0,
#       'strike': 19.5,
#       'volume': 46},
#      {'ask': 2.73,
#       'bid': 2.7,
#       'change': 0.1500001,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00020000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 2.68,
#       'lastTradeDate': 1484935486,
#       'openInterest': 219659,
#       'percentChange': 5.928858,
#       'strike': 20.0,
#       'volume': 11590},
#      {'ask': 2.18,
#       'bid': 2.17,
#       'change': 0.29999995,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00020500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 2.32,
#       'lastTradeDate': 1484931737,
#       'openInterest': 2403,
#       'percentChange': 14.851482,
#       'strike': 20.5,
#       'volume': 15},
#      {'ask': 1.68,
#       'bid': 1.67,
#       'change': 0.16999996,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00021000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 1.68,
#       'lastTradeDate': 1484935623,
#       'openInterest': 89307,
#       'percentChange': 11.258275,
#       'strike': 21.0,
#       'volume': 3065},
#      {'ask': 1.19,
#       'bid': 1.18,
#       'change': 0.37,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00021500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 1.4,
#       'lastTradeDate': 1484929145,
#       'openInterest': 6260,
#       'percentChange': 35.92233,
#       'strike': 21.5,
#       'volume': 2024},
#      {'ask': 0.69,
#       'bid': 0.68,
#       'change': 0.15000004,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00022000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 0.68,
#       'lastTradeDate': 1484935617,
#       'openInterest': 230140,
#       'percentChange': 28.301895,
#       'strike': 22.0,
#       'volume': 12681},
#      {'ask': 0.21,
#       'bid': 0.2,
#       'change': 0.030000001,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00022500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 0.2,
#       'lastTradeDate': 1484935751,
#       'openInterest': 36166,
#       'percentChange': 17.647058,
#       'strike': 22.5,
#       'volume': 27773},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.02,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00023000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.16407085937500002,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484935282,
#       'openInterest': 177033,
#       'percentChange': -66.66667,
#       'strike': 23.0,
#       'volume': 32631},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00023500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.37500625,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484933647,
#       'openInterest': 32426,
#       'percentChange': 0.0,
#       'strike': 23.5,
#       'volume': 123},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00024000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.500005,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484934948,
#       'openInterest': 88070,
#       'percentChange': 0.0,
#       'strike': 24.0,
#       'volume': 115},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': -0.07,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00024500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.7500025,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484340149,
#       'openInterest': 15005,
#       'percentChange': -87.5,
#       'strike': 24.5,
#       'volume': 23072},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.03,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00025000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.8125018749999999,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484340447,
#       'openInterest': 133741,
#       'percentChange': -75.0,
#       'strike': 25.0,
#       'volume': 3059},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.02,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00025500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.937500625,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484323358,
#       'openInterest': 35301,
#       'percentChange': -66.66667,
#       'strike': 25.5,
#       'volume': 268},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00026000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.125004375,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484318201,
#       'openInterest': 29812,
#       'percentChange': -50.0,
#       'strike': 26.0,
#       'volume': 2},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00026500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.3750031249999999,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1483563510,
#       'openInterest': 647,
#       'percentChange': 0.0,
#       'strike': 26.5,
#       'volume': 14},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00027000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.3750031249999999,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483730925,
#       'openInterest': 22851,
#       'percentChange': -50.0,
#       'strike': 27.0,
#       'volume': 446},
#      {'ask': 0.02,
#       'bid': 0.01,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00027500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.71875140625,
#       'inTheMoney': False,
#       'lastPrice': 0.03,
#       'lastTradeDate': 1482262814,
#       'openInterest': 211,
#       'percentChange': 0.0,
#       'strike': 27.5,
#       'volume': 105},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00028000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.75000125,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483114158,
#       'openInterest': 3803,
#       'percentChange': -50.0,
#       'strike': 28.0,
#       'volume': 10},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00029000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.000005,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1482338643,
#       'openInterest': 1755,
#       'percentChange': 0.0,
#       'strike': 29.0,
#       'volume': 10},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00029500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.9375003125,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1482554706,
#       'openInterest': 165,
#       'percentChange': 0.0,
#       'strike': 29.5,
#       'volume': 155},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00030000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.0625048437499998,
#       'inTheMoney': False,
#       'lastPrice': 0.03,
#       'lastTradeDate': 1484836227,
#       'openInterest': 41890,
#       'percentChange': 0.0,
#       'strike': 30.0,
#       'volume': 20},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00030500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.1875045312499997,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483159928,
#       'openInterest': 50,
#       'percentChange': 0.0,
#       'strike': 30.5,
#       'volume': 40},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00031000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.50000375,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1481950427,
#       'openInterest': 70,
#       'percentChange': 0.0,
#       'strike': 31.0,
#       'volume': 77},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00032000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.50000375,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1482849755,
#       'openInterest': 10,
#       'percentChange': 0.0,
#       'strike': 32.0,
#       'volume': 5}],
#     'expirationDate': 1484870400,
#     'hasMiniOptions': False,
#     'puts': [{'ask': 0.02,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00005000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 11.25000296875,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1472240413,
#       'openInterest': 37092,
#       'percentChange': -50.0,
#       'strike': 5.0,
#       'volume': 200},
#      {'ask': 0.02,
#       'bid': 0.01,
#       'change': 0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00006000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 10.500003437500002,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1471536077,
#       'openInterest': 3686,
#       'percentChange': 100.0,
#       'strike': 6.0,
#       'volume': 100},
#      {'ask': 0.02,
#       'bid': 0.01,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00007000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 9.25000421875,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1473185890,
#       'openInterest': 2538,
#       'percentChange': 0.0,
#       'strike': 7.0,
#       'volume': 100},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00008000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 7.2500009375,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1476714104,
#       'openInterest': 41423,
#       'percentChange': 0.0,
#       'strike': 8.0,
#       'volume': 20},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00009000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 7.00000125,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1478619748,
#       'openInterest': 11490,
#       'percentChange': -50.0,
#       'strike': 9.0,
#       'volume': 1},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00010000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 5.7500028125,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1478890672,
#       'openInterest': 110039,
#       'percentChange': 0.0,
#       'strike': 10.0,
#       'volume': 209},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00011000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 5.62500296875,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1479329456,
#       'openInterest': 23258,
#       'percentChange': 0.0,
#       'strike': 11.0,
#       'volume': 164},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.02,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00012000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 4.62500421875,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1479501105,
#       'openInterest': 36055,
#       'percentChange': -66.66667,
#       'strike': 12.0,
#       'volume': 55},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00013000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 4.000005,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1482524762,
#       'openInterest': 280696,
#       'percentChange': 0.0,
#       'strike': 13.0,
#       'volume': 11},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00014000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 3.50000125,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483036985,
#       'openInterest': 53475,
#       'percentChange': 0.0,
#       'strike': 14.0,
#       'volume': 15},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00015000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 3.1250021875,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483634806,
#       'openInterest': 273307,
#       'percentChange': 0.0,
#       'strike': 15.0,
#       'volume': 40},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00016000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.6250034375,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484160718,
#       'openInterest': 35022,
#       'percentChange': 0.0,
#       'strike': 16.0,
#       'volume': 10},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00016500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.50000375,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483764258,
#       'openInterest': 171,
#       'percentChange': 0.0,
#       'strike': 16.5,
#       'volume': 171},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00017000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.2500043749999996,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484840373,
#       'openInterest': 244973,
#       'percentChange': 0.0,
#       'strike': 17.0,
#       'volume': 8},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00017500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.2500043749999996,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483042332,
#       'openInterest': 8234,
#       'percentChange': 0.0,
#       'strike': 17.5,
#       'volume': 140},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00018000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.875000625,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483731773,
#       'openInterest': 36798,
#       'percentChange': 0.0,
#       'strike': 18.0,
#       'volume': 110},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00018500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.8125009374999999,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483559058,
#       'openInterest': 882,
#       'percentChange': 0.0,
#       'strike': 18.5,
#       'volume': 75},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00019000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.4375028125,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484328548,
#       'openInterest': 43266,
#       'percentChange': -50.0,
#       'strike': 19.0,
#       'volume': 1615},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00019500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.2500037499999999,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1484243723,
#       'openInterest': 919,
#       'percentChange': 0.0,
#       'strike': 19.5,
#       'volume': 2},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00020000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0625046875000002,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484927615,
#       'openInterest': 136054,
#       'percentChange': 0.0,
#       'strike': 20.0,
#       'volume': 30},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00020500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.9062509375,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484773183,
#       'openInterest': 4852,
#       'percentChange': 0.0,
#       'strike': 20.5,
#       'volume': 50},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00021000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.7187528125,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484934506,
#       'openInterest': 59518,
#       'percentChange': 0.0,
#       'strike': 21.0,
#       'volume': 36},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00021500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.5312546875,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484935001,
#       'openInterest': 15254,
#       'percentChange': 0.0,
#       'strike': 21.5,
#       'volume': 175},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.02,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00022000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.39063109375,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484934871,
#       'openInterest': 186302,
#       'percentChange': -66.66667,
#       'strike': 22.0,
#       'volume': 371},
#      {'ask': 0.02,
#       'bid': 0.01,
#       'change': -0.099999994,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00022500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.21094539062499998,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1484935342,
#       'openInterest': 54055,
#       'percentChange': -83.33333,
#       'strike': 22.5,
#       'volume': 8640},
#      {'ask': 0.32,
#       'bid': 0.31,
#       'change': -0.19,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00023000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.34766277343749996,
#       'inTheMoney': True,
#       'lastPrice': 0.31,
#       'lastTradeDate': 1484935709,
#       'openInterest': 53142,
#       'percentChange': -38.0,
#       'strike': 23.0,
#       'volume': 6778},
#      {'ask': 0.8,
#       'bid': 0.8,
#       'change': -0.17000002,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00023500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.57812921875,
#       'inTheMoney': True,
#       'lastPrice': 0.77,
#       'lastTradeDate': 1484933592,
#       'openInterest': 2312,
#       'percentChange': -18.085108,
#       'strike': 23.5,
#       'volume': 55},
#      {'ask': 1.83,
#       'bid': 1.82,
#       'change': -0.3499999,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00024500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.1484417578125,
#       'inTheMoney': True,
#       'lastPrice': 1.7,
#       'lastTradeDate': 1484932216,
#       'openInterest': 1501,
#       'percentChange': -17.073166,
#       'strike': 24.5,
#       'volume': 10},
#      {'ask': 2.32,
#       'bid': 2.31,
#       'change': -0.25,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00025000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.3203158984374999,
#       'inTheMoney': True,
#       'lastPrice': 2.23,
#       'lastTradeDate': 1484934506,
#       'openInterest': 19484,
#       'percentChange': -10.080646,
#       'strike': 25.0,
#       'volume': 208},
#      {'ask': 2.83,
#       'bid': 2.82,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00025500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.5781271093749998,
#       'inTheMoney': True,
#       'lastPrice': 3.0,
#       'lastTradeDate': 1484839061,
#       'openInterest': 310,
#       'percentChange': 0.0,
#       'strike': 25.5,
#       'volume': 2},
#      {'ask': 3.35,
#       'bid': 3.3,
#       'change': -0.4000001,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00026000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.765626171875,
#       'inTheMoney': True,
#       'lastPrice': 3.32,
#       'lastTradeDate': 1484924748,
#       'openInterest': 605,
#       'percentChange': -10.75269,
#       'strike': 26.0,
#       'volume': 70},
#      {'ask': 3.85,
#       'bid': 3.8,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00026500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.953125234375,
#       'inTheMoney': True,
#       'lastPrice': 4.0,
#       'lastTradeDate': 1484839061,
#       'openInterest': 47,
#       'percentChange': 0.0,
#       'strike': 26.5,
#       'volume': 8},
#      {'ask': 4.05,
#       'bid': 3.95,
#       'change': -0.25,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00027000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 3.9,
#       'lastTradeDate': 1484322511,
#       'openInterest': 603,
#       'percentChange': -6.024096,
#       'strike': 27.0,
#       'volume': 1},
#      {'ask': 4.55,
#       'bid': 4.45,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00027500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 4.55,
#       'lastTradeDate': 1484074867,
#       'openInterest': 11,
#       'percentChange': 0.0,
#       'strike': 27.5,
#       'volume': 10},
#      {'ask': 5.05,
#       'bid': 4.95,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00028000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 5.0,
#       'lastTradeDate': 1484068828,
#       'openInterest': 180,
#       'percentChange': 0.0,
#       'strike': 28.0,
#       'volume': 10},
#      {'ask': 5.85,
#       'bid': 5.75,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00028500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.43750390625,
#       'inTheMoney': True,
#       'lastPrice': 5.8,
#       'lastTradeDate': 1483545990,
#       'openInterest': 23,
#       'percentChange': 0.0,
#       'strike': 28.5,
#       'volume': 22},
#      {'ask': 6.35,
#       'bid': 6.25,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00029000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.5781285546875,
#       'inTheMoney': True,
#       'lastPrice': 6.16,
#       'lastTradeDate': 1483626950,
#       'openInterest': 122,
#       'percentChange': 0.0,
#       'strike': 29.0,
#       'volume': 7},
#      {'ask': 7.4,
#       'bid': 7.3,
#       'change': 0.25,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00029500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 5.0937536328125,
#       'inTheMoney': True,
#       'lastPrice': 7.45,
#       'lastTradeDate': 1483108656,
#       'openInterest': 71,
#       'percentChange': 3.4722223,
#       'strike': 29.5,
#       'volume': 16},
#      {'ask': 7.4,
#       'bid': 7.05,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00030000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 3.5781260546875,
#       'inTheMoney': True,
#       'lastPrice': 7.92,
#       'lastTradeDate': 1484683974,
#       'openInterest': 566,
#       'percentChange': 0.0,
#       'strike': 30.0,
#       'volume': 2},
#      {'ask': 8.9,
#       'bid': 8.8,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00031000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 5.667971665039062,
#       'inTheMoney': True,
#       'lastPrice': 9.05,
#       'lastTradeDate': 1483040040,
#       'openInterest': 293,
#       'percentChange': 0.0,
#       'strike': 31.0,
#       'volume': 170},
#      {'ask': 9.35,
#       'bid': 9.25,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00032000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 3.3906265234374997,
#       'inTheMoney': True,
#       'lastPrice': 9.68,
#       'lastTradeDate': 1484674693,
#       'openInterest': 83,
#       'percentChange': 0.0,
#       'strike': 32.0,
#       'volume': 18}]}],
#   'quote': {'ask': 0.0,
#    'askSize': 0,
#    'averageDailyVolume10Day': 118337914,
#    'averageDailyVolume3Month': 119729733,
#    'bid': 0.0,
#    'bidSize': 0,
#    'bookValue': 24.187,
#    'currency': 'USD',
#    'dividendDate': 1483056000,
#    'earningsTimestamp': 1484332200,
#    'earningsTimestampEnd': 1492446600,
#    'earningsTimestampStart': 1492014600,
#    'epsForward': 1.62,
#    'epsTrailingTwelveMonths': 1.367,
#    'exchange': 'NYQ',
#    'exchangeTimezoneName': 'America/New_York',
#    'exchangeTimezoneShortName': 'EST',
#    'fiftyDayAverage': 22.53303,
#    'fiftyDayAverageChange': 0.21697044,
#    'fiftyDayAverageChangePercent': 0.009628995,
#    'fiftyTwoWeekHigh': 23.41,
#    'fiftyTwoWeekHighChange': -0.65999985,
#    'fiftyTwoWeekHighChangePercent': -0.028193073,
#    'fiftyTwoWeekLow': 10.99,
#    'fiftyTwoWeekLowChange': 11.76,
#    'fiftyTwoWeekLowChangePercent': 1.0700637,
#    'forwardPE': 14.04321,
#    'fullExchangeName': 'NYSE',
#    'gmtOffSetMilliseconds': -18000000,
#    'longName': 'Bank of America Corporation',
#    'market': 'us_market',
#    'marketCap': 229888753664,
#    'marketState': 'REGULAR',
#    'messageBoardId': 'finmb_19049',
#    'priceToBook': 0.94058794,
#    'quoteSourceName': 'NYSE Real Time Price',
#    'quoteType': 'EQUITY',
#    'regularMarketChange': 0.21999931,
#    'regularMarketChangePercent': 0.97647274,
#    'regularMarketDayHigh': 22.93,
#    'regularMarketDayLow': 22.62,
#    'regularMarketOpen': 22.66,
#    'regularMarketPreviousClose': 22.53,
#    'regularMarketPrice': 22.75,
#    'regularMarketTime': 1484936765,
#    'regularMarketVolume': 65511798,
#    'sharesOutstanding': 10105000000,
#    'shortName': 'Bank of America Corporation Com',
#    'sourceInterval': 15,
#    'symbol': 'BAC',
#    'trailingAnnualDividendRate': 0.225,
#    'trailingPE': 16.642282,
#    'twoHundredDayAverage': 17.578623,
#    'twoHundredDayAverageChange': 5.171377,
#    'twoHundredDayAverageChangePercent': 0.29418558},
#   'strikes': [5.0,
#    6.0,
#    7.0,
#    8.0,
#    9.0,
#    10.0,
#    11.0,
#    12.0,
#    13.0,
#    14.0,
#    14.5,
#    15.0,
#    15.5,
#    16.0,
#    16.5,
#    17.0,
#    17.5,
#    18.0,
#    18.5,
#    19.0,
#    19.5,
#    20.0,
#    20.5,
#    21.0,
#    21.5,
#    22.0,
#    22.5,
#    23.0,
#    23.5,
#    24.0,
#    24.5,
#    25.0,
#    25.5,
#    26.0,
#    26.5,
#    27.0,
#    27.5,
#    28.0,
#    28.5,
#    29.0,
#    29.5,
#    30.0,
#    30.5,
#    31.0,
#    32.0],
#   'underlyingSymbol': 'BAC'}]

# %%
result = results[0]
dates = [dt.fromtimestamp(tm) for tm in result['expirationDates']]
# we can use these dates to get data for a specific expiration date
# an example url: https://query1.finance.yahoo.com/v7/finance/options/BAC?date=1484265600 
# the first date is default
dates
# Out:
# [datetime.datetime(2017, 1, 20, 2, 0),
#  datetime.datetime(2017, 1, 27, 2, 0),
#  datetime.datetime(2017, 2, 3, 2, 0),
#  datetime.datetime(2017, 2, 10, 2, 0),
#  datetime.datetime(2017, 2, 17, 2, 0),
#  datetime.datetime(2017, 2, 24, 2, 0),
#  datetime.datetime(2017, 3, 3, 2, 0),
#  datetime.datetime(2017, 3, 17, 2, 0),
#  datetime.datetime(2017, 4, 21, 3, 0),
#  datetime.datetime(2017, 5, 19, 3, 0),
#  datetime.datetime(2017, 6, 16, 3, 0),
#  datetime.datetime(2017, 8, 18, 3, 0),
#  datetime.datetime(2017, 12, 15, 2, 0),
#  datetime.datetime(2018, 1, 19, 2, 0),
#  datetime.datetime(2019, 1, 18, 2, 0)]

# %%
option = result['options'][0]
calls = option['calls']
calls[:2]
# Out:
# [{'ask': 18.1,
#   'bid': 17.0,
#   'change': -0.17000008,
#   'contractSize': 'REGULAR',
#   'contractSymbol': 'BAC170120C00005000',
#   'currency': 'USD',
#   'expiration': 1484870400,
#   'impliedVolatility': 15.59375025390625,
#   'inTheMoney': True,
#   'lastPrice': 17.86,
#   'lastTradeDate': 1484334975,
#   'openInterest': 265,
#   'percentChange': -0.9428734,
#   'strike': 5.0,
#   'volume': 15},
#  {'ask': 10.85,
#   'bid': 10.3,
#   'change': 0.0,
#   'contractSize': 'REGULAR',
#   'contractSymbol': 'BAC170120C00006000',
#   'currency': 'USD',
#   'expiration': 1484870400,
#   'impliedVolatility': 1.0000000000000003e-05,
#   'inTheMoney': True,
#   'lastPrice': 10.4,
#   'lastTradeDate': 1476885202,
#   'openInterest': 2,
#   'percentChange': 0.0,
#   'strike': 6.0,
#   'volume': 2}]

# %%
puts = option['puts']
puts[-2:]
# Out:
# [{'ask': 8.9,
#   'bid': 8.8,
#   'change': 0.0,
#   'contractSize': 'REGULAR',
#   'contractSymbol': 'BAC170120P00031000',
#   'currency': 'USD',
#   'expiration': 1484870400,
#   'impliedVolatility': 3.7343756640625,
#   'inTheMoney': True,
#   'lastPrice': 9.05,
#   'lastTradeDate': 1483040040,
#   'openInterest': 293,
#   'percentChange': 0.0,
#   'strike': 31.0,
#   'volume': 170},
#  {'ask': 9.45,
#   'bid': 9.35,
#   'change': 0.0,
#   'contractSize': 'REGULAR',
#   'contractSymbol': 'BAC170120P00032000',
#   'currency': 'USD',
#   'expiration': 1484870400,
#   'impliedVolatility': 1.9375003125,
#   'inTheMoney': True,
#   'lastPrice': 9.68,
#   'lastTradeDate': 1484674693,
#   'openInterest': 83,
#   'percentChange': 0.0,
#   'strike': 32.0,
#   'volume': 18}]

# %% [markdown]
# # Implementation

# %%
# There is a lot of data to load every minute, so we have to do this in parrallel
# 'threading' module fits well for this purpose
# I'm going to use two queues to connect our main programm and thread workers: 
# the first is for tasks, the other - for results
# You can find some examples of using 'queue'-module here
# https://docs.python.org/3/library/queue.html#queue.Queue.join
import queue
import requests
import threading


def load_data(time):
    
    num_worker_threads = 10
    
    def worker():
        while True:
            args = q.get()
            if args is None:
                break
            get_transactions(q, r, *args)  # <-- see definition of this function below
            q.task_done()

    q = queue.Queue() # queue with arguments for the 'get_transactions' function
    r = queue.Queue() # queue with raw responses

    threads = []
    for i in range(num_worker_threads):
        t = threading.Thread(target=worker)
        t.start()
        threads.append(t)

    for stock in STOCKS:
        q.put((stock, None))

    # block until all tasks are done
    q.join()

    # stop workers
    for i in range(num_worker_threads):
        q.put(None)

    for t in threads:
        t.join()
        
    save_rows(r, time)
    
    
def get_transactions(queue, resp_queue, stock, date=None):     
    base_url = "https://query1.finance.yahoo.com/v7/finance/options/{}".format(stock)
    if date is not None:
        url = "{}?date={}".format(base_url, date)
    else:
        url = base_url
    try:
        page = requests.get(url)
    except Exception as e:
        print(e)
    else:
        response = page.json()
        if response['optionChain']['error']: # if any error
            print(response['optionChain']['error'])

        else:
            results = response['optionChain']['result']
            for result in results:
                price = result['quote']['regularMarketPrice']
                for option in result['options']:
                    resp_queue.put(
                        (stock, price, option['calls'], option['puts'])
                    )

                if date is None:
                    for tm in result['expirationDates'][1:]:
                        queue.put((stock, tm))

# %%
# Functions which take response from the response queue and put to the 'largest_transactions' list
def save_rows(q, time):
    global largest_transactions
    while True:
        try:
            stock, price, calls, puts = q.get(block=False)
        except queue.Empty:
            break
        else:
            for call in calls:
                save_row(stock, price, 'Calls', time, call)
            for put in puts:
                save_row(stock, price, 'Puts', time, put)

def save_row(s, price, t, time, raw):
    contact = raw['contractSymbol']    
    previous_volume = transaction_volumes.get(contact)
    volume = raw['volume']
    transaction_volumes[contact] = volume
    
    if previous_volume is not None:        
        volume_diff = volume - previous_volume
        if volume_diff > 0:
            last_price = raw['lastPrice']
            strike = raw['strike']
            ask = raw['ask']
            bid = raw['bid']
            largest_transactions.append(
                dict(
                    stock=s,
                    price=price,
                    type=t,
                    time=time,
                    expiration=dt.fromtimestamp(raw['expiration']),
                    strike=strike,
                    contact=contact,
                    last_price=last_price,
                    bid=bid,
                    ask=ask,
                    volume=volume,
                    open_interest=raw['openInterest'],
                    implied_volatility=raw['impliedVolatility'],
                    volume_diff=volume_diff,
                    cost=volume_diff * last_price,
                    strike_div_price=(strike / price - 1) * 100,
                    last_price_position=(1 - (ask-last_price) / (ask-bid)) * 100 if ask != bid else None
                )
            )

# %%
# This function will display the table
from IPython.display import clear_output, display, HTML

headers = (
    "Stock", "Share price", "Options", "Volume", "Strike", "Strike /Share price", 
    "Expiration", "Last price", "Bid", "Ask", "Last price position",  "Value", "Time of trade",
)
row = """
<td>{stock}</td><td>{price}</td><td>{type}</td><td>{volume_diff}</td>
<td>{strike}</td><td>{strike_div_price:.2f}%</td><td>{expiration:%b %d, %Y}</td>
<td>{last_price}</td><td>{bid}</td><td>{ask}</td><td>{last_price_position:.0f}%</td>
<td>${cost:,.2f}</td><td>{time:%I:%M%p}</td>
"""

def display_data():    
    table_rows = (row.format(**row_data) for row_data in largest_transactions)           
    clear_output()
    display(
        HTML(
            '<table><tr><th>{}</th></tr><tr>{}</tr></table>'.format(
                "</th><th>".join(headers),
                "</tr><tr>".join(table_rows)
            )
        )
    )

# %%
from datetime import datetime as dt, timedelta as td
from pytz import timezone
from time import sleep
import heapq

tz = timezone('America/Los_Angeles')  # timezone produces time with PST or PDT tzname depending on the date
STOCKS = ['AAPL', 'BAC', 'NVDA', 'AMZN', 'FB']

last_time = None
count = 1
largest_transactions = []  # here we will store top entries
transaction_volumes = {}  # latest volumes for transactions

while True:    
    now = dt.now(tz=tz)
    start = now.replace(hour=6, minute=30, second=0, microsecond=0)
    stop = start.replace(hour=13, minute=0)
    
    if start <= now <= stop: # proper time for getting data
        
        if last_time: # no more often than once per minute
            diff = 60 - (now - last_time).seconds            
            if diff > 0:
                sleep(diff)  
        
        # the main functionality
        load_data(now)
        # it's efficient way to keep only top 20 entries in the 'largest_transactions' list
        largest_transactions = heapq.nlargest(20, largest_transactions, key=lambda i: i['cost']) 
        display_data()
        
        # some statistics
        print("last update", now)
        print("prev update", last_time) 
        print("update time", dt.now(tz=tz) - now)
        print("iterations", count)
        count += 1
        
        last_time = now        
    else:
        largest_transactions = [] # drop transactions
        if now < start:
            diff = start - now
            print("time to start:", diff)
            
        else:
            start_tommorow = start + td(days=1)
            print("start tommorow at", start_tommorow)
            diff = start_tommorow - now
        
        sleep(diff.seconds + diff.microseconds * 0.1 ** 6)
# Out:
# <table><tr><th>Stock</th><th>Share price</th><th>Options</th><th>Volume</th><th>Strike</th><th>Strike /Share price</th><th>Expiration</th><th>Last price</th><th>Bid</th><th>Ask</th><th>Last price position</th><th>Value</th><th>Time of trade</th></tr><tr>
# <td>AAPL</td><td>119.83</td><td>Calls</td><td>1369</td>
# <td>100.0</td><td>-16.55%</td><td>Jan 20, 2017</td>
# <td>19.84</td><td>19.8</td><td>19.9</td><td>40%</td>
# <td>$27,160.96</td><td>11:19AM</td>
# </tr><tr>
# <td>AAPL</td><td>119.83</td><td>Calls</td><td>88</td>
# <td>50.0</td><td>-58.27%</td><td>Jan 20, 2017</td>
# <td>69.76</td><td>69.75</td><td>69.9</td><td>7%</td>
# <td>$6,138.88</td><td>11:18AM</td>
# </tr><tr>
# <td>AAPL</td><td>119.83</td><td>Calls</td><td>88</td>
# <td>50.0</td><td>-58.27%</td><td>Jan 19, 2018</td>
# <td>69.76</td><td>69.6</td><td>70.0</td><td>40%</td>
# <td>$6,138.88</td><td>11:18AM</td>
# </tr><tr>
# <td>AAPL</td><td>119.84</td><td>Calls</td><td>236</td>
# <td>100.0</td><td>-16.56%</td><td>Jan 20, 2017</td>
# <td>19.8</td><td>19.8</td><td>19.85</td><td>0%</td>
# <td>$4,672.80</td><td>11:13AM</td>
# </tr><tr>
# <td>AAPL</td><td>119.855</td><td>Puts</td><td>1000</td>
# <td>97.5</td><td>-18.65%</td><td>Jan 19, 2018</td>
# <td>3.72</td><td>3.7</td><td>3.75</td><td>40%</td>
# <td>$3,720.00</td><td>11:16AM</td>
# </tr><tr>
# <td>AAPL</td><td>119.81</td><td>Calls</td><td>597</td>
# <td>115.0</td><td>-4.01%</td><td>Jan 20, 2017</td>
# <td>4.82</td><td>4.8</td><td>4.85</td><td>40%</td>
# <td>$2,877.54</td><td>11:14AM</td>
# </tr><tr>
# <td>AAPL</td><td>119.81</td><td>Calls</td><td>110</td>
# <td>97.5</td><td>-18.62%</td><td>Jan 20, 2017</td>
# <td>22.34</td><td>22.25</td><td>22.5</td><td>36%</td>
# <td>$2,457.40</td><td>11:14AM</td>
# </tr><tr>
# <td>AAPL</td><td>119.84</td><td>Calls</td><td>510</td>
# <td>135.0</td><td>12.65%</td><td>Jan 19, 2018</td>
# <td>4.78</td><td>4.7</td><td>4.8</td><td>80%</td>
# <td>$2,437.80</td><td>11:13AM</td>
# </tr><tr>
# <td>FB</td><td>127.1399</td><td>Puts</td><td>650</td>
# <td>115.0</td><td>-9.55%</td><td>Jun 16, 2017</td>
# <td>3.6</td><td>3.5</td><td>3.6</td><td>100%</td>
# <td>$2,340.00</td><td>11:17AM</td>
# </tr><tr>
# <td>AAPL</td><td>119.84</td><td>Puts</td><td>1000</td>
# <td>87.5</td><td>-26.99%</td><td>Jan 19, 2018</td>
# <td>2.11</td><td>2.1</td><td>2.12</td><td>50%</td>
# <td>$2,110.00</td><td>11:13AM</td>
# </tr><tr>
# <td>FB</td><td>127.1067</td><td>Calls</td><td>155</td>
# <td>120.0</td><td>-5.59%</td><td>Jun 16, 2017</td>
# <td>12.73</td><td>12.7</td><td>12.8</td><td>30%</td>
# <td>$1,973.15</td><td>11:18AM</td>
# </tr><tr>
# <td>FB</td><td>127.1067</td><td>Calls</td><td>110</td>
# <td>115.0</td><td>-9.52%</td><td>Jun 16, 2017</td>
# <td>16.3</td><td>16.15</td><td>16.3</td><td>100%</td>
# <td>$1,793.00</td><td>11:18AM</td>
# </tr><tr>
# <td>FB</td><td>127.0922</td><td>Calls</td><td>245</td>
# <td>120.0</td><td>-5.58%</td><td>Jan 27, 2017</td>
# <td>7.25</td><td>7.25</td><td>7.3</td><td>0%</td>
# <td>$1,776.25</td><td>11:18AM</td>
# </tr><tr>
# <td>AAPL</td><td>119.8199</td><td>Calls</td><td>252</td>
# <td>115.0</td><td>-4.02%</td><td>Mar 17, 2017</td>
# <td>6.31</td><td>6.3</td><td>6.35</td><td>20%</td>
# <td>$1,590.12</td><td>11:14AM</td>
# </tr><tr>
# <td>FB</td><td>127.15</td><td>Calls</td><td>200</td>
# <td>130.0</td><td>2.24%</td><td>Jun 16, 2017</td>
# <td>7.15</td><td>7.05</td><td>7.15</td><td>100%</td>
# <td>$1,430.00</td><td>11:15AM</td>
# </tr><tr>
# <td>AAPL</td><td>119.88</td><td>Calls</td><td>335</td>
# <td>116.0</td><td>-3.24%</td><td>Jan 27, 2017</td>
# <td>3.98</td><td>3.95</td><td>4.0</td><td>60%</td>
# <td>$1,333.30</td><td>11:16AM</td>
# </tr><tr>
# <td>FB</td><td>127.1067</td><td>Calls</td><td>210</td>
# <td>125.0</td><td>-1.66%</td><td>Mar 17, 2017</td>
# <td>6.3</td><td>6.25</td><td>6.35</td><td>50%</td>
# <td>$1,323.00</td><td>11:18AM</td>
# </tr><tr>
# <td>AAPL</td><td>119.8199</td><td>Puts</td><td>59</td>
# <td>135.0</td><td>12.67%</td><td>Jan 19, 2018</td>
# <td>20.6</td><td>20.55</td><td>20.65</td><td>50%</td>
# <td>$1,215.40</td><td>11:14AM</td>
# </tr><tr>
# <td>NVDA</td><td>103.43</td><td>Calls</td><td>50</td>
# <td>80.0</td><td>-22.65%</td><td>Jan 20, 2017</td>
# <td>23.5</td><td>23.4</td><td>23.5</td><td>100%</td>
# <td>$1,175.00</td><td>11:19AM</td>
# </tr><tr>
# <td>FB</td><td>127.11</td><td>Calls</td><td>155</td>
# <td>120.0</td><td>-5.59%</td><td>Jan 20, 2017</td>
# <td>7.13</td><td>7.1</td><td>7.15</td><td>60%</td>
# <td>$1,105.15</td><td>11:14AM</td>
# </tr></table>
# last update 2017-01-20 11:19:49.576159-08:00
# prev update 2017-01-20 11:19:20.379109-08:00
# update time 0:00:38.722644
# iterations 17
