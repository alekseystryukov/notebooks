# %%
from datetime import datetime as dt, timedelta as td
import requests

# %%
url = "https://query1.finance.yahoo.com/v7/finance/options/BAC"
#?formatted=true&crumb=bCkXlpLUQ.w&lang=en-US&region=US&date=1484265600&corsDomain=finance.yahoo.com

# %%
page = requests.get(url)
response = page.json()
if response['optionChain']['error']:
    print(response['optionChain']['error'])

results = response['optionChain']['result']
results
# Out:
# [{'expirationDates': [1484870400,
#    1485475200,
#    1486080000,
#    1486684800,
#    1487289600,
#    1487894400,
#    1488499200,
#    1489708800,
#    1492732800,
#    1495152000,
#    1497571200,
#    1503014400,
#    1513296000,
#    1516320000,
#    1547769600],
#   'hasMiniOptions': False,
#   'options': [{'calls': [{'ask': 18.1,
#       'bid': 17.0,
#       'change': -0.17000008,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00005000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 10.343753535156253,
#       'inTheMoney': True,
#       'lastPrice': 17.86,
#       'lastTradeDate': 1484334975,
#       'openInterest': 265,
#       'percentChange': -0.9428734,
#       'strike': 5.0,
#       'volume': 15},
#      {'ask': 10.85,
#       'bid': 10.3,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00006000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 10.4,
#       'lastTradeDate': 1476885202,
#       'openInterest': 2,
#       'percentChange': 0.0,
#       'strike': 6.0,
#       'volume': 2},
#      {'ask': 14.3,
#       'bid': 13.95,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00007000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 13.35,
#       'lastTradeDate': 1480449162,
#       'openInterest': 63,
#       'percentChange': 0.0,
#       'strike': 7.0,
#       'volume': 140},
#      {'ask': 14.4,
#       'bid': 14.15,
#       'change': 0.21000004,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00008000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 5.7812527734375,
#       'inTheMoney': True,
#       'lastPrice': 14.51,
#       'lastTradeDate': 1484752568,
#       'openInterest': 2434,
#       'percentChange': 1.4685317,
#       'strike': 8.0,
#       'volume': 120},
#      {'ask': 13.55,
#       'bid': 13.15,
#       'change': -0.32000065,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00009000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 4.12500484375,
#       'inTheMoney': True,
#       'lastPrice': 13.28,
#       'lastTradeDate': 1484750915,
#       'openInterest': 187,
#       'percentChange': -2.3529458,
#       'strike': 9.0,
#       'volume': 40},
#      {'ask': 12.3,
#       'bid': 12.15,
#       'change': 0.25,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00010000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 12.32,
#       'lastTradeDate': 1484759165,
#       'openInterest': 10749,
#       'percentChange': 2.0712512,
#       'strike': 10.0,
#       'volume': 115},
#      {'ask': 12.15,
#       'bid': 11.2,
#       'change': 0.54999924,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00011000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 5.835940205078126,
#       'inTheMoney': True,
#       'lastPrice': 12.15,
#       'lastTradeDate': 1484321265,
#       'openInterest': 570,
#       'percentChange': 4.7413726,
#       'strike': 11.0,
#       'volume': 30},
#      {'ask': 10.45,
#       'bid': 10.15,
#       'change': -0.30999947,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00012000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 4.0781299023437505,
#       'inTheMoney': True,
#       'lastPrice': 10.47,
#       'lastTradeDate': 1484751464,
#       'openInterest': 494,
#       'percentChange': -2.875691,
#       'strike': 12.0,
#       'volume': 202},
#      {'ask': 9.3,
#       'bid': 9.2,
#       'change': 0.13000011,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00013000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 9.22,
#       'lastTradeDate': 1484760955,
#       'openInterest': 23406,
#       'percentChange': 1.4301443,
#       'strike': 13.0,
#       'volume': 426},
#      {'ask': 8.35,
#       'bid': 8.15,
#       'change': -0.65999985,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00014000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.2500043749999996,
#       'inTheMoney': True,
#       'lastPrice': 8.39,
#       'lastTradeDate': 1484754471,
#       'openInterest': 3308,
#       'percentChange': -7.292816,
#       'strike': 14.0,
#       'volume': 20},
#      {'ask': 7.7,
#       'bid': 7.55,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00014500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 7.45,
#       'lastTradeDate': 1483038300,
#       'openInterest': 31,
#       'percentChange': 0.0,
#       'strike': 14.5,
#       'volume': 32},
#      {'ask': 7.3,
#       'bid': 7.2,
#       'change': 0.21000004,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00015000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 7.25,
#       'lastTradeDate': 1484759902,
#       'openInterest': 64611,
#       'percentChange': 2.982955,
#       'strike': 15.0,
#       'volume': 3009},
#      {'ask': 7.55,
#       'bid': 7.45,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00015500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 4.2812546484375,
#       'inTheMoney': True,
#       'lastPrice': 7.5,
#       'lastTradeDate': 1484166763,
#       'openInterest': 144,
#       'percentChange': 0.0,
#       'strike': 15.5,
#       'volume': 13},
#      {'ask': 6.3,
#       'bid': 6.15,
#       'change': 0.21000004,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00016000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 6.3,
#       'lastTradeDate': 1484759067,
#       'openInterest': 57696,
#       'percentChange': 3.4482763,
#       'strike': 16.0,
#       'volume': 138},
#      {'ask': 6.55,
#       'bid': 6.45,
#       'change': 0.14999962,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00016500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 3.7578131054687502,
#       'inTheMoney': True,
#       'lastPrice': 6.45,
#       'lastTradeDate': 1484333383,
#       'openInterest': 160,
#       'percentChange': 2.3809462,
#       'strike': 16.5,
#       'volume': 27},
#      {'ask': 5.3,
#       'bid': 5.2,
#       'change': 0.21000004,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00017000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 5.25,
#       'lastTradeDate': 1484761082,
#       'openInterest': 301770,
#       'percentChange': 4.1666675,
#       'strike': 17.0,
#       'volume': 7053},
#      {'ask': 5.55,
#       'bid': 5.45,
#       'change': 0.25,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00017500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 3.253908115234375,
#       'inTheMoney': True,
#       'lastPrice': 5.6,
#       'lastTradeDate': 1484326813,
#       'openInterest': 107,
#       'percentChange': 4.6728973,
#       'strike': 17.5,
#       'volume': 119},
#      {'ask': 4.3,
#       'bid': 4.25,
#       'change': 0.13000011,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00018000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 4.19,
#       'lastTradeDate': 1484760821,
#       'openInterest': 115986,
#       'percentChange': 3.2019734,
#       'strike': 18.0,
#       'volume': 889},
#      {'ask': 3.8,
#       'bid': 3.7,
#       'change': -0.25,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00018500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 3.75,
#       'lastTradeDate': 1484760500,
#       'openInterest': 200,
#       'percentChange': -6.25,
#       'strike': 18.5,
#       'volume': 14},
#      {'ask': 3.3,
#       'bid': 3.2,
#       'change': 0.23000002,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00019000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 3.27,
#       'lastTradeDate': 1484759773,
#       'openInterest': 223342,
#       'percentChange': 7.56579,
#       'strike': 19.0,
#       'volume': 442},
#      {'ask': 2.76,
#       'bid': 2.75,
#       'change': 0.4000001,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00019500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 2.93,
#       'lastTradeDate': 1484754285,
#       'openInterest': 1241,
#       'percentChange': 15.810281,
#       'strike': 19.5,
#       'volume': 82},
#      {'ask': 2.26,
#       'bid': 2.24,
#       'change': 0.19000006,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00020000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 2.24,
#       'lastTradeDate': 1484761220,
#       'openInterest': 174072,
#       'percentChange': 9.268295,
#       'strike': 20.0,
#       'volume': 9644},
#      {'ask': 1.76,
#       'bid': 1.75,
#       'change': 0.14999998,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00020500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 1.75,
#       'lastTradeDate': 1484760500,
#       'openInterest': 2358,
#       'percentChange': 9.374998,
#       'strike': 20.5,
#       'volume': 287},
#      {'ask': 1.26,
#       'bid': 1.25,
#       'change': 0.19999993,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00021000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 1.27,
#       'lastTradeDate': 1484761082,
#       'openInterest': 92748,
#       'percentChange': 18.691582,
#       'strike': 21.0,
#       'volume': 2460},
#      {'ask': 0.79,
#       'bid': 0.78,
#       'change': 0.19,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00021500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 0.85,
#       'lastTradeDate': 1484758746,
#       'openInterest': 6552,
#       'percentChange': 28.787878,
#       'strike': 21.5,
#       'volume': 1899},
#      {'ask': 0.37,
#       'bid': 0.35,
#       'change': 0.030000001,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00022000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.179695703125,
#       'inTheMoney': True,
#       'lastPrice': 0.36,
#       'lastTradeDate': 1484761263,
#       'openInterest': 243048,
#       'percentChange': 9.090909,
#       'strike': 22.0,
#       'volume': 20672},
#      {'ask': 0.12,
#       'bid': 0.11,
#       'change': -0.009999998,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00022500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.23438265625,
#       'inTheMoney': False,
#       'lastPrice': 0.1,
#       'lastTradeDate': 1484761264,
#       'openInterest': 29366,
#       'percentChange': -9.090907,
#       'strike': 22.5,
#       'volume': 18139},
#      {'ask': 0.03,
#       'bid': 0.02,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00023000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.26563234375,
#       'inTheMoney': False,
#       'lastPrice': 0.03,
#       'lastTradeDate': 1484761313,
#       'openInterest': 182526,
#       'percentChange': -25.0,
#       'strike': 23.0,
#       'volume': 36725},
#      {'ask': 0.02,
#       'bid': 0.01,
#       'change': 0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00023500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.35938140625,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1484761121,
#       'openInterest': 32607,
#       'percentChange': 100.0,
#       'strike': 23.5,
#       'volume': 706},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00024000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.42188078125,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484760781,
#       'openInterest': 88168,
#       'percentChange': 0.0,
#       'strike': 24.0,
#       'volume': 615},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': -0.07,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00024500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.51562984375,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484340149,
#       'openInterest': 15005,
#       'percentChange': -87.5,
#       'strike': 24.5,
#       'volume': 23072},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.03,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00025000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.5625043750000001,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484340447,
#       'openInterest': 133741,
#       'percentChange': -75.0,
#       'strike': 25.0,
#       'volume': 3059},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.02,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00025500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.6250037500000001,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484323358,
#       'openInterest': 35301,
#       'percentChange': -66.66667,
#       'strike': 25.5,
#       'volume': 268},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00026000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.7187528125,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484318201,
#       'openInterest': 29812,
#       'percentChange': -50.0,
#       'strike': 26.0,
#       'volume': 2},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00026500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.87500125,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1483563510,
#       'openInterest': 647,
#       'percentChange': 0.0,
#       'strike': 26.5,
#       'volume': 14},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00027000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.87500125,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483730925,
#       'openInterest': 22851,
#       'percentChange': -50.0,
#       'strike': 27.0,
#       'volume': 446},
#      {'ask': 0.02,
#       'bid': 0.01,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00027500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.09375453125,
#       'inTheMoney': False,
#       'lastPrice': 0.03,
#       'lastTradeDate': 1482262814,
#       'openInterest': 211,
#       'percentChange': 0.0,
#       'strike': 27.5,
#       'volume': 105},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00028000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.09375453125,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483114158,
#       'openInterest': 3803,
#       'percentChange': -50.0,
#       'strike': 28.0,
#       'volume': 10},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00029000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.2500037499999999,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1482338643,
#       'openInterest': 1755,
#       'percentChange': 0.0,
#       'strike': 29.0,
#       'volume': 10},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00029500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.1875040625,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1482554706,
#       'openInterest': 165,
#       'percentChange': 0.0,
#       'strike': 29.5,
#       'volume': 155},
#      {'ask': 0.03,
#       'bid': 0.01,
#       'change': -0.02,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00030000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.5156274218749999,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1481902676,
#       'openInterest': 41647,
#       'percentChange': -66.66667,
#       'strike': 30.0,
#       'volume': 20},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00030500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.3125034374999998,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483159928,
#       'openInterest': 50,
#       'percentChange': 0.0,
#       'strike': 30.5,
#       'volume': 40},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00031000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.5000025,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1481950427,
#       'openInterest': 70,
#       'percentChange': 0.0,
#       'strike': 31.0,
#       'volume': 77},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00032000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.5000025,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1482849755,
#       'openInterest': 10,
#       'percentChange': 0.0,
#       'strike': 32.0,
#       'volume': 5}],
#     'expirationDate': 1484870400,
#     'hasMiniOptions': False,
#     'puts': [{'ask': 0.02,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00005000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 6.500001875000001,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1472240413,
#       'openInterest': 37092,
#       'percentChange': -50.0,
#       'strike': 5.0,
#       'volume': 200},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00006000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 5.7500028125,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1471536077,
#       'openInterest': 3686,
#       'percentChange': 0.0,
#       'strike': 6.0,
#       'volume': 100},
#      {'ask': 0.02,
#       'bid': 0.01,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00007000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 5.250003437499999,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1473185890,
#       'openInterest': 2538,
#       'percentChange': 0.0,
#       'strike': 7.0,
#       'volume': 100},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00008000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 4.12500484375,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1476714104,
#       'openInterest': 41423,
#       'percentChange': 0.0,
#       'strike': 8.0,
#       'volume': 20},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00009000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 4.000005,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1478619748,
#       'openInterest': 11490,
#       'percentChange': -50.0,
#       'strike': 9.0,
#       'volume': 1},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00010000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 3.2500018749999997,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1478890672,
#       'openInterest': 110039,
#       'percentChange': 0.0,
#       'strike': 10.0,
#       'volume': 209},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00011000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 3.1875020312499998,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1479329456,
#       'openInterest': 23258,
#       'percentChange': 0.0,
#       'strike': 11.0,
#       'volume': 164},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.02,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00012000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.6250034375,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1479501105,
#       'openInterest': 36055,
#       'percentChange': -66.66667,
#       'strike': 12.0,
#       'volume': 55},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00013000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.2500043749999996,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1482524762,
#       'openInterest': 280696,
#       'percentChange': 0.0,
#       'strike': 13.0,
#       'volume': 11},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00014000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.96875015625,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483036985,
#       'openInterest': 53475,
#       'percentChange': 0.0,
#       'strike': 14.0,
#       'volume': 15},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00015000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.75000125,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483634806,
#       'openInterest': 273307,
#       'percentChange': 0.0,
#       'strike': 15.0,
#       'volume': 40},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00016000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.5000025,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484160718,
#       'openInterest': 35022,
#       'percentChange': 0.0,
#       'strike': 16.0,
#       'volume': 10},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00016500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.3750031249999999,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483764258,
#       'openInterest': 171,
#       'percentChange': 0.0,
#       'strike': 16.5,
#       'volume': 171},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00017000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.2500037499999999,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1484757848,
#       'openInterest': 244981,
#       'percentChange': 100.0,
#       'strike': 17.0,
#       'volume': 1},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00017500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.21875390625,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483042332,
#       'openInterest': 8234,
#       'percentChange': 0.0,
#       'strike': 17.5,
#       'volume': 140},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00018000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.9687503125,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483731773,
#       'openInterest': 36798,
#       'percentChange': 0.0,
#       'strike': 18.0,
#       'volume': 110},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00018500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.9687503125,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483559058,
#       'openInterest': 882,
#       'percentChange': 0.0,
#       'strike': 18.5,
#       'volume': 75},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00019000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.7500025,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484328548,
#       'openInterest': 43266,
#       'percentChange': -50.0,
#       'strike': 19.0,
#       'volume': 1615},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00019500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.6562534375000001,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1484243723,
#       'openInterest': 919,
#       'percentChange': 0.0,
#       'strike': 19.5,
#       'volume': 2},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00020000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.5625043750000001,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484759603,
#       'openInterest': 136086,
#       'percentChange': 0.0,
#       'strike': 20.0,
#       'volume': 10},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00020500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.500005,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484751058,
#       'openInterest': 4802,
#       'percentChange': 0.0,
#       'strike': 20.5,
#       'volume': 40},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00021000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.37500625,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1484759699,
#       'openInterest': 59560,
#       'percentChange': -33.333336,
#       'strike': 21.0,
#       'volume': 419},
#      {'ask': 0.03,
#       'bid': 0.02,
#       'change': -0.049999997,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00021500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.32813171874999997,
#       'inTheMoney': False,
#       'lastPrice': 0.03,
#       'lastTradeDate': 1484759612,
#       'openInterest': 14091,
#       'percentChange': -62.5,
#       'strike': 21.5,
#       'volume': 3177},
#      {'ask': 0.11,
#       'bid': 0.1,
#       'change': -0.15,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00022000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.3007882421875,
#       'inTheMoney': False,
#       'lastPrice': 0.1,
#       'lastTradeDate': 1484761264,
#       'openInterest': 187613,
#       'percentChange': -60.000004,
#       'strike': 22.0,
#       'volume': 10442},
#      {'ask': 0.36,
#       'bid': 0.35,
#       'change': -0.16000003,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00022500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.33399103515625,
#       'inTheMoney': True,
#       'lastPrice': 0.39,
#       'lastTradeDate': 1484760873,
#       'openInterest': 55140,
#       'percentChange': -29.090914,
#       'strike': 22.5,
#       'volume': 5546},
#      {'ask': 0.75,
#       'bid': 0.74,
#       'change': -0.22000003,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00023000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.3789124609375,
#       'inTheMoney': True,
#       'lastPrice': 0.76,
#       'lastTradeDate': 1484761284,
#       'openInterest': 55424,
#       'percentChange': -22.448982,
#       'strike': 23.0,
#       'volume': 1626},
#      {'ask': 1.25,
#       'bid': 1.23,
#       'change': -0.22000003,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00023500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.51562984375,
#       'inTheMoney': True,
#       'lastPrice': 1.26,
#       'lastTradeDate': 1484760500,
#       'openInterest': 3050,
#       'percentChange': -14.864866,
#       'strike': 23.5,
#       'volume': 253},
#      {'ask': 2.25,
#       'bid': 2.24,
#       'change': -0.18000007,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00024500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.79687703125,
#       'inTheMoney': True,
#       'lastPrice': 2.25,
#       'lastTradeDate': 1484760500,
#       'openInterest': 1153,
#       'percentChange': -7.4074097,
#       'strike': 24.5,
#       'volume': 250},
#      {'ask': 2.75,
#       'bid': 2.74,
#       'change': -0.17000008,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00025000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.92187578125,
#       'inTheMoney': True,
#       'lastPrice': 2.8,
#       'lastTradeDate': 1484760781,
#       'openInterest': 17892,
#       'percentChange': -5.723908,
#       'strike': 25.0,
#       'volume': 84},
#      {'ask': 3.25,
#       'bid': 3.2,
#       'change': 0.120000124,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00025500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.9687503125,
#       'inTheMoney': True,
#       'lastPrice': 3.22,
#       'lastTradeDate': 1484760199,
#       'openInterest': 209,
#       'percentChange': 3.870972,
#       'strike': 25.5,
#       'volume': 104},
#      {'ask': 3.75,
#       'bid': 3.7,
#       'change': 0.029999971,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00026000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0781296093750001,
#       'inTheMoney': True,
#       'lastPrice': 3.72,
#       'lastTradeDate': 1484760199,
#       'openInterest': 604,
#       'percentChange': 0.81300735,
#       'strike': 26.0,
#       'volume': 4},
#      {'ask': 3.55,
#       'bid': 3.45,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00026500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 3.65,
#       'lastTradeDate': 1484246729,
#       'openInterest': 39,
#       'percentChange': 0.0,
#       'strike': 26.5,
#       'volume': 5},
#      {'ask': 4.05,
#       'bid': 3.95,
#       'change': -0.25,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00027000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 3.9,
#       'lastTradeDate': 1484322511,
#       'openInterest': 603,
#       'percentChange': -6.024096,
#       'strike': 27.0,
#       'volume': 1},
#      {'ask': 4.55,
#       'bid': 4.45,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00027500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 4.55,
#       'lastTradeDate': 1484074867,
#       'openInterest': 11,
#       'percentChange': 0.0,
#       'strike': 27.5,
#       'volume': 10},
#      {'ask': 5.05,
#       'bid': 4.95,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00028000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 5.0,
#       'lastTradeDate': 1484068828,
#       'openInterest': 180,
#       'percentChange': 0.0,
#       'strike': 28.0,
#       'volume': 10},
#      {'ask': 5.85,
#       'bid': 5.75,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00028500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 5.8,
#       'lastTradeDate': 1483545990,
#       'openInterest': 23,
#       'percentChange': 0.0,
#       'strike': 28.5,
#       'volume': 22},
#      {'ask': 6.35,
#       'bid': 6.25,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00029000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 6.16,
#       'lastTradeDate': 1483626950,
#       'openInterest': 122,
#       'percentChange': 0.0,
#       'strike': 29.0,
#       'volume': 7},
#      {'ask': 7.4,
#       'bid': 7.3,
#       'change': 0.25,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00029500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.1914107714843745,
#       'inTheMoney': True,
#       'lastPrice': 7.45,
#       'lastTradeDate': 1483108656,
#       'openInterest': 71,
#       'percentChange': 3.4722223,
#       'strike': 29.5,
#       'volume': 16},
#      {'ask': 7.95,
#       'bid': 7.35,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00030000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.550784873046875,
#       'inTheMoney': True,
#       'lastPrice': 7.92,
#       'lastTradeDate': 1484683974,
#       'openInterest': 566,
#       'percentChange': 0.0,
#       'strike': 30.0,
#       'volume': 2},
#      {'ask': 8.9,
#       'bid': 8.8,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00031000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.468753828125,
#       'inTheMoney': True,
#       'lastPrice': 9.05,
#       'lastTradeDate': 1483040040,
#       'openInterest': 293,
#       'percentChange': 0.0,
#       'strike': 31.0,
#       'volume': 170},
#      {'ask': 9.8,
#       'bid': 9.7,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00032000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.2578168554687497,
#       'inTheMoney': True,
#       'lastPrice': 9.68,
#       'lastTradeDate': 1484674693,
#       'openInterest': 83,
#       'percentChange': 0.0,
#       'strike': 32.0,
#       'volume': 18}]}],
#   'quote': {'ask': 0.0,
#    'askSize': 0,
#    'averageDailyVolume10Day': 117278216,
#    'averageDailyVolume3Month': 119229109,
#    'bid': 0.0,
#    'bidSize': 0,
#    'bookValue': 24.187,
#    'currency': 'USD',
#    'dividendDate': 1483056000,
#    'earningsTimestamp': 1484332200,
#    'earningsTimestampEnd': 1492446600,
#    'earningsTimestampStart': 1492014600,
#    'epsForward': 1.62,
#    'epsTrailingTwelveMonths': 1.367,
#    'exchange': 'NYQ',
#    'exchangeTimezoneName': 'America/New_York',
#    'exchangeTimezoneShortName': 'EST',
#    'fiftyDayAverage': 22.419394,
#    'fiftyDayAverageChange': -0.083192825,
#    'fiftyDayAverageChangePercent': -0.0037107528,
#    'fiftyTwoWeekHigh': 23.41,
#    'fiftyTwoWeekHighChange': -1.0737991,
#    'fiftyTwoWeekHighChangePercent': -0.04586925,
#    'fiftyTwoWeekLow': 10.99,
#    'fiftyTwoWeekLowChange': 11.346201,
#    'fiftyTwoWeekLowChangePercent': 1.0324113,
#    'forwardPE': 13.787778,
#    'fullExchangeName': 'NYSE',
#    'gmtOffSetMilliseconds': -18000000,
#    'longName': 'Bank of America Corporation',
#    'market': 'us_market',
#    'marketCap': 225707311104,
#    'marketState': 'REGULAR',
#    'messageBoardId': 'finmb_19049',
#    'priceToBook': 0.92347956,
#    'quoteSourceName': 'NYSE Real Time Price',
#    'quoteType': 'EQUITY',
#    'regularMarketChange': 0.28620148,
#    'regularMarketChangePercent': 1.2979659,
#    'regularMarketDayHigh': 22.58,
#    'regularMarketDayLow': 22.1,
#    'regularMarketOpen': 22.3,
#    'regularMarketPreviousClose': 22.05,
#    'regularMarketPrice': 22.3362,
#    'regularMarketTime': 1484762339,
#    'regularMarketVolume': 79288422,
#    'sharesOutstanding': 10105000000,
#    'shortName': 'Bank of America Corporation Com',
#    'sourceInterval': 15,
#    'symbol': 'BAC',
#    'trailingAnnualDividendRate': 0.225,
#    'trailingPE': 16.339577,
#    'twoHundredDayAverage': 17.505074,
#    'twoHundredDayAverageChange': 4.831127,
#    'twoHundredDayAverageChangePercent': 0.2759844},
#   'strikes': [5.0,
#    6.0,
#    7.0,
#    8.0,
#    9.0,
#    10.0,
#    11.0,
#    12.0,
#    13.0,
#    14.0,
#    14.5,
#    15.0,
#    15.5,
#    16.0,
#    16.5,
#    17.0,
#    17.5,
#    18.0,
#    18.5,
#    19.0,
#    19.5,
#    20.0,
#    20.5,
#    21.0,
#    21.5,
#    22.0,
#    22.5,
#    23.0,
#    23.5,
#    24.0,
#    24.5,
#    25.0,
#    25.5,
#    26.0,
#    26.5,
#    27.0,
#    27.5,
#    28.0,
#    28.5,
#    29.0,
#    29.5,
#    30.0,
#    30.5,
#    31.0,
#    32.0],
#   'underlyingSymbol': 'BAC'}]

# %%
result = results[0]
dates = [dt.fromtimestamp(tm) for tm in result['expirationDates']]
# we can use these dates to get data for a specific expiration date
# an example url: https://query1.finance.yahoo.com/v7/finance/options/BAC?date=1484265600 
# the first date is default
dates
# Out:
# [datetime.datetime(2017, 1, 20, 2, 0),
#  datetime.datetime(2017, 1, 27, 2, 0),
#  datetime.datetime(2017, 2, 3, 2, 0),
#  datetime.datetime(2017, 2, 10, 2, 0),
#  datetime.datetime(2017, 2, 17, 2, 0),
#  datetime.datetime(2017, 2, 24, 2, 0),
#  datetime.datetime(2017, 3, 3, 2, 0),
#  datetime.datetime(2017, 3, 17, 2, 0),
#  datetime.datetime(2017, 4, 21, 3, 0),
#  datetime.datetime(2017, 5, 19, 3, 0),
#  datetime.datetime(2017, 6, 16, 3, 0),
#  datetime.datetime(2017, 8, 18, 3, 0),
#  datetime.datetime(2017, 12, 15, 2, 0),
#  datetime.datetime(2018, 1, 19, 2, 0),
#  datetime.datetime(2019, 1, 18, 2, 0)]

# %%
option = result['options'][0]
calls = option['calls']
calls[:2]
# Out:
# [{'ask': 18.1,
#   'bid': 17.0,
#   'change': -0.17000008,
#   'contractSize': 'REGULAR',
#   'contractSymbol': 'BAC170120C00005000',
#   'currency': 'USD',
#   'expiration': 1484870400,
#   'impliedVolatility': 10.343753535156253,
#   'inTheMoney': True,
#   'lastPrice': 17.86,
#   'lastTradeDate': 1484334975,
#   'openInterest': 265,
#   'percentChange': -0.9428734,
#   'strike': 5.0,
#   'volume': 15},
#  {'ask': 10.85,
#   'bid': 10.3,
#   'change': 0.0,
#   'contractSize': 'REGULAR',
#   'contractSymbol': 'BAC170120C00006000',
#   'currency': 'USD',
#   'expiration': 1484870400,
#   'impliedVolatility': 1.0000000000000003e-05,
#   'inTheMoney': True,
#   'lastPrice': 10.4,
#   'lastTradeDate': 1476885202,
#   'openInterest': 2,
#   'percentChange': 0.0,
#   'strike': 6.0,
#   'volume': 2}]

# %%
puts = option['puts']
puts[-2:]
# Out:
# [{'ask': 8.9,
#   'bid': 8.8,
#   'change': 0.0,
#   'contractSize': 'REGULAR',
#   'contractSymbol': 'BAC170120P00031000',
#   'currency': 'USD',
#   'expiration': 1484870400,
#   'impliedVolatility': 2.468753828125,
#   'inTheMoney': True,
#   'lastPrice': 9.05,
#   'lastTradeDate': 1483040040,
#   'openInterest': 293,
#   'percentChange': 0.0,
#   'strike': 31.0,
#   'volume': 170},
#  {'ask': 9.8,
#   'bid': 9.7,
#   'change': 0.0,
#   'contractSize': 'REGULAR',
#   'contractSymbol': 'BAC170120P00032000',
#   'currency': 'USD',
#   'expiration': 1484870400,
#   'impliedVolatility': 2.2578168554687497,
#   'inTheMoney': True,
#   'lastPrice': 9.68,
#   'lastTradeDate': 1484674693,
#   'openInterest': 83,
#   'percentChange': 0.0,
#   'strike': 32.0,
#   'volume': 18}]

# %% [markdown]
# # Implementation

# %%
# There is a lot of data to load every minute, so we have to do this in parrallel
# 'threading' module fits well for this purpose
# I'm going to use two queues to connect our main programm and thread workers: 
# the first is for tasks, the other - for results
# You can find some examples of using 'queue'-module here
# https://docs.python.org/3/library/queue.html#queue.Queue.join
import queue
import requests
import threading


def load_data(time):
    
    num_worker_threads = 10
    
    def worker():
        while True:
            args = q.get()
            if args is None:
                break
            get_transactions(q, r, *args)  # <-- see definition of this function below
            q.task_done()

    q = queue.Queue() # queue with arguments for the 'get_transactions' function
    r = queue.Queue() # queue with raw responses

    threads = []
    for i in range(num_worker_threads):
        t = threading.Thread(target=worker)
        t.start()
        threads.append(t)

    for stock in STOCKS:
        q.put((stock, None))

    # block until all tasks are done
    q.join()

    # stop workers
    for i in range(num_worker_threads):
        q.put(None)

    for t in threads:
        t.join()
        
    save_rows(r, time)
    
    
def get_transactions(queue, resp_queue, stock, date=None):     
    base_url = "https://query1.finance.yahoo.com/v7/finance/options/{}".format(stock)
    if date is not None:
        url = "{}?date={}".format(base_url, date)
    else:
        url = base_url
    try:
        page = requests.get(url)
    except Exception as e:
        print(e)
    else:
        response = page.json()
        if response['optionChain']['error']: # if any error
            print(response['optionChain']['error'])

        else:
            results = response['optionChain']['result']
            result = results[0]

            for option in result['options']:
                resp_queue.put((stock, dict(calls=option['calls'], puts=option['puts'])))

            if date is None:
                for tm in result['expirationDates'][1:]:
                    if dt.fromtimestamp(tm).date() in DATES:
                        queue.put((stock, tm))

# %%
# Functions which take response from the response queue and put to the 'largest_transactions' list
def save_rows(q, time):
    global largest_transactions
    while True:
        try:
            stock, data = q.get(block=False)
        except queue.Empty:
            break
        else:
            for call in data['calls']:
                save_row(stock, 'call', time, call)
            for put in data['puts']:
                save_row(stock, 'put', time, put)

def save_row(s, t, time, raw):
    contact = raw['contractSymbol']    
    previous_volume = transaction_volumes.get(contact)
    volume = raw['volume']
    transaction_volumes[contact] = volume
    
    if previous_volume is not None:        
        volume_diff = volume - previous_volume
        if volume_diff > 0:
            last_price = raw['lastPrice']
            largest_transactions.append(
                dict(
                    stock=s,
                    type=t,
                    time=time,
                    expiration=dt.fromtimestamp(raw['expiration']),
                    strike=raw['strike'],
                    contact=contact,
                    last_price=last_price,
                    bid=raw['bid'],
                    ask=raw['ask'],
                    volume=volume,
                    open_interest=raw['openInterest'],
                    implied_volatility=raw['impliedVolatility'],
                    volume_diff=volume_diff,
                    cost=volume_diff * last_price,
                )
            )

# %%
# This function will display the table
from IPython.display import clear_output, display, HTML
fields = ("stock", "contact", "strike", "volume", "volume_diff", "expiration", "time", "bid", "ask", "last_price", "cost")

def display_data():    
    table_rows = []
    for row_data in largest_transactions:          
        table_rows.append(
            "<td>{stock}</td><td>{contact}</td><td>{strike}</td><td>{volume}</td><td>{volume_diff}</td>"\
            "<td>{expiration:%B %d, %Y}</td><td>{time:%I:%M%p}</td>"\
            "<td>${bid}</td><td>${ask}</td>"\
            "<td>${last_price}</td><td>${cost:.2f}</td>".format(**row_data)
        )
    clear_output()
    display(
        HTML(
            '<table><tr><th>{}</th></tr><tr>{}</tr></table>'.format(
                "</th><th>".join(f.capitalize().replace("_", " ") for f in fields),
                "</tr><tr>".join(table_rows)
            )
        )
    )

# %%
from datetime import datetime as dt, timedelta as td
from pytz import timezone
from time import sleep
import heapq

tz = timezone('America/Los_Angeles')  # timezone produces time with PST or PDT tzname depending on the date
STOCKS = ['AAPL', 'BAC', 'NVDA', 'AMZN', 'FB']
DATES = (
    dt(2017, 1, 20).date(), dt(2017, 2, 17).date(), dt(2017, 3, 17).date(), 
    dt(2017, 6, 16).date(), dt(2018, 1, 19).date()
)

last_time = None
count = 1
largest_transactions = []  # here we will store top entries
transaction_volumes = {}  # latest volumes for transactions

while True:    
    now = dt.now(tz=tz)
    start = now.replace(hour=6, minute=30, second=0, microsecond=0)
    stop = start.replace(hour=13, minute=0)
    
    if start <= now <= stop: # proper time for getting data
        
        if last_time: # no more often than once per minute
            diff = 60 - (now - last_time).seconds            
            if diff > 0:
                sleep(diff)  
        
        # the main functionality
        load_data(now)
        # it's efficient way to keep only top 20 entries in the 'largest_transactions' list
        largest_transactions = heapq.nlargest(20, largest_transactions, key=lambda i: i['cost']) 
        display_data()
        
        # some statistics
        print("last update", now)
        print("prev update", last_time) 
        print("update time", dt.now(tz=tz) - now)
        print("iterations", count)
        count += 1
        
        last_time = now        
    else:
        largest_transactions = [] # drop transactions
        if now < start:
            diff = start - now
            print("time to start:", diff)
            
        else:
            start_tommorow = start + td(days=1)
            print("start tommorow at", start_tommorow)
            diff = start_tommorow - now
        
        sleep(diff.seconds + diff.microseconds * 0.1 ** 6)
# Out:
# <table><tr><th>Stock</th><th>Contact</th><th>Strike</th><th>Volume</th><th>Volume diff</th><th>Expiration</th><th>Time</th><th>Bid</th><th>Ask</th><th>Last price</th><th>Cost</th></tr><tr><td>AAPL</td><td>AAPL180119C00120000</td><td>120.0</td><td>2500</td><td>2107</td><td>January 19, 2018</td><td>11:06AM</td><td>$10.75</td><td>$10.85</td><td>$10.77</td><td>$22692.39</td></tr><tr><td>AAPL</td><td>AAPL170120C00085000</td><td>85.0</td><td>439</td><td>400</td><td>January 20, 2017</td><td>11:46AM</td><td>$34.95</td><td>$35.1</td><td>$35.0</td><td>$14000.00</td></tr><tr><td>FB</td><td>FB180119C00005000</td><td>5.0</td><td>343</td><td>94</td><td>January 19, 2018</td><td>11:15AM</td><td>$122.4</td><td>$122.9</td><td>$122.4</td><td>$11505.60</td></tr><tr><td>AAPL</td><td>AAPL180119C00150000</td><td>150.0</td><td>5491</td><td>5159</td><td>January 19, 2018</td><td>11:06AM</td><td>$1.86</td><td>$1.88</td><td>$1.88</td><td>$9698.92</td></tr><tr><td>FB</td><td>FB180119C00005000</td><td>5.0</td><td>196</td><td>56</td><td>January 19, 2018</td><td>11:05AM</td><td>$122.05</td><td>$122.35</td><td>$122.3</td><td>$6848.80</td></tr><tr><td>FB</td><td>FB180119C00005000</td><td>5.0</td><td>249</td><td>53</td><td>January 19, 2018</td><td>11:10AM</td><td>$122.1</td><td>$122.45</td><td>$122.35</td><td>$6484.55</td></tr><tr><td>BAC</td><td>BAC170120C00015000</td><td>15.0</td><td>3939</td><td>850</td><td>January 20, 2017</td><td>11:31AM</td><td>$7.5</td><td>$7.55</td><td>$7.5</td><td>$6375.00</td></tr><tr><td>FB</td><td>FB180119C00005000</td><td>5.0</td><td>456</td><td>47</td><td>January 19, 2018</td><td>11:44AM</td><td>$122.55</td><td>$123.35</td><td>$122.85</td><td>$5773.95</td></tr><tr><td>BAC</td><td>BAC180119C00013000</td><td>13.0</td><td>1214</td><td>519</td><td>January 19, 2018</td><td>11:26AM</td><td>$9.55</td><td>$9.6</td><td>$9.52</td><td>$4940.88</td></tr><tr><td>BAC</td><td>BAC170120C00013000</td><td>13.0</td><td>1006</td><td>500</td><td>January 20, 2017</td><td>11:26AM</td><td>$9.4</td><td>$9.5</td><td>$9.4</td><td>$4700.00</td></tr><tr><td>FB</td><td>FB180119C00005000</td><td>5.0</td><td>409</td><td>37</td><td>January 19, 2018</td><td>11:31AM</td><td>$122.65</td><td>$123.05</td><td>$122.65</td><td>$4538.05</td></tr><tr><td>AMZN</td><td>AMZN170120C00490000</td><td>490.0</td><td>25</td><td>13</td><td>January 20, 2017</td><td>11:30AM</td><td>$314.45</td><td>$317.7</td><td>$317.74</td><td>$4130.62</td></tr><tr><td>AMZN</td><td>AMZN170217P00800000</td><td>800.0</td><td>573</td><td>158</td><td>February 17, 2017</td><td>10:23AM</td><td>$25.35</td><td>$25.55</td><td>$25.15</td><td>$3973.70</td></tr><tr><td>AAPL</td><td>AAPL170120C00100000</td><td>100.0</td><td>742</td><td>200</td><td>January 20, 2017</td><td>10:17AM</td><td>$19.8</td><td>$20.0</td><td>$19.81</td><td>$3962.00</td></tr><tr><td>AAPL</td><td>AAPL170120C00090000</td><td>90.0</td><td>202</td><td>114</td><td>January 20, 2017</td><td>10:18AM</td><td>$29.8</td><td>$30.0</td><td>$29.88</td><td>$3406.32</td></tr><tr><td>AAPL</td><td>AAPL180119C00120000</td><td>120.0</td><td>3126</td><td>312</td><td>January 19, 2018</td><td>11:29AM</td><td>$10.8</td><td>$10.85</td><td>$10.8</td><td>$3369.60</td></tr><tr><td>AMZN</td><td>AMZN170120C00490000</td><td>490.0</td><td>12</td><td>10</td><td>January 20, 2017</td><td>11:14AM</td><td>$314.25</td><td>$329.4</td><td>$315.78</td><td>$3157.80</td></tr><tr><td>FB</td><td>FB180119C00135000</td><td>135.0</td><td>1168</td><td>238</td><td>January 19, 2018</td><td>11:00AM</td><td>$11.5</td><td>$11.6</td><td>$11.58</td><td>$2756.04</td></tr><tr><td>AAPL</td><td>AAPL180119C00095000</td><td>95.0</td><td>104</td><td>100</td><td>January 19, 2018</td><td>11:03AM</td><td>$27.3</td><td>$27.5</td><td>$27.38</td><td>$2738.00</td></tr><tr><td>AMZN</td><td>AMZN170120C00480000</td><td>480.0</td><td>10</td><td>8</td><td>January 20, 2017</td><td>11:07AM</td><td>$324.4</td><td>$326.85</td><td>$325.65</td><td>$2605.20</td></tr></table>
# last update 2017-01-18 12:02:06.051402-08:00
# prev update 2017-01-18 12:01:13.678646-08:00
# update time 0:00:13.792472
# iterations 219
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-bc732a238401> in <module>()
#      26             diff = 60 - (now - last_time).seconds
#      27             if diff > 0:
# ---> 28                 sleep(diff)
#      29
#      30         # the main functionality
#
# KeyboardInterrupt:
