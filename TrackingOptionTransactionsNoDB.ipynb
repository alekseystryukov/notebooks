# %%
from datetime import datetime as dt, timedelta as td
import requests

# %%
url = "https://query1.finance.yahoo.com/v7/finance/options/BAC"
#?formatted=true&crumb=bCkXlpLUQ.w&lang=en-US&region=US&date=1484265600&corsDomain=finance.yahoo.com

# %%
page = requests.get(url)
response = page.json()
if response['optionChain']['error']:
    print(response['optionChain']['error'])

results = response['optionChain']['result']
results
# Out:
# [{'expirationDates': [1484870400,
#    1485475200,
#    1486080000,
#    1486684800,
#    1487289600,
#    1487894400,
#    1488499200,
#    1489708800,
#    1492732800,
#    1495152000,
#    1497571200,
#    1503014400,
#    1513296000,
#    1516320000,
#    1547769600],
#   'hasMiniOptions': False,
#   'options': [{'calls': [{'ask': 18.1,
#       'bid': 17.0,
#       'change': -0.17000008,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00005000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 15.5000003125,
#       'inTheMoney': True,
#       'lastPrice': 17.86,
#       'lastTradeDate': 1484334975,
#       'openInterest': 265,
#       'percentChange': -0.9428734,
#       'strike': 5.0,
#       'volume': 15},
#      {'ask': 10.85,
#       'bid': 10.3,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00006000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 10.4,
#       'lastTradeDate': 1476885202,
#       'openInterest': 2,
#       'percentChange': 0.0,
#       'strike': 6.0,
#       'volume': 2},
#      {'ask': 14.3,
#       'bid': 13.95,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00007000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 13.35,
#       'lastTradeDate': 1480449162,
#       'openInterest': 63,
#       'percentChange': 0.0,
#       'strike': 7.0,
#       'volume': 140},
#      {'ask': 14.7,
#       'bid': 14.55,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00008000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 5.000003749999999,
#       'inTheMoney': True,
#       'lastPrice': 14.51,
#       'lastTradeDate': 1484752568,
#       'openInterest': 2422,
#       'percentChange': 0.0,
#       'strike': 8.0,
#       'volume': 120},
#      {'ask': 13.85,
#       'bid': 13.35,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00009000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 8.15625490234375,
#       'inTheMoney': True,
#       'lastPrice': 13.28,
#       'lastTradeDate': 1484750915,
#       'openInterest': 187,
#       'percentChange': 0.0,
#       'strike': 9.0,
#       'volume': 40},
#      {'ask': 12.7,
#       'bid': 12.55,
#       'change': -0.029999733,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00010000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 4.000005,
#       'inTheMoney': True,
#       'lastPrice': 12.55,
#       'lastTradeDate': 1484839133,
#       'openInterest': 10535,
#       'percentChange': -0.23847164,
#       'strike': 10.0,
#       'volume': 17},
#      {'ask': 12.15,
#       'bid': 11.2,
#       'change': 0.54999924,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00011000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 4.968753789062499,
#       'inTheMoney': True,
#       'lastPrice': 12.15,
#       'lastTradeDate': 1484321265,
#       'openInterest': 570,
#       'percentChange': 4.7413726,
#       'strike': 11.0,
#       'volume': 30},
#      {'ask': 10.7,
#       'bid': 10.55,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00012000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 3.1250021875,
#       'inTheMoney': True,
#       'lastPrice': 10.47,
#       'lastTradeDate': 1484751464,
#       'openInterest': 443,
#       'percentChange': 0.0,
#       'strike': 12.0,
#       'volume': 202},
#      {'ask': 9.7,
#       'bid': 9.55,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00013000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.750003125,
#       'inTheMoney': True,
#       'lastPrice': 9.6,
#       'lastTradeDate': 1484843968,
#       'openInterest': 22367,
#       'percentChange': 0.0,
#       'strike': 13.0,
#       'volume': 36},
#      {'ask': 8.7,
#       'bid': 8.55,
#       'change': 0.069999695,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00014000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.50000375,
#       'inTheMoney': True,
#       'lastPrice': 8.65,
#       'lastTradeDate': 1484843428,
#       'openInterest': 3052,
#       'percentChange': 0.8158472,
#       'strike': 14.0,
#       'volume': 43},
#      {'ask': 7.7,
#       'bid': 7.55,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00014500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 7.45,
#       'lastTradeDate': 1483038300,
#       'openInterest': 31,
#       'percentChange': 0.0,
#       'strike': 14.5,
#       'volume': 32},
#      {'ask': 7.65,
#       'bid': 7.55,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00015000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.718753203125,
#       'inTheMoney': True,
#       'lastPrice': 7.6,
#       'lastTradeDate': 1484844613,
#       'openInterest': 63059,
#       'percentChange': 0.0,
#       'strike': 15.0,
#       'volume': 1912},
#      {'ask': 7.55,
#       'bid': 7.45,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00015500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 4.441410698242187,
#       'inTheMoney': True,
#       'lastPrice': 7.5,
#       'lastTradeDate': 1484166763,
#       'openInterest': 144,
#       'percentChange': 0.0,
#       'strike': 15.5,
#       'volume': 13},
#      {'ask': 6.7,
#       'bid': 6.5,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00016000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.81250296875,
#       'inTheMoney': True,
#       'lastPrice': 6.55,
#       'lastTradeDate': 1484842000,
#       'openInterest': 57597,
#       'percentChange': 0.0,
#       'strike': 16.0,
#       'volume': 89},
#      {'ask': 6.55,
#       'bid': 6.45,
#       'change': 0.14999962,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00016500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 3.8789065527343753,
#       'inTheMoney': True,
#       'lastPrice': 6.45,
#       'lastTradeDate': 1484333383,
#       'openInterest': 160,
#       'percentChange': 2.3809462,
#       'strike': 16.5,
#       'volume': 27},
#      {'ask': 5.65,
#       'bid': 5.6,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00017000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.5000025,
#       'inTheMoney': True,
#       'lastPrice': 5.6,
#       'lastTradeDate': 1484844100,
#       'openInterest': 295546,
#       'percentChange': 0.0,
#       'strike': 17.0,
#       'volume': 1129},
#      {'ask': 5.55,
#       'bid': 5.45,
#       'change': 0.25,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00017500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 3.339845400390624,
#       'inTheMoney': True,
#       'lastPrice': 5.6,
#       'lastTradeDate': 1484326813,
#       'openInterest': 107,
#       'percentChange': 4.6728973,
#       'strike': 17.5,
#       'volume': 119},
#      {'ask': 4.7,
#       'bid': 4.6,
#       'change': -0.05000019,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00018000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.65625171875,
#       'inTheMoney': True,
#       'lastPrice': 4.6,
#       'lastTradeDate': 1484844784,
#       'openInterest': 115280,
#       'percentChange': -1.0752729,
#       'strike': 18.0,
#       'volume': 137},
#      {'ask': 4.2,
#       'bid': 4.0,
#       'change': 0.099999905,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00018500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.8046884765624998,
#       'inTheMoney': True,
#       'lastPrice': 4.0,
#       'lastTradeDate': 1484839061,
#       'openInterest': 200,
#       'percentChange': 2.5641,
#       'strike': 18.5,
#       'volume': 12},
#      {'ask': 3.65,
#       'bid': 3.6,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00019000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.9687503125,
#       'inTheMoney': True,
#       'lastPrice': 3.6,
#       'lastTradeDate': 1484844055,
#       'openInterest': 223092,
#       'percentChange': 0.0,
#       'strike': 19.0,
#       'volume': 204},
#      {'ask': 3.15,
#       'bid': 3.1,
#       'change': 0.049999952,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00019500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.8437515624999999,
#       'inTheMoney': True,
#       'lastPrice': 2.98,
#       'lastTradeDate': 1484839056,
#       'openInterest': 1241,
#       'percentChange': 1.706483,
#       'strike': 19.5,
#       'volume': 46},
#      {'ask': 2.61,
#       'bid': 2.59,
#       'change': -0.01999998,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00020000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 2.6,
#       'lastTradeDate': 1484844703,
#       'openInterest': 238542,
#       'percentChange': -0.76335806,
#       'strike': 20.0,
#       'volume': 4193},
#      {'ask': 2.13,
#       'bid': 2.12,
#       'change': 0.099999905,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00020500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.5937540625000001,
#       'inTheMoney': True,
#       'lastPrice': 2.11,
#       'lastTradeDate': 1484841428,
#       'openInterest': 2464,
#       'percentChange': 4.9751196,
#       'strike': 20.5,
#       'volume': 143},
#      {'ask': 1.63,
#       'bid': 1.62,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00021000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.5312546875,
#       'inTheMoney': True,
#       'lastPrice': 1.6,
#       'lastTradeDate': 1484843967,
#       'openInterest': 90589,
#       'percentChange': 0.0,
#       'strike': 21.0,
#       'volume': 2302},
#      {'ask': 1.14,
#       'bid': 1.12,
#       'change': -0.01999998,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00021500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.445318046875,
#       'inTheMoney': True,
#       'lastPrice': 1.08,
#       'lastTradeDate': 1484842063,
#       'openInterest': 7018,
#       'percentChange': -1.8181801,
#       'strike': 21.5,
#       'volume': 111},
#      {'ask': 0.64,
#       'bid': 0.63,
#       'change': -0.030000031,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00022000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.28125718749999995,
#       'inTheMoney': True,
#       'lastPrice': 0.64,
#       'lastTradeDate': 1484844639,
#       'openInterest': 233615,
#       'percentChange': -4.4776163,
#       'strike': 22.0,
#       'volume': 2815},
#      {'ask': 0.23,
#       'bid': 0.22,
#       'change': -0.030000016,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00022500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.242195078125,
#       'inTheMoney': True,
#       'lastPrice': 0.24,
#       'lastTradeDate': 1484844545,
#       'openInterest': 36941,
#       'percentChange': -11.111116,
#       'strike': 22.5,
#       'volume': 5189},
#      {'ask': 0.05,
#       'bid': 0.04,
#       'change': -0.030000001,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00023000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.26563234375,
#       'inTheMoney': False,
#       'lastPrice': 0.04,
#       'lastTradeDate': 1484844710,
#       'openInterest': 176466,
#       'percentChange': -42.857143,
#       'strike': 23.0,
#       'volume': 9305},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00023500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.304694453125,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484844438,
#       'openInterest': 32557,
#       'percentChange': 0.0,
#       'strike': 23.5,
#       'volume': 1023},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00024000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.437505625,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484839669,
#       'openInterest': 88119,
#       'percentChange': 0.0,
#       'strike': 24.0,
#       'volume': 78},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': -0.07,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00024500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.5625043750000001,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484340149,
#       'openInterest': 15005,
#       'percentChange': -87.5,
#       'strike': 24.5,
#       'volume': 23072},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.03,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00025000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.6250037500000001,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484340447,
#       'openInterest': 133741,
#       'percentChange': -75.0,
#       'strike': 25.0,
#       'volume': 3059},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.02,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00025500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.7187528125,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484323358,
#       'openInterest': 35301,
#       'percentChange': -66.66667,
#       'strike': 25.5,
#       'volume': 268},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00026000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.8125018749999999,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484318201,
#       'openInterest': 29812,
#       'percentChange': -50.0,
#       'strike': 26.0,
#       'volume': 2},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00026500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.98437515625,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1483563510,
#       'openInterest': 647,
#       'percentChange': 0.0,
#       'strike': 26.5,
#       'volume': 14},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00027000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.98437515625,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483730925,
#       'openInterest': 22851,
#       'percentChange': -50.0,
#       'strike': 27.0,
#       'volume': 446},
#      {'ask': 0.02,
#       'bid': 0.01,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00027500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.2500037499999999,
#       'inTheMoney': False,
#       'lastPrice': 0.03,
#       'lastTradeDate': 1482262814,
#       'openInterest': 211,
#       'percentChange': 0.0,
#       'strike': 27.5,
#       'volume': 105},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00028000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.2812535937499998,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483114158,
#       'openInterest': 3803,
#       'percentChange': -50.0,
#       'strike': 28.0,
#       'volume': 10},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00029000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.4375028125,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1482338643,
#       'openInterest': 1755,
#       'percentChange': 0.0,
#       'strike': 29.0,
#       'volume': 10},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00029500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.4375028125,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1482554706,
#       'openInterest': 165,
#       'percentChange': 0.0,
#       'strike': 29.5,
#       'volume': 155},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.02,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00030000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.5000025,
#       'inTheMoney': False,
#       'lastPrice': 0.03,
#       'lastTradeDate': 1484836227,
#       'openInterest': 41890,
#       'percentChange': 200.0,
#       'strike': 30.0,
#       'volume': 20},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00030500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.5625021874999998,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483159928,
#       'openInterest': 50,
#       'percentChange': 0.0,
#       'strike': 30.5,
#       'volume': 40},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00031000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.78125109375,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1481950427,
#       'openInterest': 70,
#       'percentChange': 0.0,
#       'strike': 31.0,
#       'volume': 77},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00032000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.8125009374999999,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1482849755,
#       'openInterest': 10,
#       'percentChange': 0.0,
#       'strike': 32.0,
#       'volume': 5}],
#     'expirationDate': 1484870400,
#     'hasMiniOptions': False,
#     'puts': [{'ask': 0.02,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00005000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 7.87500015625,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1472240413,
#       'openInterest': 37092,
#       'percentChange': -50.0,
#       'strike': 5.0,
#       'volume': 200},
#      {'ask': 0.02,
#       'bid': 0.01,
#       'change': 0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00006000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 7.37500078125,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1471536077,
#       'openInterest': 3686,
#       'percentChange': 100.0,
#       'strike': 6.0,
#       'volume': 100},
#      {'ask': 0.02,
#       'bid': 0.01,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00007000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 6.500001875000001,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1473185890,
#       'openInterest': 2538,
#       'percentChange': 0.0,
#       'strike': 7.0,
#       'volume': 100},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00008000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 5.250003437499999,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1476714104,
#       'openInterest': 41423,
#       'percentChange': 0.0,
#       'strike': 8.0,
#       'volume': 20},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00009000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 5.000003749999999,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1478619748,
#       'openInterest': 11490,
#       'percentChange': -50.0,
#       'strike': 9.0,
#       'volume': 1},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00010000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 4.12500484375,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1478890672,
#       'openInterest': 110039,
#       'percentChange': 0.0,
#       'strike': 10.0,
#       'volume': 209},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00011000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 3.93750015625,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1479329456,
#       'openInterest': 23258,
#       'percentChange': 0.0,
#       'strike': 11.0,
#       'volume': 164},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.02,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00012000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 3.2500018749999997,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1479501105,
#       'openInterest': 36055,
#       'percentChange': -66.66667,
#       'strike': 12.0,
#       'volume': 55},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00013000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.8750028125,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1482524762,
#       'openInterest': 280696,
#       'percentChange': 0.0,
#       'strike': 13.0,
#       'volume': 11},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00014000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.50000375,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483036985,
#       'openInterest': 53475,
#       'percentChange': 0.0,
#       'strike': 14.0,
#       'volume': 15},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00015000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.1250046874999997,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483634806,
#       'openInterest': 273307,
#       'percentChange': 0.0,
#       'strike': 15.0,
#       'volume': 40},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00016000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.875000625,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484160718,
#       'openInterest': 35022,
#       'percentChange': 0.0,
#       'strike': 16.0,
#       'volume': 10},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00016500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.6875015625,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483764258,
#       'openInterest': 171,
#       'percentChange': 0.0,
#       'strike': 16.5,
#       'volume': 171},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00017000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.5625021874999998,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484840373,
#       'openInterest': 244981,
#       'percentChange': -50.0,
#       'strike': 17.0,
#       'volume': 8},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00017500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.5625021874999998,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483042332,
#       'openInterest': 8234,
#       'percentChange': 0.0,
#       'strike': 17.5,
#       'volume': 140},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00018000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.2500037499999999,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483731773,
#       'openInterest': 36798,
#       'percentChange': 0.0,
#       'strike': 18.0,
#       'volume': 110},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00018500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.2500037499999999,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483559058,
#       'openInterest': 882,
#       'percentChange': 0.0,
#       'strike': 18.5,
#       'volume': 75},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00019000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.000005,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484328548,
#       'openInterest': 43266,
#       'percentChange': -50.0,
#       'strike': 19.0,
#       'volume': 1615},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00019500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.87500125,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1484243723,
#       'openInterest': 919,
#       'percentChange': 0.0,
#       'strike': 19.5,
#       'volume': 2},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00020000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.7500025,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484836228,
#       'openInterest': 136059,
#       'percentChange': 0.0,
#       'strike': 20.0,
#       'volume': 4},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00020500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.6250037500000001,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484773183,
#       'openInterest': 4852,
#       'percentChange': 0.0,
#       'strike': 20.5,
#       'volume': 50},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00021000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.5312546875,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484838301,
#       'openInterest': 59535,
#       'percentChange': 0.0,
#       'strike': 21.0,
#       'volume': 2},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00021500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.39063109375,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484841826,
#       'openInterest': 15267,
#       'percentChange': 0.0,
#       'strike': 21.5,
#       'volume': 79},
#      {'ask': 0.03,
#       'bid': 0.02,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00022000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.31641308593749995,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1484844644,
#       'openInterest': 183061,
#       'percentChange': -33.333336,
#       'strike': 22.0,
#       'volume': 7393},
#      {'ask': 0.13,
#       'bid': 0.12,
#       'change': -0.009999998,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00022500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.27735097656249996,
#       'inTheMoney': False,
#       'lastPrice': 0.12,
#       'lastTradeDate': 1484844841,
#       'openInterest': 56372,
#       'percentChange': -7.6923065,
#       'strike': 22.5,
#       'volume': 4354},
#      {'ask': 0.42,
#       'bid': 0.41,
#       'change': -0.01999998,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00023000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.2461012890625,
#       'inTheMoney': True,
#       'lastPrice': 0.4,
#       'lastTradeDate': 1484844346,
#       'openInterest': 53824,
#       'percentChange': -4.7619004,
#       'strike': 23.0,
#       'volume': 2054},
#      {'ask': 0.9,
#       'bid': 0.88,
#       'change': -0.029999971,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00023500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.35938140625,
#       'inTheMoney': True,
#       'lastPrice': 0.87,
#       'lastTradeDate': 1484843725,
#       'openInterest': 2768,
#       'percentChange': -3.3333302,
#       'strike': 23.5,
#       'volume': 182},
#      {'ask': 1.91,
#       'bid': 1.9,
#       'change': -0.1400001,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00024500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.6718782812500002,
#       'inTheMoney': True,
#       'lastPrice': 2.05,
#       'lastTradeDate': 1484839041,
#       'openInterest': 1331,
#       'percentChange': -6.392699,
#       'strike': 24.5,
#       'volume': 170},
#      {'ask': 2.4,
#       'bid': 2.39,
#       'change': 0.00999999,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00025000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.73437765625,
#       'inTheMoney': True,
#       'lastPrice': 2.41,
#       'lastTradeDate': 1484843902,
#       'openInterest': 19562,
#       'percentChange': 0.41666627,
#       'strike': 25.0,
#       'volume': 100},
#      {'ask': 2.89,
#       'bid': 2.88,
#       'change': 0.00999999,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00025500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.7187528125,
#       'inTheMoney': True,
#       'lastPrice': 3.0,
#       'lastTradeDate': 1484839061,
#       'openInterest': 308,
#       'percentChange': 0.33444783,
#       'strike': 25.5,
#       'volume': 2},
#      {'ask': 3.4,
#       'bid': 3.35,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00026000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.000005,
#       'inTheMoney': True,
#       'lastPrice': 3.72,
#       'lastTradeDate': 1484760199,
#       'openInterest': 605,
#       'percentChange': 0.0,
#       'strike': 26.0,
#       'volume': 4},
#      {'ask': 3.95,
#       'bid': 3.85,
#       'change': 0.3499999,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00026500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.109379453125,
#       'inTheMoney': True,
#       'lastPrice': 4.0,
#       'lastTradeDate': 1484839061,
#       'openInterest': 39,
#       'percentChange': 9.589038,
#       'strike': 26.5,
#       'volume': 8},
#      {'ask': 4.05,
#       'bid': 3.95,
#       'change': -0.25,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00027000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 3.9,
#       'lastTradeDate': 1484322511,
#       'openInterest': 603,
#       'percentChange': -6.024096,
#       'strike': 27.0,
#       'volume': 1},
#      {'ask': 4.55,
#       'bid': 4.45,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00027500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 4.55,
#       'lastTradeDate': 1484074867,
#       'openInterest': 11,
#       'percentChange': 0.0,
#       'strike': 27.5,
#       'volume': 10},
#      {'ask': 5.05,
#       'bid': 4.95,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00028000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 5.0,
#       'lastTradeDate': 1484068828,
#       'openInterest': 180,
#       'percentChange': 0.0,
#       'strike': 28.0,
#       'volume': 10},
#      {'ask': 5.85,
#       'bid': 5.75,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00028500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 5.8,
#       'lastTradeDate': 1483545990,
#       'openInterest': 23,
#       'percentChange': 0.0,
#       'strike': 28.5,
#       'volume': 22},
#      {'ask': 6.35,
#       'bid': 6.25,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00029000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 6.16,
#       'lastTradeDate': 1483626950,
#       'openInterest': 122,
#       'percentChange': 0.0,
#       'strike': 29.0,
#       'volume': 7},
#      {'ask': 7.4,
#       'bid': 7.3,
#       'change': 0.25,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00029500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 3.3671890820312496,
#       'inTheMoney': True,
#       'lastPrice': 7.45,
#       'lastTradeDate': 1483108656,
#       'openInterest': 71,
#       'percentChange': 3.4722223,
#       'strike': 29.5,
#       'volume': 16},
#      {'ask': 7.65,
#       'bid': 7.15,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00030000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.7968760156249999,
#       'inTheMoney': True,
#       'lastPrice': 7.92,
#       'lastTradeDate': 1484683974,
#       'openInterest': 566,
#       'percentChange': 0.0,
#       'strike': 30.0,
#       'volume': 2},
#      {'ask': 8.9,
#       'bid': 8.8,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00031000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 3.7578131054687502,
#       'inTheMoney': True,
#       'lastPrice': 9.05,
#       'lastTradeDate': 1483040040,
#       'openInterest': 293,
#       'percentChange': 0.0,
#       'strike': 31.0,
#       'volume': 170},
#      {'ask': 9.45,
#       'bid': 9.35,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00032000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.1250046874999997,
#       'inTheMoney': True,
#       'lastPrice': 9.68,
#       'lastTradeDate': 1484674693,
#       'openInterest': 83,
#       'percentChange': 0.0,
#       'strike': 32.0,
#       'volume': 18}]}],
#   'quote': {'ask': 0.0,
#    'askSize': 0,
#    'averageDailyVolume10Day': 118286100,
#    'averageDailyVolume3Month': 120082340,
#    'bid': 0.0,
#    'bidSize': 0,
#    'bookValue': 24.187,
#    'currency': 'USD',
#    'dividendDate': 1483056000,
#    'earningsTimestamp': 1484332200,
#    'earningsTimestampEnd': 1492446600,
#    'earningsTimestampStart': 1492014600,
#    'epsForward': 1.62,
#    'epsTrailingTwelveMonths': 1.367,
#    'exchange': 'NYQ',
#    'exchangeTimezoneName': 'America/New_York',
#    'exchangeTimezoneShortName': 'EST',
#    'fiftyDayAverage': 22.490303,
#    'fiftyDayAverageChange': 0.13069725,
#    'fiftyDayAverageChangePercent': 0.0058112713,
#    'fiftyTwoWeekHigh': 23.41,
#    'fiftyTwoWeekHighChange': -0.78899956,
#    'fiftyTwoWeekHighChangePercent': -0.03370353,
#    'fiftyTwoWeekLow': 10.99,
#    'fiftyTwoWeekLowChange': 11.6310005,
#    'fiftyTwoWeekLowChangePercent': 1.0583258,
#    'forwardPE': 13.96358,
#    'fullExchangeName': 'NYSE',
#    'gmtOffSetMilliseconds': -18000000,
#    'longName': 'Bank of America Corporation',
#    'market': 'us_market',
#    'marketCap': 228585209856,
#    'marketState': 'REGULAR',
#    'messageBoardId': 'finmb_19049',
#    'priceToBook': 0.93525445,
#    'quoteSourceName': 'NYSE Real Time Price',
#    'quoteType': 'EQUITY',
#    'regularMarketChange': -0.008998871,
#    'regularMarketChangePercent': -0.039765228,
#    'regularMarketDayHigh': 22.81,
#    'regularMarketDayLow': 22.41,
#    'regularMarketOpen': 22.73,
#    'regularMarketPreviousClose': 22.63,
#    'regularMarketPrice': 22.621,
#    'regularMarketTime': 1484845790,
#    'regularMarketVolume': 41814454,
#    'sharesOutstanding': 10105000000,
#    'shortName': 'Bank of America Corporation Com',
#    'sourceInterval': 15,
#    'symbol': 'BAC',
#    'trailingAnnualDividendRate': 0.225,
#    'trailingPE': 16.547916,
#    'twoHundredDayAverage': 17.542482,
#    'twoHundredDayAverageChange': 5.078518,
#    'twoHundredDayAverageChangePercent': 0.28949824},
#   'strikes': [5.0,
#    6.0,
#    7.0,
#    8.0,
#    9.0,
#    10.0,
#    11.0,
#    12.0,
#    13.0,
#    14.0,
#    14.5,
#    15.0,
#    15.5,
#    16.0,
#    16.5,
#    17.0,
#    17.5,
#    18.0,
#    18.5,
#    19.0,
#    19.5,
#    20.0,
#    20.5,
#    21.0,
#    21.5,
#    22.0,
#    22.5,
#    23.0,
#    23.5,
#    24.0,
#    24.5,
#    25.0,
#    25.5,
#    26.0,
#    26.5,
#    27.0,
#    27.5,
#    28.0,
#    28.5,
#    29.0,
#    29.5,
#    30.0,
#    30.5,
#    31.0,
#    32.0],
#   'underlyingSymbol': 'BAC'}]

# %%
result = results[0]
dates = [dt.fromtimestamp(tm) for tm in result['expirationDates']]
# we can use these dates to get data for a specific expiration date
# an example url: https://query1.finance.yahoo.com/v7/finance/options/BAC?date=1484265600 
# the first date is default
dates
# Out:
# [datetime.datetime(2017, 1, 20, 2, 0),
#  datetime.datetime(2017, 1, 27, 2, 0),
#  datetime.datetime(2017, 2, 3, 2, 0),
#  datetime.datetime(2017, 2, 10, 2, 0),
#  datetime.datetime(2017, 2, 17, 2, 0),
#  datetime.datetime(2017, 2, 24, 2, 0),
#  datetime.datetime(2017, 3, 3, 2, 0),
#  datetime.datetime(2017, 3, 17, 2, 0),
#  datetime.datetime(2017, 4, 21, 3, 0),
#  datetime.datetime(2017, 5, 19, 3, 0),
#  datetime.datetime(2017, 6, 16, 3, 0),
#  datetime.datetime(2017, 8, 18, 3, 0),
#  datetime.datetime(2017, 12, 15, 2, 0),
#  datetime.datetime(2018, 1, 19, 2, 0),
#  datetime.datetime(2019, 1, 18, 2, 0)]

# %%
option = result['options'][0]
calls = option['calls']
calls[:2]
# Out:
# [{'ask': 18.1,
#   'bid': 17.0,
#   'change': -0.17000008,
#   'contractSize': 'REGULAR',
#   'contractSymbol': 'BAC170120C00005000',
#   'currency': 'USD',
#   'expiration': 1484870400,
#   'impliedVolatility': 15.5000003125,
#   'inTheMoney': True,
#   'lastPrice': 17.86,
#   'lastTradeDate': 1484334975,
#   'openInterest': 265,
#   'percentChange': -0.9428734,
#   'strike': 5.0,
#   'volume': 15},
#  {'ask': 10.85,
#   'bid': 10.3,
#   'change': 0.0,
#   'contractSize': 'REGULAR',
#   'contractSymbol': 'BAC170120C00006000',
#   'currency': 'USD',
#   'expiration': 1484870400,
#   'impliedVolatility': 1.0000000000000003e-05,
#   'inTheMoney': True,
#   'lastPrice': 10.4,
#   'lastTradeDate': 1476885202,
#   'openInterest': 2,
#   'percentChange': 0.0,
#   'strike': 6.0,
#   'volume': 2}]

# %%
puts = option['puts']
puts[-2:]
# Out:
# [{'ask': 8.9,
#   'bid': 8.8,
#   'change': 0.0,
#   'contractSize': 'REGULAR',
#   'contractSymbol': 'BAC170120P00031000',
#   'currency': 'USD',
#   'expiration': 1484870400,
#   'impliedVolatility': 3.7578131054687502,
#   'inTheMoney': True,
#   'lastPrice': 9.05,
#   'lastTradeDate': 1483040040,
#   'openInterest': 293,
#   'percentChange': 0.0,
#   'strike': 31.0,
#   'volume': 170},
#  {'ask': 9.45,
#   'bid': 9.35,
#   'change': 0.0,
#   'contractSize': 'REGULAR',
#   'contractSymbol': 'BAC170120P00032000',
#   'currency': 'USD',
#   'expiration': 1484870400,
#   'impliedVolatility': 2.1250046874999997,
#   'inTheMoney': True,
#   'lastPrice': 9.68,
#   'lastTradeDate': 1484674693,
#   'openInterest': 83,
#   'percentChange': 0.0,
#   'strike': 32.0,
#   'volume': 18}]

# %% [markdown]
# # Implementation

# %%
# There is a lot of data to load every minute, so we have to do this in parrallel
# 'threading' module fits well for this purpose
# I'm going to use two queues to connect our main programm and thread workers: 
# the first is for tasks, the other - for results
# You can find some examples of using 'queue'-module here
# https://docs.python.org/3/library/queue.html#queue.Queue.join
import queue
import requests
import threading


def load_data(time):
    
    num_worker_threads = 10
    
    def worker():
        while True:
            args = q.get()
            if args is None:
                break
            get_transactions(q, r, *args)  # <-- see definition of this function below
            q.task_done()

    q = queue.Queue() # queue with arguments for the 'get_transactions' function
    r = queue.Queue() # queue with raw responses

    threads = []
    for i in range(num_worker_threads):
        t = threading.Thread(target=worker)
        t.start()
        threads.append(t)

    for stock in STOCKS:
        q.put((stock, None))

    # block until all tasks are done
    q.join()

    # stop workers
    for i in range(num_worker_threads):
        q.put(None)

    for t in threads:
        t.join()
        
    save_rows(r, time)
    
    
def get_transactions(queue, resp_queue, stock, date=None):     
    base_url = "https://query1.finance.yahoo.com/v7/finance/options/{}".format(stock)
    if date is not None:
        url = "{}?date={}".format(base_url, date)
    else:
        url = base_url
    try:
        page = requests.get(url)
    except Exception as e:
        print(e)
    else:
        response = page.json()
        if response['optionChain']['error']: # if any error
            print(response['optionChain']['error'])

        else:
            results = response['optionChain']['result']
            result = results[0]

            for option in result['options']:
                resp_queue.put((stock, dict(calls=option['calls'], puts=option['puts'])))

            if date is None:
                for tm in result['expirationDates'][1:]:
                    if dt.fromtimestamp(tm).date() in DATES:
                        queue.put((stock, tm))

# %%
# Functions which take response from the response queue and put to the 'largest_transactions' list
def save_rows(q, time):
    global largest_transactions
    while True:
        try:
            stock, data = q.get(block=False)
        except queue.Empty:
            break
        else:
            for call in data['calls']:
                save_row(stock, 'call', time, call)
            for put in data['puts']:
                save_row(stock, 'put', time, put)

def save_row(s, t, time, raw):
    contact = raw['contractSymbol']    
    previous_volume = transaction_volumes.get(contact)
    volume = raw['volume']
    transaction_volumes[contact] = volume
    
    if previous_volume is not None:        
        volume_diff = volume - previous_volume
        if volume_diff > 0:
            last_price = raw['lastPrice']
            largest_transactions.append(
                dict(
                    stock=s,
                    type=t,
                    time=time,
                    expiration=dt.fromtimestamp(raw['expiration']),
                    strike=raw['strike'],
                    contact=contact,
                    last_price=last_price,
                    bid=raw['bid'],
                    ask=raw['ask'],
                    volume=volume,
                    open_interest=raw['openInterest'],
                    implied_volatility=raw['impliedVolatility'],
                    volume_diff=volume_diff,
                    cost=volume_diff * last_price,
                )
            )

# %%
# This function will display the table
from IPython.display import clear_output, display, HTML
fields = ("stock", "strike", "volume_diff", "expiration", "time", "bid", "ask", "last_price", "cost")

def display_data():    
    table_rows = []
    for row_data in largest_transactions:          
        table_rows.append(
            "<td>{stock}</td><td>{strike}</td><td>{volume_diff}</td>"\
            "<td>{expiration:%B %d, %Y}</td><td>{time:%I:%M%p}</td>"\
            "<td> ${bid} </td><td> ${ask} </td>"\
            "<td> ${last_price} </td><td> ${cost:.2f} </td>".format(**row_data)
        )
    clear_output()
    display(
        HTML(
            '<table><tr><th>{}</th></tr><tr>{}</tr></table>'.format(
                "</th><th>".join(f.capitalize().replace("_", " ") for f in fields),
                "</tr><tr>".join(table_rows)
            )
        )
    )

# %%
from datetime import datetime as dt, timedelta as td
from pytz import timezone
from time import sleep
import heapq

tz = timezone('America/Los_Angeles')  # timezone produces time with PST or PDT tzname depending on the date
STOCKS = ['AAPL', 'BAC', 'NVDA', 'AMZN', 'FB']
DATES = (
    dt(2017, 1, 20).date(), dt(2017, 2, 17).date(), dt(2017, 3, 17).date(), 
    dt(2017, 6, 16).date(), dt(2018, 1, 19).date()
)

last_time = None
count = 1
largest_transactions = []  # here we will store top entries
transaction_volumes = {}  # latest volumes for transactions

while True:    
    now = dt.now(tz=tz)
    start = now.replace(hour=6, minute=30, second=0, microsecond=0)
    stop = start.replace(hour=13, minute=0)
    
    if start <= now <= stop: # proper time for getting data
        
        if last_time: # no more often than once per minute
            diff = 60 - (now - last_time).seconds            
            if diff > 0:
                sleep(diff)  
        
        # the main functionality
        load_data(now)
        # it's efficient way to keep only top 20 entries in the 'largest_transactions' list
        largest_transactions = heapq.nlargest(20, largest_transactions, key=lambda i: i['cost']) 
        display_data()
        
        # some statistics
        print("last update", now)
        print("prev update", last_time) 
        print("update time", dt.now(tz=tz) - now)
        print("iterations", count)
        count += 1
        
        last_time = now        
    else:
        largest_transactions = [] # drop transactions
        if now < start:
            diff = start - now
            print("time to start:", diff)
            
        else:
            start_tommorow = start + td(days=1)
            print("start tommorow at", start_tommorow)
            diff = start_tommorow - now
        
        sleep(diff.seconds + diff.microseconds * 0.1 ** 6)
# Out:
# <table><tr><th>Stock</th><th>Strike</th><th>Volume diff</th><th>Expiration</th><th>Time</th><th>Bid</th><th>Ask</th><th>Last price</th><th>Cost</th></tr><tr><td>NVDA</td><td>90.0</td><td>104</td><td>March 17, 2017</td><td>09:10AM</td><td> $11.05 </td><td> $11.4 </td><td> $11.25 </td><td> $1170.00 </td></tr><tr><td>NVDA</td><td>105.0</td><td>101</td><td>February 17, 2017</td><td>09:10AM</td><td> $6.9 </td><td> $7.0 </td><td> $6.94 </td><td> $700.94 </td></tr><tr><td>AAPL</td><td>115.0</td><td>129</td><td>January 20, 2017</td><td>09:10AM</td><td> $4.95 </td><td> $5.05 </td><td> $5.0 </td><td> $645.00 </td></tr><tr><td>BAC</td><td>17.0</td><td>90</td><td>January 20, 2017</td><td>09:10AM</td><td> $5.55 </td><td> $5.65 </td><td> $5.6 </td><td> $504.00 </td></tr><tr><td>NVDA</td><td>100.0</td><td>14</td><td>June 16, 2017</td><td>09:10AM</td><td> $9.65 </td><td> $9.7 </td><td> $9.7 </td><td> $135.80 </td></tr><tr><td>FB</td><td>126.0</td><td>60</td><td>January 20, 2017</td><td>09:10AM</td><td> $2.09 </td><td> $2.12 </td><td> $2.15 </td><td> $129.00 </td></tr><tr><td>FB</td><td>75.0</td><td>2</td><td>January 20, 2017</td><td>09:10AM</td><td> $53.0 </td><td> $53.1 </td><td> $53.02 </td><td> $106.04 </td></tr><tr><td>AMZN</td><td>815.0</td><td>48</td><td>January 20, 2017</td><td>09:10AM</td><td> $1.79 </td><td> $2.14 </td><td> $1.96 </td><td> $94.08 </td></tr><tr><td>FB</td><td>110.0</td><td>5</td><td>January 20, 2017</td><td>09:10AM</td><td> $17.95 </td><td> $18.1 </td><td> $18.05 </td><td> $90.25 </td></tr><tr><td>FB</td><td>130.0</td><td>10</td><td>June 16, 2017</td><td>09:10AM</td><td> $7.45 </td><td> $7.55 </td><td> $7.5 </td><td> $75.00 </td></tr><tr><td>FB</td><td>130.0</td><td>849</td><td>January 20, 2017</td><td>09:10AM</td><td> $0.07 </td><td> $0.08 </td><td> $0.08 </td><td> $67.92 </td></tr><tr><td>FB</td><td>90.0</td><td>23</td><td>January 19, 2018</td><td>09:10AM</td><td> $2.44 </td><td> $2.49 </td><td> $2.47 </td><td> $56.81 </td></tr><tr><td>BAC</td><td>21.0</td><td>35</td><td>January 20, 2017</td><td>09:10AM</td><td> $1.6 </td><td> $1.61 </td><td> $1.61 </td><td> $56.35 </td></tr><tr><td>NVDA</td><td>70.0</td><td>11</td><td>January 19, 2018</td><td>09:10AM</td><td> $4.45 </td><td> $4.5 </td><td> $4.5 </td><td> $49.50 </td></tr><tr><td>AMZN</td><td>810.0</td><td>11</td><td>January 20, 2017</td><td>09:10AM</td><td> $3.9 </td><td> $4.3 </td><td> $4.18 </td><td> $45.98 </td></tr><tr><td>NVDA</td><td>95.0</td><td>19</td><td>February 17, 2017</td><td>09:10AM</td><td> $2.37 </td><td> $2.43 </td><td> $2.37 </td><td> $45.03 </td></tr><tr><td>NVDA</td><td>105.0</td><td>69</td><td>January 20, 2017</td><td>09:10AM</td><td> $0.66 </td><td> $0.69 </td><td> $0.65 </td><td> $44.85 </td></tr><tr><td>AMZN</td><td>680.0</td><td>40</td><td>February 17, 2017</td><td>09:10AM</td><td> $1.01 </td><td> $1.15 </td><td> $1.07 </td><td> $42.80 </td></tr><tr><td>NVDA</td><td>105.0</td><td>28</td><td>January 20, 2017</td><td>09:10AM</td><td> $1.29 </td><td> $1.39 </td><td> $1.38 </td><td> $38.64 </td></tr><tr><td>NVDA</td><td>90.0</td><td>2</td><td>January 20, 2017</td><td>09:10AM</td><td> $15.6 </td><td> $16.0 </td><td> $15.7 </td><td> $31.40 </td></tr></table>
# last update 2017-01-19 09:10:55.570782-08:00
# prev update 2017-01-19 09:10:11.411549-08:00
# update time 0:00:22.319078
# iterations 3
