# %%
from datetime import datetime as dt, timedelta as td
import requests

# %%
url = "https://query1.finance.yahoo.com/v7/finance/options/BAC"
#?formatted=true&crumb=bCkXlpLUQ.w&lang=en-US&region=US&date=1484265600&corsDomain=finance.yahoo.com

# %%
page = requests.get(url)
response = page.json()
if response['optionChain']['error']:
    print(response['optionChain']['error'])

results = response['optionChain']['result']
results
# Out:
# [{'expirationDates': [1484870400,
#    1485475200,
#    1486080000,
#    1486684800,
#    1487289600,
#    1487894400,
#    1488499200,
#    1489708800,
#    1492732800,
#    1495152000,
#    1497571200,
#    1503014400,
#    1513296000,
#    1516320000,
#    1547769600],
#   'hasMiniOptions': False,
#   'options': [{'calls': [{'ask': 17.7,
#       'bid': 17.6,
#       'change': 0.010000229,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00005000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 16.000005,
#       'inTheMoney': True,
#       'lastPrice': 17.87,
#       'lastTradeDate': 1484930558,
#       'openInterest': 261,
#       'percentChange': 0.055992324,
#       'strike': 5.0,
#       'volume': 210},
#      {'ask': 10.85,
#       'bid': 10.3,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00006000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 10.4,
#       'lastTradeDate': 1476885202,
#       'openInterest': 2,
#       'percentChange': 0.0,
#       'strike': 6.0,
#       'volume': 2},
#      {'ask': 15.7,
#       'bid': 15.6,
#       'change': 2.4499998,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00007000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 12.562502148437503,
#       'inTheMoney': True,
#       'lastPrice': 15.8,
#       'lastTradeDate': 1484931768,
#       'openInterest': 60,
#       'percentChange': 18.352058,
#       'strike': 7.0,
#       'volume': 60},
#      {'ask': 14.85,
#       'bid': 14.6,
#       'change': 0.22999954,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00008000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 12.375002265625001,
#       'inTheMoney': True,
#       'lastPrice': 14.75,
#       'lastTradeDate': 1484934699,
#       'openInterest': 2406,
#       'percentChange': 1.5840187,
#       'strike': 8.0,
#       'volume': 3},
#      {'ask': 13.95,
#       'bid': 13.6,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00009000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 11.671877705078124,
#       'inTheMoney': True,
#       'lastPrice': 13.28,
#       'lastTradeDate': 1484750915,
#       'openInterest': 187,
#       'percentChange': 0.0,
#       'strike': 9.0,
#       'volume': 40},
#      {'ask': 12.75,
#       'bid': 12.6,
#       'change': 0.21000004,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00010000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 9.343754160156251,
#       'inTheMoney': True,
#       'lastPrice': 12.75,
#       'lastTradeDate': 1484937029,
#       'openInterest': 10169,
#       'percentChange': 1.6746415,
#       'strike': 10.0,
#       'volume': 1026},
#      {'ask': 11.85,
#       'bid': 11.6,
#       'change': 0.09999943,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00011000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 8.921879423828123,
#       'inTheMoney': True,
#       'lastPrice': 11.7,
#       'lastTradeDate': 1484925081,
#       'openInterest': 569,
#       'percentChange': 0.862064,
#       'strike': 11.0,
#       'volume': 10},
#      {'ask': 10.95,
#       'bid': 10.6,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00012000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 8.421879736328123,
#       'inTheMoney': True,
#       'lastPrice': 10.47,
#       'lastTradeDate': 1484751464,
#       'openInterest': 443,
#       'percentChange': 0.0,
#       'strike': 12.0,
#       'volume': 202},
#      {'ask': 9.7,
#       'bid': 9.6,
#       'change': 0.19999981,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00013000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 6.4062519921875,
#       'inTheMoney': True,
#       'lastPrice': 9.72,
#       'lastTradeDate': 1484937284,
#       'openInterest': 22174,
#       'percentChange': 2.1008382,
#       'strike': 13.0,
#       'volume': 7940},
#      {'ask': 8.8,
#       'bid': 8.6,
#       'change': 0.29999924,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00014000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 6.109377363281249,
#       'inTheMoney': True,
#       'lastPrice': 8.9,
#       'lastTradeDate': 1484928764,
#       'openInterest': 2984,
#       'percentChange': 3.488363,
#       'strike': 14.0,
#       'volume': 33},
#      {'ask': 7.7,
#       'bid': 7.55,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00014500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 7.45,
#       'lastTradeDate': 1483038300,
#       'openInterest': 31,
#       'percentChange': 0.0,
#       'strike': 14.5,
#       'volume': 32},
#      {'ask': 7.7,
#       'bid': 7.6,
#       'change': 0.26000023,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00015000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 4.968753789062499,
#       'inTheMoney': True,
#       'lastPrice': 7.78,
#       'lastTradeDate': 1484936614,
#       'openInterest': 62057,
#       'percentChange': 3.4574497,
#       'strike': 15.0,
#       'volume': 3349},
#      {'ask': 7.55,
#       'bid': 7.45,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00015500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 6.671876660156251,
#       'inTheMoney': True,
#       'lastPrice': 7.5,
#       'lastTradeDate': 1484166763,
#       'openInterest': 144,
#       'percentChange': 0.0,
#       'strike': 15.5,
#       'volume': 13},
#      {'ask': 6.7,
#       'bid': 6.6,
#       'change': 0.13000011,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00016000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 4.312504609374999,
#       'inTheMoney': True,
#       'lastPrice': 6.65,
#       'lastTradeDate': 1484938193,
#       'openInterest': 57553,
#       'percentChange': 1.9938668,
#       'strike': 16.0,
#       'volume': 594},
#      {'ask': 6.55,
#       'bid': 6.45,
#       'change': 0.14999962,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00016500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 5.8437526953125,
#       'inTheMoney': True,
#       'lastPrice': 6.45,
#       'lastTradeDate': 1484333383,
#       'openInterest': 160,
#       'percentChange': 2.3809462,
#       'strike': 16.5,
#       'volume': 27},
#      {'ask': 5.65,
#       'bid': 5.6,
#       'change': 0.119999886,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00017000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 3.4843762890625003,
#       'inTheMoney': True,
#       'lastPrice': 5.64,
#       'lastTradeDate': 1484939018,
#       'openInterest': 297263,
#       'percentChange': 2.173911,
#       'strike': 17.0,
#       'volume': 5501},
#      {'ask': 5.55,
#       'bid': 5.45,
#       'change': 0.25,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00017500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 5.039066201171874,
#       'inTheMoney': True,
#       'lastPrice': 5.6,
#       'lastTradeDate': 1484326813,
#       'openInterest': 107,
#       'percentChange': 4.6728973,
#       'strike': 17.5,
#       'volume': 119},
#      {'ask': 4.85,
#       'bid': 4.6,
#       'change': 0.17999983,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00018000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 3.50000125,
#       'inTheMoney': True,
#       'lastPrice': 4.71,
#       'lastTradeDate': 1484935875,
#       'openInterest': 115233,
#       'percentChange': 3.973506,
#       'strike': 18.0,
#       'volume': 1510},
#      {'ask': 4.15,
#       'bid': 4.1,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00018500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.6250034375,
#       'inTheMoney': True,
#       'lastPrice': 4.0,
#       'lastTradeDate': 1484839061,
#       'openInterest': 188,
#       'percentChange': 0.0,
#       'strike': 18.5,
#       'volume': 12},
#      {'ask': 3.65,
#       'bid': 3.6,
#       'change': 0.13000011,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00019000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.3437541406249993,
#       'inTheMoney': True,
#       'lastPrice': 3.65,
#       'lastTradeDate': 1484938013,
#       'openInterest': 222897,
#       'percentChange': 3.693185,
#       'strike': 19.0,
#       'volume': 239},
#      {'ask': 3.2,
#       'bid': 3.15,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00019500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.3125042187499996,
#       'inTheMoney': True,
#       'lastPrice': 2.98,
#       'lastTradeDate': 1484839056,
#       'openInterest': 1241,
#       'percentChange': 0.0,
#       'strike': 19.5,
#       'volume': 46},
#      {'ask': 2.64,
#       'bid': 2.63,
#       'change': 0.13000011,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00020000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.8359383203124997,
#       'inTheMoney': True,
#       'lastPrice': 2.66,
#       'lastTradeDate': 1484938867,
#       'openInterest': 219659,
#       'percentChange': 5.1383443,
#       'strike': 20.0,
#       'volume': 12286},
#      {'ask': 2.14,
#       'bid': 2.13,
#       'change': 0.29999995,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00020500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.5468772656249998,
#       'inTheMoney': True,
#       'lastPrice': 2.32,
#       'lastTradeDate': 1484931737,
#       'openInterest': 2403,
#       'percentChange': 14.851482,
#       'strike': 20.5,
#       'volume': 15},
#      {'ask': 1.64,
#       'bid': 1.63,
#       'change': 0.14999998,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00021000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.2578162109375,
#       'inTheMoney': True,
#       'lastPrice': 1.66,
#       'lastTradeDate': 1484938858,
#       'openInterest': 89307,
#       'percentChange': 9.933773,
#       'strike': 21.0,
#       'volume': 3239},
#      {'ask': 1.14,
#       'bid': 1.12,
#       'change': 0.24000001,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00021500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.945313046875,
#       'inTheMoney': True,
#       'lastPrice': 1.27,
#       'lastTradeDate': 1484936664,
#       'openInterest': 6260,
#       'percentChange': 23.300972,
#       'strike': 21.5,
#       'volume': 2032},
#      {'ask': 0.64,
#       'bid': 0.63,
#       'change': 0.110000014,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00022000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.64062859375,
#       'inTheMoney': True,
#       'lastPrice': 0.64,
#       'lastTradeDate': 1484939029,
#       'openInterest': 230140,
#       'percentChange': 20.75472,
#       'strike': 22.0,
#       'volume': 14261},
#      {'ask': 0.15,
#       'bid': 0.15,
#       'change': -0.019999996,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00022500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.28516339843749994,
#       'inTheMoney': True,
#       'lastPrice': 0.15,
#       'lastTradeDate': 1484939107,
#       'openInterest': 36166,
#       'percentChange': -11.764703,
#       'strike': 22.5,
#       'volume': 29443},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.02,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00023000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.26563234375,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484938326,
#       'openInterest': 177033,
#       'percentChange': -66.66667,
#       'strike': 23.0,
#       'volume': 34050},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00023500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.4687553125,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484936828,
#       'openInterest': 32426,
#       'percentChange': 0.0,
#       'strike': 23.5,
#       'volume': 138},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00024000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.5937540625000001,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484936879,
#       'openInterest': 88070,
#       'percentChange': 0.0,
#       'strike': 24.0,
#       'volume': 125},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': -0.07,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00024500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.8125018749999999,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484340149,
#       'openInterest': 15005,
#       'percentChange': -87.5,
#       'strike': 24.5,
#       'volume': 23072},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.03,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00025000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.87500125,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484340447,
#       'openInterest': 133741,
#       'percentChange': -75.0,
#       'strike': 25.0,
#       'volume': 3059},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.02,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00025500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0312548437500002,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484323358,
#       'openInterest': 35301,
#       'percentChange': -66.66667,
#       'strike': 25.5,
#       'volume': 268},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00026000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.1875040625,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484318201,
#       'openInterest': 29812,
#       'percentChange': -50.0,
#       'strike': 26.0,
#       'volume': 2},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00026500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.4375028125,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1483563510,
#       'openInterest': 647,
#       'percentChange': 0.0,
#       'strike': 26.5,
#       'volume': 14},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00027000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.4375028125,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483730925,
#       'openInterest': 22851,
#       'percentChange': -50.0,
#       'strike': 27.0,
#       'volume': 446},
#      {'ask': 0.02,
#       'bid': 0.01,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00027500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.8125009374999999,
#       'inTheMoney': False,
#       'lastPrice': 0.03,
#       'lastTradeDate': 1482262814,
#       'openInterest': 211,
#       'percentChange': 0.0,
#       'strike': 27.5,
#       'volume': 105},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00028000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.8437507812499998,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483114158,
#       'openInterest': 3803,
#       'percentChange': -50.0,
#       'strike': 28.0,
#       'volume': 10},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00029000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.0625048437499998,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1482338643,
#       'openInterest': 1755,
#       'percentChange': 0.0,
#       'strike': 29.0,
#       'volume': 10},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00029500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.000005,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1482554706,
#       'openInterest': 165,
#       'percentChange': 0.0,
#       'strike': 29.5,
#       'volume': 155},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00030000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.1250046874999997,
#       'inTheMoney': False,
#       'lastPrice': 0.03,
#       'lastTradeDate': 1484836227,
#       'openInterest': 41890,
#       'percentChange': 0.0,
#       'strike': 30.0,
#       'volume': 20},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00030500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.2500043749999996,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483159928,
#       'openInterest': 50,
#       'percentChange': 0.0,
#       'strike': 30.5,
#       'volume': 40},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00031000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.56250359375,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1481950427,
#       'openInterest': 70,
#       'percentChange': 0.0,
#       'strike': 31.0,
#       'volume': 77},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120C00032000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.56250359375,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1482849755,
#       'openInterest': 10,
#       'percentChange': 0.0,
#       'strike': 32.0,
#       'volume': 5}],
#     'expirationDate': 1484870400,
#     'hasMiniOptions': False,
#     'puts': [{'ask': 0.02,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00005000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 11.25000296875,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1472240413,
#       'openInterest': 37092,
#       'percentChange': -50.0,
#       'strike': 5.0,
#       'volume': 200},
#      {'ask': 0.02,
#       'bid': 0.01,
#       'change': 0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00006000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 10.375003515625002,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1471536077,
#       'openInterest': 3686,
#       'percentChange': 100.0,
#       'strike': 6.0,
#       'volume': 100},
#      {'ask': 0.02,
#       'bid': 0.01,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00007000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 9.25000421875,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1473185890,
#       'openInterest': 2538,
#       'percentChange': 0.0,
#       'strike': 7.0,
#       'volume': 100},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00008000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 7.2500009375,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1476714104,
#       'openInterest': 41423,
#       'percentChange': 0.0,
#       'strike': 8.0,
#       'volume': 20},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00009000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 7.00000125,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1478619748,
#       'openInterest': 11490,
#       'percentChange': -50.0,
#       'strike': 9.0,
#       'volume': 1},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00010000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 5.7500028125,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1478890672,
#       'openInterest': 110039,
#       'percentChange': 0.0,
#       'strike': 10.0,
#       'volume': 209},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00011000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 5.500003124999999,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1479329456,
#       'openInterest': 23258,
#       'percentChange': 0.0,
#       'strike': 11.0,
#       'volume': 164},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.02,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00012000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 4.500004375,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1479501105,
#       'openInterest': 36055,
#       'percentChange': -66.66667,
#       'strike': 12.0,
#       'volume': 55},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00013000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 4.000005,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1482524762,
#       'openInterest': 280696,
#       'percentChange': 0.0,
#       'strike': 13.0,
#       'volume': 11},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00014000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 3.50000125,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483036985,
#       'openInterest': 53475,
#       'percentChange': 0.0,
#       'strike': 14.0,
#       'volume': 15},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00015000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 3.0000025,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483634806,
#       'openInterest': 273307,
#       'percentChange': 0.0,
#       'strike': 15.0,
#       'volume': 40},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00016000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.6250034375,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484160718,
#       'openInterest': 35022,
#       'percentChange': 0.0,
#       'strike': 16.0,
#       'volume': 10},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00016500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.3750040624999995,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483764258,
#       'openInterest': 171,
#       'percentChange': 0.0,
#       'strike': 16.5,
#       'volume': 171},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00017000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.1875045312499997,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484840373,
#       'openInterest': 244973,
#       'percentChange': 0.0,
#       'strike': 17.0,
#       'volume': 8},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00017500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 2.1875045312499997,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483042332,
#       'openInterest': 8234,
#       'percentChange': 0.0,
#       'strike': 17.5,
#       'volume': 140},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00018000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.75000125,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483731773,
#       'openInterest': 36798,
#       'percentChange': 0.0,
#       'strike': 18.0,
#       'volume': 110},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00018500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.75000125,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1483559058,
#       'openInterest': 882,
#       'percentChange': 0.0,
#       'strike': 18.5,
#       'volume': 75},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00019000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.3750031249999999,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484328548,
#       'openInterest': 43266,
#       'percentChange': -50.0,
#       'strike': 19.0,
#       'volume': 1615},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00019500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.1875040625,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1484243723,
#       'openInterest': 919,
#       'percentChange': 0.0,
#       'strike': 19.5,
#       'volume': 2},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00020000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.000005,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484927615,
#       'openInterest': 136054,
#       'percentChange': 0.0,
#       'strike': 20.0,
#       'volume': 30},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00020500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.8125018749999999,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484773183,
#       'openInterest': 4852,
#       'percentChange': 0.0,
#       'strike': 20.5,
#       'volume': 50},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00021000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.6250037500000001,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484938917,
#       'openInterest': 59518,
#       'percentChange': 0.0,
#       'strike': 21.0,
#       'volume': 41},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00021500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.51562984375,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484935001,
#       'openInterest': 15254,
#       'percentChange': 0.0,
#       'strike': 21.5,
#       'volume': 175},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.02,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00022000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.29688203124999996,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484938569,
#       'openInterest': 186302,
#       'percentChange': -66.66667,
#       'strike': 22.0,
#       'volume': 571},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': -0.11,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00022500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 0.07032179687500001,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484939152,
#       'openInterest': 54055,
#       'percentChange': -91.66667,
#       'strike': 22.5,
#       'volume': 9206},
#      {'ask': 0.37,
#       'bid': 0.36,
#       'change': -0.13999999,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00023000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 0.36,
#       'lastTradeDate': 1484938765,
#       'openInterest': 53142,
#       'percentChange': -27.999996,
#       'strike': 23.0,
#       'volume': 8788},
#      {'ask': 0.87,
#       'bid': 0.86,
#       'change': -0.07999998,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00023500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 0.86,
#       'lastTradeDate': 1484938833,
#       'openInterest': 2312,
#       'percentChange': -8.510636,
#       'strike': 23.5,
#       'volume': 387},
#      {'ask': 1.87,
#       'bid': 1.86,
#       'change': -0.3499999,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00024500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 1.7,
#       'lastTradeDate': 1484932216,
#       'openInterest': 1501,
#       'percentChange': -17.073166,
#       'strike': 24.5,
#       'volume': 10},
#      {'ask': 2.37,
#       'bid': 2.36,
#       'change': -0.13000011,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00025000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 2.35,
#       'lastTradeDate': 1484938315,
#       'openInterest': 19484,
#       'percentChange': -5.24194,
#       'strike': 25.0,
#       'volume': 223},
#      {'ask': 2.87,
#       'bid': 2.86,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00025500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 3.0,
#       'lastTradeDate': 1484839061,
#       'openInterest': 310,
#       'percentChange': 0.0,
#       'strike': 25.5,
#       'volume': 2},
#      {'ask': 3.4,
#       'bid': 3.35,
#       'change': -0.4000001,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00026000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 3.32,
#       'lastTradeDate': 1484924748,
#       'openInterest': 605,
#       'percentChange': -10.75269,
#       'strike': 26.0,
#       'volume': 70},
#      {'ask': 3.9,
#       'bid': 3.85,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00026500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 4.0,
#       'lastTradeDate': 1484839061,
#       'openInterest': 47,
#       'percentChange': 0.0,
#       'strike': 26.5,
#       'volume': 8},
#      {'ask': 4.05,
#       'bid': 3.95,
#       'change': -0.25,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00027000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 3.9,
#       'lastTradeDate': 1484322511,
#       'openInterest': 603,
#       'percentChange': -6.024096,
#       'strike': 27.0,
#       'volume': 1},
#      {'ask': 4.55,
#       'bid': 4.45,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00027500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 4.55,
#       'lastTradeDate': 1484074867,
#       'openInterest': 11,
#       'percentChange': 0.0,
#       'strike': 27.5,
#       'volume': 10},
#      {'ask': 5.05,
#       'bid': 4.95,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00028000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 5.0,
#       'lastTradeDate': 1484068828,
#       'openInterest': 180,
#       'percentChange': 0.0,
#       'strike': 28.0,
#       'volume': 10},
#      {'ask': 5.85,
#       'bid': 5.75,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00028500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 5.8,
#       'lastTradeDate': 1483545990,
#       'openInterest': 23,
#       'percentChange': 0.0,
#       'strike': 28.5,
#       'volume': 22},
#      {'ask': 6.35,
#       'bid': 6.25,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00029000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 6.16,
#       'lastTradeDate': 1483626950,
#       'openInterest': 122,
#       'percentChange': 0.0,
#       'strike': 29.0,
#       'volume': 7},
#      {'ask': 7.4,
#       'bid': 7.3,
#       'change': 0.25,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00029500',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 4.500004375,
#       'inTheMoney': True,
#       'lastPrice': 7.45,
#       'lastTradeDate': 1483108656,
#       'openInterest': 71,
#       'percentChange': 3.4722223,
#       'strike': 29.5,
#       'volume': 16},
#      {'ask': 7.4,
#       'bid': 7.05,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00030000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 7.92,
#       'lastTradeDate': 1484683974,
#       'openInterest': 566,
#       'percentChange': 0.0,
#       'strike': 30.0,
#       'volume': 2},
#      {'ask': 8.9,
#       'bid': 8.8,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00031000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 5.039066201171874,
#       'inTheMoney': True,
#       'lastPrice': 9.05,
#       'lastTradeDate': 1483040040,
#       'openInterest': 293,
#       'percentChange': 0.0,
#       'strike': 31.0,
#       'volume': 170},
#      {'ask': 9.4,
#       'bid': 9.3,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170120P00032000',
#       'currency': 'USD',
#       'expiration': 1484870400,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 9.68,
#       'lastTradeDate': 1484674693,
#       'openInterest': 83,
#       'percentChange': 0.0,
#       'strike': 32.0,
#       'volume': 18}]}],
#   'quote': {'ask': 0.0,
#    'askSize': 0,
#    'averageDailyVolume10Day': 118337914,
#    'averageDailyVolume3Month': 119729733,
#    'bid': 0.0,
#    'bidSize': 0,
#    'bookValue': 24.187,
#    'currency': 'USD',
#    'dividendDate': 1483056000,
#    'earningsTimestamp': 1484332200,
#    'earningsTimestampEnd': 1492446600,
#    'earningsTimestampStart': 1492014600,
#    'epsForward': 1.62,
#    'epsTrailingTwelveMonths': 1.367,
#    'exchange': 'NYQ',
#    'exchangeTimezoneName': 'America/New_York',
#    'exchangeTimezoneShortName': 'EST',
#    'fiftyDayAverage': 22.53303,
#    'fiftyDayAverageChange': -0.0030288696,
#    'fiftyDayAverageChangePercent': -0.0001344191,
#    'fiftyTwoWeekHigh': 23.41,
#    'fiftyTwoWeekHighChange': -0.87999916,
#    'fiftyTwoWeekHighChangePercent': -0.03759074,
#    'fiftyTwoWeekLow': 10.99,
#    'fiftyTwoWeekLowChange': 11.540001,
#    'fiftyTwoWeekLowChangePercent': 1.0500456,
#    'forwardPE': 13.907408,
#    'fullExchangeName': 'NYSE',
#    'gmtOffSetMilliseconds': -18000000,
#    'longName': 'Bank of America Corporation',
#    'market': 'us_market',
#    'marketCap': 227665657856,
#    'marketState': 'REGULAR',
#    'messageBoardId': 'finmb_19049',
#    'priceToBook': 0.93149215,
#    'quoteSourceName': 'NYSE Real Time Price',
#    'quoteType': 'EQUITY',
#    'regularMarketChange': 0.0,
#    'regularMarketChangePercent': 0.0,
#    'regularMarketDayHigh': 22.93,
#    'regularMarketDayLow': 22.53,
#    'regularMarketOpen': 22.66,
#    'regularMarketPreviousClose': 22.53,
#    'regularMarketPrice': 22.53,
#    'regularMarketTime': 1484940172,
#    'regularMarketVolume': 74321927,
#    'sharesOutstanding': 10105000000,
#    'shortName': 'Bank of America Corporation Com',
#    'sourceInterval': 15,
#    'symbol': 'BAC',
#    'trailingAnnualDividendRate': 0.225,
#    'trailingPE': 16.481346,
#    'twoHundredDayAverage': 17.578623,
#    'twoHundredDayAverageChange': 4.951378,
#    'twoHundredDayAverageChangePercent': 0.28167042},
#   'strikes': [5.0,
#    6.0,
#    7.0,
#    8.0,
#    9.0,
#    10.0,
#    11.0,
#    12.0,
#    13.0,
#    14.0,
#    14.5,
#    15.0,
#    15.5,
#    16.0,
#    16.5,
#    17.0,
#    17.5,
#    18.0,
#    18.5,
#    19.0,
#    19.5,
#    20.0,
#    20.5,
#    21.0,
#    21.5,
#    22.0,
#    22.5,
#    23.0,
#    23.5,
#    24.0,
#    24.5,
#    25.0,
#    25.5,
#    26.0,
#    26.5,
#    27.0,
#    27.5,
#    28.0,
#    28.5,
#    29.0,
#    29.5,
#    30.0,
#    30.5,
#    31.0,
#    32.0],
#   'underlyingSymbol': 'BAC'}]

# %%
result = results[0]
dates = [dt.fromtimestamp(tm) for tm in result['expirationDates']]
# we can use these dates to get data for a specific expiration date
# an example url: https://query1.finance.yahoo.com/v7/finance/options/BAC?date=1484265600 
# the first date is default
dates
# Out:
# [datetime.datetime(2017, 1, 20, 2, 0),
#  datetime.datetime(2017, 1, 27, 2, 0),
#  datetime.datetime(2017, 2, 3, 2, 0),
#  datetime.datetime(2017, 2, 10, 2, 0),
#  datetime.datetime(2017, 2, 17, 2, 0),
#  datetime.datetime(2017, 2, 24, 2, 0),
#  datetime.datetime(2017, 3, 3, 2, 0),
#  datetime.datetime(2017, 3, 17, 2, 0),
#  datetime.datetime(2017, 4, 21, 3, 0),
#  datetime.datetime(2017, 5, 19, 3, 0),
#  datetime.datetime(2017, 6, 16, 3, 0),
#  datetime.datetime(2017, 8, 18, 3, 0),
#  datetime.datetime(2017, 12, 15, 2, 0),
#  datetime.datetime(2018, 1, 19, 2, 0),
#  datetime.datetime(2019, 1, 18, 2, 0)]

# %%
option = result['options'][0]
calls = option['calls']
calls[:2]
# Out:
# [{'ask': 17.7,
#   'bid': 17.6,
#   'change': 0.010000229,
#   'contractSize': 'REGULAR',
#   'contractSymbol': 'BAC170120C00005000',
#   'currency': 'USD',
#   'expiration': 1484870400,
#   'impliedVolatility': 16.000005,
#   'inTheMoney': True,
#   'lastPrice': 17.87,
#   'lastTradeDate': 1484930558,
#   'openInterest': 261,
#   'percentChange': 0.055992324,
#   'strike': 5.0,
#   'volume': 210},
#  {'ask': 10.85,
#   'bid': 10.3,
#   'change': 0.0,
#   'contractSize': 'REGULAR',
#   'contractSymbol': 'BAC170120C00006000',
#   'currency': 'USD',
#   'expiration': 1484870400,
#   'impliedVolatility': 1.0000000000000003e-05,
#   'inTheMoney': True,
#   'lastPrice': 10.4,
#   'lastTradeDate': 1476885202,
#   'openInterest': 2,
#   'percentChange': 0.0,
#   'strike': 6.0,
#   'volume': 2}]

# %%
puts = option['puts']
puts[-2:]
# Out:
# [{'ask': 8.9,
#   'bid': 8.8,
#   'change': 0.0,
#   'contractSize': 'REGULAR',
#   'contractSymbol': 'BAC170120P00031000',
#   'currency': 'USD',
#   'expiration': 1484870400,
#   'impliedVolatility': 5.039066201171874,
#   'inTheMoney': True,
#   'lastPrice': 9.05,
#   'lastTradeDate': 1483040040,
#   'openInterest': 293,
#   'percentChange': 0.0,
#   'strike': 31.0,
#   'volume': 170},
#  {'ask': 9.4,
#   'bid': 9.3,
#   'change': 0.0,
#   'contractSize': 'REGULAR',
#   'contractSymbol': 'BAC170120P00032000',
#   'currency': 'USD',
#   'expiration': 1484870400,
#   'impliedVolatility': 1.0000000000000003e-05,
#   'inTheMoney': True,
#   'lastPrice': 9.68,
#   'lastTradeDate': 1484674693,
#   'openInterest': 83,
#   'percentChange': 0.0,
#   'strike': 32.0,
#   'volume': 18}]

# %% [markdown]
# # Implementation

# %%
# There is a lot of data to load every minute, so we have to do this in parrallel
# 'threading' module fits well for this purpose
# I'm going to use two queues to connect our main programm and thread workers: 
# the first is for tasks, the other - for results
# You can find some examples of using 'queue'-module here
# https://docs.python.org/3/library/queue.html#queue.Queue.join
import queue
import requests
import threading


def load_data(time):
    
    num_worker_threads = 10
    
    def worker():
        while True:
            args = q.get()
            if args is None:
                break
            get_transactions(q, r, *args)  # <-- see definition of this function below
            q.task_done()

    q = queue.Queue() # queue with arguments for the 'get_transactions' function
    r = queue.Queue() # queue with raw responses

    threads = []
    for i in range(num_worker_threads):
        t = threading.Thread(target=worker)
        t.start()
        threads.append(t)

    for stock in STOCKS:
        q.put((stock, None))

    # block until all tasks are done
    q.join()

    # stop workers
    for i in range(num_worker_threads):
        q.put(None)

    for t in threads:
        t.join()
        
    save_rows(r, time)
    
    
def get_transactions(queue, resp_queue, stock, date=None):     
    base_url = "https://query1.finance.yahoo.com/v7/finance/options/{}".format(stock)
    if date is not None:
        url = "{}?date={}".format(base_url, date)
    else:
        url = base_url
    try:
        page = requests.get(url)
    except Exception as e:
        print(e)
    else:
        response = page.json()
        if response['optionChain']['error']: # if any error
            print(response['optionChain']['error'])

        else:
            results = response['optionChain']['result']
            for result in results:
                price = result['quote']['regularMarketPrice']
                for option in result['options']:
                    resp_queue.put(
                        (stock, price, option['calls'], option['puts'])
                    )

                if date is None:
                    for tm in result['expirationDates'][1:]:
                        queue.put((stock, tm))

# %%
# Functions which take response from the response queue and put to the 'largest_transactions' list
def save_rows(q, time):
    global largest_transactions
    while True:
        try:
            stock, price, calls, puts = q.get(block=False)
        except queue.Empty:
            break
        else:
            for call in calls:
                save_row(stock, price, 'Calls', time, call)
            for put in puts:
                save_row(stock, price, 'Puts', time, put)

def save_row(s, price, t, time, raw):
    contact = raw['contractSymbol']    
    previous_volume = transaction_volumes.get(contact)
    volume = raw['volume']
    transaction_volumes[contact] = volume
    
    if previous_volume is not None:        
        volume_diff = volume - previous_volume
        if volume_diff > 0:
            last_price = raw['lastPrice']
            strike = raw['strike']
            ask = raw['ask']
            bid = raw['bid']
            largest_transactions.append(
                dict(
                    stock=s,
                    price=price,
                    type=t,
                    time=time,
                    expiration=dt.fromtimestamp(raw['expiration']),
                    strike=strike,
                    contact=contact,
                    last_price=last_price,
                    bid=bid,
                    ask=ask,
                    volume=volume,
                    open_interest=raw['openInterest'],
                    implied_volatility=raw['impliedVolatility'],
                    volume_diff=volume_diff,
                    cost=volume_diff * last_price,
                    strike_div_price=(strike / price - 1) * 100,
                    last_price_position=(1 - (ask-last_price) / (ask-bid)) * 100 if ask != bid else None
                )
            )

# %%
# This function will display the table
from IPython.display import clear_output, display, HTML

headers = (
    "Stock", "Share price", "Options", "Volume", "Strike", "Strike /Share price", 
    "Expiration", "Last price", "Bid", "Ask", "Last price position",  "Value", "Time of trade",
)
row = """
<td>{stock}</td><td>{price}</td><td>{type}</td><td>{volume_diff}</td>
<td>{strike}</td><td>{strike_div_price:.2f}%</td><td>{expiration:%b %d, %Y}</td>
<td>{last_price}</td><td>{bid}</td><td>{ask}</td><td>{last_price_position:.0f}%</td>
<td>${cost:,.2f}</td><td>{time:%I:%M%p}</td>
"""

def display_data():    
    table_rows = (row.format(**row_data) for row_data in largest_transactions)           
    clear_output()
    display(
        HTML(
            '<table><tr><th>{}</th></tr><tr>{}</tr></table>'.format(
                "</th><th>".join(headers),
                "</tr><tr>".join(table_rows)
            )
        )
    )

# %%
from datetime import datetime as dt, timedelta as td
from pytz import timezone
from time import sleep
import heapq

tz = timezone('America/Los_Angeles')  # timezone produces time with PST or PDT tzname depending on the date
STOCKS = ['AAPL', 'BAC', 'NVDA', 'AMZN', 'FB']

last_time = None
count = 1
largest_transactions = []  # here we will store top entries
transaction_volumes = {}  # latest volumes for transactions

while True:    
    now = dt.now(tz=tz)
    start = now.replace(hour=6, minute=30, second=0, microsecond=0)
    stop = start.replace(hour=13, minute=0)
    
    if start <= now <= stop: # proper time for getting data
        
        if last_time: # no more often than once per minute
            diff = 60 - (now - last_time).seconds            
            if diff > 0:
                sleep(diff)  
        
        # the main functionality
        load_data(now)
        # it's efficient way to keep only top 20 entries in the 'largest_transactions' list
        largest_transactions = heapq.nlargest(20, largest_transactions, key=lambda i: i['cost']) 
        display_data()
        
        # some statistics
        print("last update", now)
        print("prev update", last_time) 
        print("update time", dt.now(tz=tz) - now)
        print("iterations", count)
        count += 1
        
        last_time = now        
    else:
        largest_transactions = [] # drop transactions
        if now < start:
            diff = start - now
            print("time to start:", diff)
            
        else:
            start_tommorow = start + td(days=1)
            print("start tommorow at", start_tommorow)
            diff = start_tommorow - now
        
        sleep(diff.seconds + diff.microseconds * 0.1 ** 6)
# Out:
# <table><tr><th>Stock</th><th>Share price</th><th>Options</th><th>Volume</th><th>Strike</th><th>Strike /Share price</th><th>Expiration</th><th>Last price</th><th>Bid</th><th>Ask</th><th>Last price position</th><th>Value</th><th>Time of trade</th></tr><tr>
# <td>AAPL</td><td>119.9195</td><td>Calls</td><td>1279</td>
# <td>110.0</td><td>-8.27%</td><td>Jul 21, 2017</td>
# <td>12.65</td><td>12.6</td><td>12.75</td><td>33%</td>
# <td>$16,179.35</td><td>12:01PM</td>
# </tr><tr>
# <td>FB</td><td>127.22</td><td>Calls</td><td>274</td>
# <td>70.0</td><td>-44.98%</td><td>Jan 20, 2017</td>
# <td>57.0</td><td>56.9</td><td>57.0</td><td>100%</td>
# <td>$15,618.00</td><td>12:05PM</td>
# </tr><tr>
# <td>AAPL</td><td>119.89</td><td>Calls</td><td>4554</td>
# <td>130.0</td><td>8.43%</td><td>Jul 21, 2017</td>
# <td>2.63</td><td>2.62</td><td>2.65</td><td>33%</td>
# <td>$11,977.02</td><td>11:57AM</td>
# </tr><tr>
# <td>AAPL</td><td>119.795</td><td>Calls</td><td>200</td>
# <td>75.0</td><td>-37.39%</td><td>Jan 19, 2018</td>
# <td>45.05</td><td>45.0</td><td>45.2</td><td>25%</td>
# <td>$9,010.00</td><td>11:48AM</td>
# </tr><tr>
# <td>FB</td><td>126.9834</td><td>Calls</td><td>844</td>
# <td>120.0</td><td>-5.50%</td><td>Jan 20, 2017</td>
# <td>6.9</td><td>6.85</td><td>6.95</td><td>50%</td>
# <td>$5,823.60</td><td>11:43AM</td>
# </tr><tr>
# <td>AAPL</td><td>119.881</td><td>Calls</td><td>376</td>
# <td>105.0</td><td>-12.41%</td><td>Jan 20, 2017</td>
# <td>14.7</td><td>14.7</td><td>14.85</td><td>0%</td>
# <td>$5,527.20</td><td>11:54AM</td>
# </tr><tr>
# <td>AAPL</td><td>119.85</td><td>Calls</td><td>415</td>
# <td>115.0</td><td>-4.05%</td><td>Nov 17, 2017</td>
# <td>12.0</td><td>11.95</td><td>12.15</td><td>25%</td>
# <td>$4,980.00</td><td>11:33AM</td>
# </tr><tr>
# <td>AAPL</td><td>119.8559</td><td>Calls</td><td>500</td>
# <td>120.0</td><td>0.12%</td><td>Nov 17, 2017</td>
# <td>9.4</td><td>9.35</td><td>9.45</td><td>50%</td>
# <td>$4,700.00</td><td>11:32AM</td>
# </tr><tr>
# <td>FB</td><td>127.3001</td><td>Calls</td><td>237</td>
# <td>110.0</td><td>-13.59%</td><td>Mar 17, 2017</td>
# <td>17.94</td><td>17.95</td><td>18.1</td><td>-7%</td>
# <td>$4,251.78</td><td>12:10PM</td>
# </tr><tr>
# <td>AAPL</td><td>119.8454</td><td>Calls</td><td>406</td>
# <td>110.0</td><td>-8.22%</td><td>Jan 20, 2017</td>
# <td>9.86</td><td>9.8</td><td>9.9</td><td>60%</td>
# <td>$4,003.16</td><td>11:34AM</td>
# </tr><tr>
# <td>BAC</td><td>22.595</td><td>Puts</td><td>11023</td>
# <td>22.0</td><td>-2.63%</td><td>Feb 17, 2017</td>
# <td>0.35</td><td>0.35</td><td>0.37</td><td>0%</td>
# <td>$3,858.05</td><td>11:42AM</td>
# </tr><tr>
# <td>FB</td><td>126.8641</td><td>Calls</td><td>539</td>
# <td>120.0</td><td>-5.41%</td><td>Jan 20, 2017</td>
# <td>6.8</td><td>6.9</td><td>7.0</td><td>-100%</td>
# <td>$3,665.20</td><td>11:39AM</td>
# </tr><tr>
# <td>AMZN</td><td>808.105</td><td>Calls</td><td>50</td>
# <td>750.0</td><td>-7.19%</td><td>Jan 20, 2017</td>
# <td>58.0</td><td>57.9</td><td>58.45</td><td>18%</td>
# <td>$2,900.00</td><td>11:44AM</td>
# </tr><tr>
# <td>AAPL</td><td>119.9341</td><td>Calls</td><td>3541</td>
# <td>120.0</td><td>0.05%</td><td>Jan 27, 2017</td>
# <td>0.81</td><td>0.81</td><td>0.83</td><td>0%</td>
# <td>$2,868.21</td><td>12:03PM</td>
# </tr><tr>
# <td>AAPL</td><td>119.83</td><td>Calls</td><td>235</td>
# <td>115.0</td><td>-4.03%</td><td>Nov 17, 2017</td>
# <td>12.05</td><td>12.0</td><td>12.1</td><td>50%</td>
# <td>$2,831.75</td><td>11:28AM</td>
# </tr><tr>
# <td>BAC</td><td>22.6301</td><td>Calls</td><td>6851</td>
# <td>23.0</td><td>1.63%</td><td>Feb 17, 2017</td>
# <td>0.41</td><td>0.4</td><td>0.41</td><td>100%</td>
# <td>$2,808.91</td><td>12:01PM</td>
# </tr><tr>
# <td>FB</td><td>127.22</td><td>Calls</td><td>158</td>
# <td>110.0</td><td>-13.54%</td><td>Jan 20, 2017</td>
# <td>17.0</td><td>16.95</td><td>17.05</td><td>50%</td>
# <td>$2,686.00</td><td>12:05PM</td>
# </tr><tr>
# <td>AMZN</td><td>808.015</td><td>Puts</td><td>26</td>
# <td>830.0</td><td>2.72%</td><td>Jan 19, 2018</td>
# <td>100.0</td><td>99.05</td><td>100.5</td><td>66%</td>
# <td>$2,600.00</td><td>11:52AM</td>
# </tr><tr>
# <td>AAPL</td><td>119.9199</td><td>Calls</td><td>40</td>
# <td>55.0</td><td>-54.14%</td><td>Jan 19, 2018</td>
# <td>64.81</td><td>64.55</td><td>64.9</td><td>74%</td>
# <td>$2,592.40</td><td>11:54AM</td>
# </tr><tr>
# <td>FB</td><td>127.2901</td><td>Calls</td><td>142</td>
# <td>110.0</td><td>-13.58%</td><td>Jan 20, 2017</td>
# <td>17.1</td><td>17.1</td><td>17.15</td><td>0%</td>
# <td>$2,428.20</td><td>12:10PM</td>
# </tr></table>
# last update 2017-01-20 12:10:20.529878-08:00
# prev update 2017-01-20 12:10:13.442580-08:00
# update time 0:01:00.103256
# iterations 84
