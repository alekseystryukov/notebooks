# %%
from datetime import datetime as dt, timedelta as td
import requests

# %%
url = "https://query1.finance.yahoo.com/v7/finance/options/BAC"
#?formatted=true&crumb=bCkXlpLUQ.w&lang=en-US&region=US&date=1484265600&corsDomain=finance.yahoo.com

# %%
page = requests.get(url)
response = page.json()
if response['optionChain']['error']:
    print(response['optionChain']['error'])

results = response['optionChain']['result']
results
# Out:
# [{'expirationDates': [1485475200,
#    1486080000,
#    1486684800,
#    1487289600,
#    1487894400,
#    1488499200,
#    1489708800,
#    1492732800,
#    1495152000,
#    1497571200,
#    1503014400,
#    1510876800,
#    1513296000,
#    1516320000,
#    1547769600],
#   'hasMiniOptions': False,
#   'options': [{'calls': [{'ask': 7.25,
#       'bid': 7.05,
#       'change': 0.39999962,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00015500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 7.2,
#       'lastTradeDate': 1484929103,
#       'openInterest': 7,
#       'percentChange': 5.882347,
#       'strike': 15.5,
#       'volume': 8},
#      {'ask': 7.8,
#       'bid': 6.85,
#       'change': 0.5999999,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00016000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 3.7890630273437504,
#       'inTheMoney': True,
#       'lastPrice': 7.1,
#       'lastTradeDate': 1484321104,
#       'openInterest': 4,
#       'percentChange': 9.230768,
#       'strike': 16.0,
#       'volume': 43},
#      {'ask': 6.05,
#       'bid': 5.95,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00017000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 6.25,
#       'lastTradeDate': 1484369490,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 17.0,
#       'volume': 39},
#      {'ask': 5.55,
#       'bid': 5.45,
#       'change': 0.4499998,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00017500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 5.6,
#       'lastTradeDate': 1484326813,
#       'openInterest': 89,
#       'percentChange': 8.73786,
#       'strike': 17.5,
#       'volume': 82},
#      {'ask': 5.05,
#       'bid': 4.95,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00018000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 5.3,
#       'lastTradeDate': 1484369490,
#       'openInterest': 61,
#       'percentChange': 0.0,
#       'strike': 18.0,
#       'volume': 6},
#      {'ask': 4.55,
#       'bid': 4.45,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00018500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 4.45,
#       'lastTradeDate': 1484369490,
#       'openInterest': 37,
#       'percentChange': 0.0,
#       'strike': 18.5,
#       'volume': 135},
#      {'ask': 4.4,
#       'bid': 4.2,
#       'change': 0.3000002,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00019000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.359378203125,
#       'inTheMoney': True,
#       'lastPrice': 4.36,
#       'lastTradeDate': 1485354917,
#       'openInterest': 102,
#       'percentChange': 7.389168,
#       'strike': 19.0,
#       'volume': 4},
#      {'ask': 3.85,
#       'bid': 3.8,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00019500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.500005,
#       'inTheMoney': True,
#       'lastPrice': 3.15,
#       'lastTradeDate': 1485181984,
#       'openInterest': 53,
#       'percentChange': 0.0,
#       'strike': 19.5,
#       'volume': 11},
#      {'ask': 3.35,
#       'bid': 3.3,
#       'change': 0.25,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00020000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.500005,
#       'inTheMoney': True,
#       'lastPrice': 3.25,
#       'lastTradeDate': 1485361947,
#       'openInterest': 1031,
#       'percentChange': 8.333334,
#       'strike': 20.0,
#       'volume': 20},
#      {'ask': 2.86,
#       'bid': 2.85,
#       'change': 0.23000002,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00020500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.6250037500000001,
#       'inTheMoney': True,
#       'lastPrice': 2.7,
#       'lastTradeDate': 1485357396,
#       'openInterest': 141,
#       'percentChange': 9.311742,
#       'strike': 20.5,
#       'volume': 26},
#      {'ask': 2.35,
#       'bid': 2.34,
#       'change': 0.32999992,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00021000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.2500075,
#       'inTheMoney': True,
#       'lastPrice': 2.31,
#       'lastTradeDate': 1485364497,
#       'openInterest': 890,
#       'percentChange': 16.666662,
#       'strike': 21.0,
#       'volume': 74},
#      {'ask': 1.86,
#       'bid': 1.85,
#       'change': 0.20000005,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00021500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.4687553125,
#       'inTheMoney': True,
#       'lastPrice': 1.7,
#       'lastTradeDate': 1485357396,
#       'openInterest': 824,
#       'percentChange': 13.333337,
#       'strike': 21.5,
#       'volume': 15},
#      {'ask': 1.36,
#       'bid': 1.34,
#       'change': 0.36,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00022000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.35938140625,
#       'inTheMoney': True,
#       'lastPrice': 1.34,
#       'lastTradeDate': 1485365408,
#       'openInterest': 5725,
#       'percentChange': 36.734695,
#       'strike': 22.0,
#       'volume': 2173},
#      {'ask': 0.86,
#       'bid': 0.85,
#       'change': 0.34000003,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00022500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.242195078125,
#       'inTheMoney': True,
#       'lastPrice': 0.85,
#       'lastTradeDate': 1485365615,
#       'openInterest': 23270,
#       'percentChange': 66.66667,
#       'strike': 22.5,
#       'volume': 4779},
#      {'ask': 0.41,
#       'bid': 0.4,
#       'change': 0.24000001,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00023000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.21875781249999998,
#       'inTheMoney': True,
#       'lastPrice': 0.4,
#       'lastTradeDate': 1485365371,
#       'openInterest': 45247,
#       'percentChange': 150.00002,
#       'strike': 23.0,
#       'volume': 28238},
#      {'ask': 0.11,
#       'bid': 0.1,
#       'change': 0.060000002,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00023500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.20703917968749996,
#       'inTheMoney': False,
#       'lastPrice': 0.1,
#       'lastTradeDate': 1485365588,
#       'openInterest': 38772,
#       'percentChange': 150.00002,
#       'strike': 23.5,
#       'volume': 17228},
#      {'ask': 0.02,
#       'bid': 0.01,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00024000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.22657023437499998,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1485365628,
#       'openInterest': 14537,
#       'percentChange': 0.0,
#       'strike': 24.0,
#       'volume': 1697},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00024500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.29688203124999996,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484939297,
#       'openInterest': 12041,
#       'percentChange': -50.0,
#       'strike': 24.5,
#       'volume': 705},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00025000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.398443515625,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484935696,
#       'openInterest': 8910,
#       'percentChange': 0.0,
#       'strike': 25.0,
#       'volume': 33},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00025500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.500005,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1485291228,
#       'openInterest': 21237,
#       'percentChange': 0.0,
#       'strike': 25.5,
#       'volume': 12},
#      {'ask': 0.02,
#       'bid': 0.01,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00026000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.6250037500000001,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1484340958,
#       'openInterest': 2542,
#       'percentChange': -33.333336,
#       'strike': 26.0,
#       'volume': 100},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00026500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.6718782812500002,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1484248624,
#       'openInterest': 594,
#       'percentChange': 0.0,
#       'strike': 26.5,
#       'volume': 574},
#      {'ask': 0.03,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00027000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.79687703125,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1484333828,
#       'openInterest': 274,
#       'percentChange': 0.0,
#       'strike': 27.0,
#       'volume': 5},
#      {'ask': 0.11,
#       'bid': 0.03,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00027500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.1640666796875,
#       'inTheMoney': False,
#       'lastPrice': 0.05,
#       'lastTradeDate': 1481950428,
#       'openInterest': 50,
#       'percentChange': 0.0,
#       'strike': 27.5,
#       'volume': 50},
#      {'ask': 0.08,
#       'bid': 0.02,
#       'change': -0.040000003,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00028000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.1796916015624999,
#       'inTheMoney': False,
#       'lastPrice': 0.05,
#       'lastTradeDate': 1481903951,
#       'openInterest': 15,
#       'percentChange': -44.444447,
#       'strike': 28.0,
#       'volume': 20},
#      {'ask': 0.06,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00029000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.2343788281249999,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484244474,
#       'openInterest': 30,
#       'percentChange': 0.0,
#       'strike': 29.0,
#       'volume': 10},
#      {'ask': 0.04,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00030000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.3125034374999998,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1481950428,
#       'openInterest': 20,
#       'percentChange': 0.0,
#       'strike': 30.0,
#       'volume': 20}],
#     'expirationDate': 1485475200,
#     'hasMiniOptions': False,
#     'puts': [{'ask': 0.05,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00015500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 2.156254609375,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1485184501,
#       'openInterest': 33,
#       'percentChange': 0.0,
#       'strike': 15.5,
#       'volume': 13},
#      {'ask': 0.04,
#       'bid': 0.0,
#       'change': -0.049999997,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00017000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.671876640625,
#       'inTheMoney': False,
#       'lastPrice': 0.03,
#       'lastTradeDate': 1482176705,
#       'openInterest': 521,
#       'percentChange': -62.5,
#       'strike': 17.0,
#       'volume': 7},
#      {'ask': 0.04,
#       'bid': 0.01,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00017500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.5937520312499998,
#       'inTheMoney': False,
#       'lastPrice': 0.06,
#       'lastTradeDate': 1481950443,
#       'openInterest': 20,
#       'percentChange': 0.0,
#       'strike': 17.5,
#       'volume': 20},
#      {'ask': 0.13,
#       'bid': 0.03,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00018000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.8046884765624998,
#       'inTheMoney': False,
#       'lastPrice': 0.06,
#       'lastTradeDate': 1483024747,
#       'openInterest': 67,
#       'percentChange': 0.0,
#       'strike': 18.0,
#       'volume': 15},
#      {'ask': 0.06,
#       'bid': 0.0,
#       'change': 0.16000001,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00018500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.359378203125,
#       'inTheMoney': False,
#       'lastPrice': 0.18,
#       'lastTradeDate': 1483972213,
#       'openInterest': 201,
#       'percentChange': 800.0001,
#       'strike': 18.5,
#       'volume': 4},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00019000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.937500625,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484320177,
#       'openInterest': 123,
#       'percentChange': -50.0,
#       'strike': 19.0,
#       'volume': 30},
#      {'ask': 0.03,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00019500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.98437515625,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1485190100,
#       'openInterest': 1300,
#       'percentChange': 0.0,
#       'strike': 19.5,
#       'volume': 1},
#      {'ask': 0.04,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00020000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.9062509375,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1485182831,
#       'openInterest': 1968,
#       'percentChange': 0.0,
#       'strike': 20.0,
#       'volume': 32},
#      {'ask': 0.02,
#       'bid': 0.01,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00020500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.7500025,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1484930919,
#       'openInterest': 2066,
#       'percentChange': 0.0,
#       'strike': 20.5,
#       'volume': 2},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00021000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.5312546875,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1485358248,
#       'openInterest': 10947,
#       'percentChange': 0.0,
#       'strike': 21.0,
#       'volume': 5},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00021500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.4687553125,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1485363744,
#       'openInterest': 5769,
#       'percentChange': 0.0,
#       'strike': 21.5,
#       'volume': 15},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00022000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.35938140625,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1485362744,
#       'openInterest': 22686,
#       'percentChange': -50.0,
#       'strike': 22.0,
#       'volume': 162},
#      {'ask': 0.02,
#       'bid': 0.01,
#       'change': -0.04,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00022500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.28516339843749994,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1485364753,
#       'openInterest': 15372,
#       'percentChange': -66.66667,
#       'strike': 22.5,
#       'volume': 4785},
#      {'ask': 0.06,
#       'bid': 0.05,
#       'change': -0.14999999,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00023000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.21875781249999998,
#       'inTheMoney': False,
#       'lastPrice': 0.06,
#       'lastTradeDate': 1485365434,
#       'openInterest': 8321,
#       'percentChange': -71.428566,
#       'strike': 23.0,
#       'volume': 17080},
#      {'ask': 0.27,
#       'bid': 0.26,
#       'change': -0.31,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00023500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.21875781249999998,
#       'inTheMoney': True,
#       'lastPrice': 0.26,
#       'lastTradeDate': 1485365493,
#       'openInterest': 1760,
#       'percentChange': -54.385967,
#       'strike': 23.5,
#       'volume': 1622},
#      {'ask': 0.67,
#       'bid': 0.66,
#       'change': -0.24000001,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00024000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.22657023437499998,
#       'inTheMoney': True,
#       'lastPrice': 0.75,
#       'lastTradeDate': 1485361911,
#       'openInterest': 943,
#       'percentChange': -24.242424,
#       'strike': 24.0,
#       'volume': 451},
#      {'ask': 1.17,
#       'bid': 1.15,
#       'change': -0.32000005,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00024500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.3437565625,
#       'inTheMoney': True,
#       'lastPrice': 1.15,
#       'lastTradeDate': 1485365514,
#       'openInterest': 861,
#       'percentChange': -21.76871,
#       'strike': 24.5,
#       'volume': 329},
#      {'ask': 1.65,
#       'bid': 1.64,
#       'change': -0.25,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00025000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.2500075,
#       'inTheMoney': True,
#       'lastPrice': 1.73,
#       'lastTradeDate': 1485363804,
#       'openInterest': 403,
#       'percentChange': -12.626262,
#       'strike': 25.0,
#       'volume': 14},
#      {'ask': 2.16,
#       'bid': 2.15,
#       'change': -0.69000006,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00025500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.500005,
#       'inTheMoney': True,
#       'lastPrice': 2.3,
#       'lastTradeDate': 1485357396,
#       'openInterest': 375,
#       'percentChange': -23.076925,
#       'strike': 25.5,
#       'volume': 5},
#      {'ask': 2.67,
#       'bid': 2.66,
#       'change': -0.25,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00026000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.6250037500000001,
#       'inTheMoney': True,
#       'lastPrice': 2.73,
#       'lastTradeDate': 1485361623,
#       'openInterest': 161,
#       'percentChange': -8.389261,
#       'strike': 26.0,
#       'volume': 49},
#      {'ask': 3.55,
#       'bid': 3.5,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00026500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.5898458007812497,
#       'inTheMoney': True,
#       'lastPrice': 3.3,
#       'lastTradeDate': 1484369513,
#       'openInterest': 17,
#       'percentChange': 0.0,
#       'strike': 26.5,
#       'volume': 113},
#      {'ask': 4.05,
#       'bid': 3.95,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00027000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.68359533203125,
#       'inTheMoney': True,
#       'lastPrice': 4.15,
#       'lastTradeDate': 1484369513,
#       'openInterest': 5,
#       'percentChange': 0.0,
#       'strike': 27.0,
#       'volume': 5},
#      {'ask': 4.55,
#       'bid': 4.45,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00027500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.8125009374999999,
#       'inTheMoney': True,
#       'lastPrice': 4.35,
#       'lastTradeDate': 1484369513,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 27.5,
#       'volume': 100},
#      {'ask': 5.45,
#       'bid': 5.25,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00028000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 2.5117224707031247,
#       'inTheMoney': True,
#       'lastPrice': 5.2,
#       'lastTradeDate': 1484836231,
#       'openInterest': 101,
#       'percentChange': 0.0,
#       'strike': 28.0,
#       'volume': 1},
#      {'ask': 5.55,
#       'bid': 5.45,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00028500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 2.058598603515625,
#       'inTheMoney': True,
#       'lastPrice': 5.35,
#       'lastTradeDate': 1484369513,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 28.5,
#       'volume': 200},
#      {'ask': 6.05,
#       'bid': 5.95,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00029000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 2.1718795703125,
#       'inTheMoney': True,
#       'lastPrice': 5.85,
#       'lastTradeDate': 1484369513,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 29.0,
#       'volume': 100}]}],
#   'quote': {'ask': 0.0,
#    'askSize': 0,
#    'averageDailyVolume10Day': 102486600,
#    'averageDailyVolume3Month': 120182019,
#    'bid': 0.0,
#    'bidSize': 0,
#    'bookValue': 24.187,
#    'currency': 'USD',
#    'dividendDate': 1483056000,
#    'earningsTimestamp': 1484332200,
#    'earningsTimestampEnd': 1492446600,
#    'earningsTimestampStart': 1492014600,
#    'epsForward': 1.62,
#    'epsTrailingTwelveMonths': 1.367,
#    'exchange': 'NYQ',
#    'exchangeTimezoneName': 'America/New_York',
#    'exchangeTimezoneShortName': 'EST',
#    'fiftyDayAverage': 22.641516,
#    'fiftyDayAverageChange': 0.70858383,
#    'fiftyDayAverageChangePercent': 0.031295776,
#    'fiftyTwoWeekHigh': 23.41,
#    'fiftyTwoWeekHighChange': -0.059900284,
#    'fiftyTwoWeekHighChangePercent': -0.0025587478,
#    'fiftyTwoWeekLow': 10.99,
#    'fiftyTwoWeekLowChange': 12.3601,
#    'fiftyTwoWeekLowChangePercent': 1.1246679,
#    'forwardPE': 14.413642,
#    'fullExchangeName': 'NYSE',
#    'gmtOffSetMilliseconds': -18000000,
#    'longName': 'Bank of America Corporation',
#    'market': 'us_market',
#    'marketCap': 234729209856,
#    'marketState': 'REGULAR',
#    'messageBoardId': 'finmb_19049',
#    'priceToBook': 0.9653987,
#    'quoteSourceName': 'NYSE Real Time Price',
#    'quoteType': 'EQUITY',
#    'regularMarketChange': 0.4000988,
#    'regularMarketChangePercent': 1.7433498,
#    'regularMarketDayHigh': 23.4,
#    'regularMarketDayLow': 23.1,
#    'regularMarketOpen': 23.32,
#    'regularMarketPreviousClose': 22.95,
#    'regularMarketPrice': 23.3501,
#    'regularMarketTime': 1485366677,
#    'regularMarketVolume': 61632429,
#    'sharesOutstanding': 10052600000,
#    'shortName': 'Bank of America Corporation Com',
#    'sourceInterval': 15,
#    'symbol': 'BAC',
#    'trailingAnnualDividendRate': 0.225,
#    'trailingPE': 17.081272,
#    'twoHundredDayAverage': 17.826424,
#    'twoHundredDayAverageChange': 5.523676,
#    'twoHundredDayAverageChangePercent': 0.3098589},
#   'strikes': [15.5,
#    16.0,
#    17.0,
#    17.5,
#    18.0,
#    18.5,
#    19.0,
#    19.5,
#    20.0,
#    20.5,
#    21.0,
#    21.5,
#    22.0,
#    22.5,
#    23.0,
#    23.5,
#    24.0,
#    24.5,
#    25.0,
#    25.5,
#    26.0,
#    26.5,
#    27.0,
#    27.5,
#    28.0,
#    28.5,
#    29.0,
#    30.0],
#   'underlyingSymbol': 'BAC'}]

# %%
result = results[0]
dates = [dt.fromtimestamp(tm) for tm in result['expirationDates']]
# we can use these dates to get data for a specific expiration date
# an example url: https://query1.finance.yahoo.com/v7/finance/options/BAC?date=1484265600 
# the first date is default
dates
# Out:
# [datetime.datetime(2017, 1, 27, 2, 0),
#  datetime.datetime(2017, 2, 3, 2, 0),
#  datetime.datetime(2017, 2, 10, 2, 0),
#  datetime.datetime(2017, 2, 17, 2, 0),
#  datetime.datetime(2017, 2, 24, 2, 0),
#  datetime.datetime(2017, 3, 3, 2, 0),
#  datetime.datetime(2017, 3, 17, 2, 0),
#  datetime.datetime(2017, 4, 21, 3, 0),
#  datetime.datetime(2017, 5, 19, 3, 0),
#  datetime.datetime(2017, 6, 16, 3, 0),
#  datetime.datetime(2017, 8, 18, 3, 0),
#  datetime.datetime(2017, 11, 17, 2, 0),
#  datetime.datetime(2017, 12, 15, 2, 0),
#  datetime.datetime(2018, 1, 19, 2, 0),
#  datetime.datetime(2019, 1, 18, 2, 0)]

# %%
option = result['options'][0]
calls = option['calls']
calls[:2]
# Out:
# [{'ask': 7.25,
#   'bid': 7.05,
#   'change': 0.39999962,
#   'contractSize': 'REGULAR',
#   'contractSymbol': 'BAC170127C00015500',
#   'currency': 'USD',
#   'expiration': 1485475200,
#   'impliedVolatility': 1.0000000000000003e-05,
#   'inTheMoney': True,
#   'lastPrice': 7.2,
#   'lastTradeDate': 1484929103,
#   'openInterest': 7,
#   'percentChange': 5.882347,
#   'strike': 15.5,
#   'volume': 8},
#  {'ask': 7.8,
#   'bid': 6.85,
#   'change': 0.5999999,
#   'contractSize': 'REGULAR',
#   'contractSymbol': 'BAC170127C00016000',
#   'currency': 'USD',
#   'expiration': 1485475200,
#   'impliedVolatility': 3.7890630273437504,
#   'inTheMoney': True,
#   'lastPrice': 7.1,
#   'lastTradeDate': 1484321104,
#   'openInterest': 4,
#   'percentChange': 9.230768,
#   'strike': 16.0,
#   'volume': 43}]

# %%
puts = option['puts']
puts[-2:]
# Out:
# [{'ask': 5.55,
#   'bid': 5.45,
#   'change': 0.0,
#   'contractSize': 'REGULAR',
#   'contractSymbol': 'BAC170127P00028500',
#   'currency': 'USD',
#   'expiration': 1485475200,
#   'impliedVolatility': 2.058598603515625,
#   'inTheMoney': True,
#   'lastPrice': 5.35,
#   'lastTradeDate': 1484369513,
#   'openInterest': 0,
#   'percentChange': 0.0,
#   'strike': 28.5,
#   'volume': 200},
#  {'ask': 6.05,
#   'bid': 5.95,
#   'change': 0.0,
#   'contractSize': 'REGULAR',
#   'contractSymbol': 'BAC170127P00029000',
#   'currency': 'USD',
#   'expiration': 1485475200,
#   'impliedVolatility': 2.1718795703125,
#   'inTheMoney': True,
#   'lastPrice': 5.85,
#   'lastTradeDate': 1484369513,
#   'openInterest': 0,
#   'percentChange': 0.0,
#   'strike': 29.0,
#   'volume': 100}]

# %% [markdown]
# # Implementation

# %%
# There is a lot of data to load every minute, so we have to do this in parrallel
# 'threading' module fits well for this purpose
# I'm going to use two queues to connect our main programm and thread workers: 
# the first is for tasks, the other - for results
# You can find some examples of using 'queue'-module here
# https://docs.python.org/3/library/queue.html#queue.Queue.join
import queue
import requests
import threading


def load_data(time):
    
    num_worker_threads = 1000
    
    def worker():
        while True:
            args = q.get()
            if args is None:
                break
            get_transactions(q, r, *args)  # <-- see definition of this function below
            q.task_done()

    q = queue.Queue() # queue with arguments for the 'get_transactions' function
    r = queue.Queue() # queue with raw responses

    threads = []
    for i in range(num_worker_threads):
        t = threading.Thread(target=worker)
        t.start()
        threads.append(t)

    for stock in STOCKS:
        q.put((stock, None))

    # block until all tasks are done
    q.join()

    # stop workers
    for i in range(num_worker_threads):
        q.put(None)

    for t in threads:
        t.join()
        
    save_rows(r, time)
    
    
def get_transactions(queue, resp_queue, stock, date=None):     
    base_url = "https://query1.finance.yahoo.com/v7/finance/options/{}".format(stock)
    if date is not None:
        url = "{}?date={}".format(base_url, date)
    else:
        url = base_url
    try:
        page = requests.get(url)
    except Exception as e:
        print(e)
    else:
        response = page.json()
        if response['optionChain']['error']: # if any error
            print(response['optionChain']['error'])

        else:
            results = response['optionChain']['result']
            for result in results:
                price = result['quote']['regularMarketPrice']
                for option in result['options']:
                    resp_queue.put(
                        (stock, price, option['calls'], option['puts'])
                    )

                if date is None:
                    for tm in result['expirationDates'][1:]:
                        queue.put((stock, tm))

# %%
# Functions which take response from the response queue and put to the 'largest_transactions' list
def save_rows(q, time):
    while True:
        try:
            stock, price, calls, puts = q.get(block=False)
        except queue.Empty:
            break
        else:
            for call in calls:
                save_row(stock, price, 'Calls', time, call)
            for put in puts:
                save_row(stock, price, 'Puts', time, put)

def save_row(s, price, t, time, raw):
    contact = raw['contractSymbol']    
    previous_volume = transaction_volumes.get(contact)
    volume = raw['volume']
    transaction_volumes[contact] = volume
    
    if previous_volume is not None:        
        volume_diff = volume - previous_volume
        if volume_diff > 0:
            last_price = raw['lastPrice']
            strike = raw['strike']
            ask = raw['ask']
            bid = raw['bid']
            largest_transactions.append(
                dict(
                    stock=s,
                    price=price,
                    type=t,
                    time=time,
                    expiration=dt.fromtimestamp(raw['expiration']),
                    strike=strike,
                    contact=contact,
                    last_price=last_price,
                    bid=bid,
                    ask=ask,
                    volume=volume,
                    open_interest=raw['openInterest'],
                    implied_volatility=raw['impliedVolatility'],
                    volume_diff=volume_diff,
                    cost=volume_diff * 100 * last_price,
                    strike_div_price=(strike / price - 1) * 100,
                    last_price_position="{:.0f}".format((1 - (ask-last_price) / (ask-bid)) * 100) if ask != bid else None
                )
            )

# %%
# This function will display the table
from IPython.display import clear_output, display, HTML

headers = (
    "Stock", "Share $", "Options", "Volume", "Open Interest", "Strike", "S / S", 
    "Expiration", "Last price", "Bid", "Ask", "Position",  "Value", "Time of trade",
)
row = """
<td>{stock}</td><td>{price}</td><td>{type}</td><td>{volume_diff}</td><td>{open_interest}</td>
<td>{strike}</td><td>{strike_div_price:.2f}%</td><td>{expiration:%b %d, %Y}</td>
<td>{last_price}</td><td>{bid}</td><td>{ask}</td><td>{last_price_position}%</td>
<td>${cost:,.0f}</td><td>{time:%I:%M%p}</td>
"""

def display_data():    
    table_rows = (row.format(**row_data) for row_data in largest_transactions)           
    clear_output()
    display(
        HTML(
            '<table><tr><th>{}</th></tr><tr>{}</tr></table>'.format(
                "</th><th>".join(headers),
                "</tr><tr>".join(table_rows)
            )
        )
    )

# %%
from datetime import datetime as dt, timedelta as td
from pytz import timezone
from time import sleep
import heapq

tz = timezone('America/Los_Angeles')  # timezone produces time with PST or PDT tzname depending on the date
STOCKS = ['AAPL', 'BAC', 'NVDA', 'AMZN', 'FB']

last_time = None
count = 1
largest_transactions = []  # here we will store top entries
transaction_volumes = {}  # latest volumes for transactions

while True:    
    now = dt.now(tz=tz)
    start = now.replace(hour=6, minute=30, second=0, microsecond=0)
    stop = start.replace(hour=13, minute=0)
    
    if start <= now <= stop: # proper time for getting data
        
        if last_time: # no more often than once per minute
            diff = 60 - (now - last_time).seconds            
            if diff > 0:
                sleep(diff)  
        
        # the main functionality
        load_data(now)
        # it's efficient way to keep only top 20 entries in the 'largest_transactions' list
        largest_transactions = heapq.nlargest(20, largest_transactions, key=lambda i: i['cost'])
        display_data()
        
        # some statistics
        print("last update", now)
        print("prev update", last_time) 
        print("update time", dt.now(tz=tz) - now)
        print("iterations", count)        
        count += 1        
        last_time = now        
    else:
        largest_transactions = [] # drop transactions
        if now < start:
            diff = start - now
            print("time to start:", diff)
            
        else:
            start_tommorow = start + td(days=1)
            print("start tommorow at", start_tommorow)
            diff = start_tommorow - now
        
        sleep(diff.seconds + diff.microseconds * 0.1 ** 6)
# Out:
# <table><tr><th>Stock</th><th>Share $</th><th>Options</th><th>Volume</th><th>Open Interest</th><th>Strike</th><th>S / S</th><th>Expiration</th><th>Last price</th><th>Bid</th><th>Ask</th><th>Position</th><th>Value</th><th>Time of trade</th></tr><tr>
# <td>FB</td><td>131.1559</td><td>Calls</td><td>330</td><td>5407</td>
# <td>122.0</td><td>-6.98%</td><td>Jan 27, 2017</td>
# <td>9.1</td><td>9.0</td><td>9.15</td><td>67%</td>
# <td>$300,300</td><td>09:51AM</td>
# </tr><tr>
# <td>AMZN</td><td>834.65</td><td>Calls</td><td>117</td><td>1697</td>
# <td>815.0</td><td>-2.35%</td><td>Jan 27, 2017</td>
# <td>21.15</td><td>20.8</td><td>21.4</td><td>58%</td>
# <td>$247,455</td><td>09:51AM</td>
# </tr><tr>
# <td>AMZN</td><td>834.65</td><td>Calls</td><td>343</td><td>433</td>
# <td>890.0</td><td>6.63%</td><td>Feb 03, 2017</td>
# <td>4.26</td><td>4.2</td><td>4.35</td><td>40%</td>
# <td>$146,118</td><td>09:51AM</td>
# </tr><tr>
# <td>AMZN</td><td>834.65</td><td>Calls</td><td>36</td><td>953</td>
# <td>800.0</td><td>-4.15%</td><td>Jan 27, 2017</td>
# <td>36.0</td><td>35.1</td><td>36.0</td><td>100%</td>
# <td>$129,600</td><td>09:51AM</td>
# </tr><tr>
# <td>FB</td><td>131.1559</td><td>Calls</td><td>215</td><td>41562</td>
# <td>130.0</td><td>-0.88%</td><td>Feb 17, 2017</td>
# <td>4.55</td><td>4.5</td><td>4.55</td><td>100%</td>
# <td>$97,825</td><td>09:51AM</td>
# </tr><tr>
# <td>NVDA</td><td>107.024</td><td>Calls</td><td>84</td><td>3299</td>
# <td>90.0</td><td>-15.91%</td><td>Mar 17, 2017</td>
# <td>11.25</td><td>11.05</td><td>11.4</td><td>57%</td>
# <td>$94,500</td><td>09:52AM</td>
# </tr><tr>
# <td>AMZN</td><td>834.65</td><td>Calls</td><td>45</td><td>2256</td>
# <td>825.0</td><td>-1.16%</td><td>Jan 27, 2017</td>
# <td>11.65</td><td>12.05</td><td>12.55</td><td>-80%</td>
# <td>$52,425</td><td>09:51AM</td>
# </tr><tr>
# <td>AMZN</td><td>834.65</td><td>Puts</td><td>25</td><td>123</td>
# <td>830.0</td><td>-0.56%</td><td>Feb 03, 2017</td>
# <td>20.3</td><td>20.15</td><td>20.3</td><td>100%</td>
# <td>$50,750</td><td>09:51AM</td>
# </tr><tr>
# <td>AAPL</td><td>121.495</td><td>Calls</td><td>64</td><td>3555</td>
# <td>116.0</td><td>-4.52%</td><td>Feb 03, 2017</td>
# <td>6.05</td><td>6.0</td><td>6.1</td><td>50%</td>
# <td>$38,720</td><td>09:51AM</td>
# </tr><tr>
# <td>AMZN</td><td>834.65</td><td>Calls</td><td>6</td><td>318</td>
# <td>830.0</td><td>-0.56%</td><td>Jun 16, 2017</td>
# <td>58.5</td><td>57.8</td><td>58.55</td><td>93%</td>
# <td>$35,100</td><td>09:51AM</td>
# </tr><tr>
# <td>FB</td><td>131.1559</td><td>Calls</td><td>10</td><td>1158</td>
# <td>115.0</td><td>-12.32%</td><td>Jan 18, 2019</td>
# <td>32.27</td><td>32.05</td><td>32.65</td><td>37%</td>
# <td>$32,270</td><td>09:51AM</td>
# </tr><tr>
# <td>AMZN</td><td>834.65</td><td>Calls</td><td>7</td><td>346</td>
# <td>825.0</td><td>-1.16%</td><td>Apr 21, 2017</td>
# <td>45.25</td><td>44.9</td><td>45.35</td><td>78%</td>
# <td>$31,675</td><td>09:51AM</td>
# </tr><tr>
# <td>AMZN</td><td>834.65</td><td>Calls</td><td>1</td><td>6</td>
# <td>450.0</td><td>-46.09%</td><td>Jun 16, 2017</td>
# <td>313.4</td><td>294.05</td><td>297.1</td><td>634%</td>
# <td>$31,340</td><td>09:52AM</td>
# </tr><tr>
# <td>AMZN</td><td>834.65</td><td>Calls</td><td>10</td><td>1767</td>
# <td>810.0</td><td>-2.95%</td><td>Jan 27, 2017</td>
# <td>26.11</td><td>25.6</td><td>26.15</td><td>93%</td>
# <td>$26,110</td><td>09:51AM</td>
# </tr><tr>
# <td>AMZN</td><td>834.65</td><td>Calls</td><td>13</td><td>1058</td>
# <td>822.5</td><td>-1.46%</td><td>Jan 27, 2017</td>
# <td>14.63</td><td>14.1</td><td>14.9</td><td>66%</td>
# <td>$19,019</td><td>09:52AM</td>
# </tr><tr>
# <td>AMZN</td><td>834.65</td><td>Puts</td><td>5</td><td>709</td>
# <td>800.0</td><td>-4.15%</td><td>Jun 16, 2017</td>
# <td>36.45</td><td>36.35</td><td>36.8</td><td>22%</td>
# <td>$18,225</td><td>09:51AM</td>
# </tr><tr>
# <td>AMZN</td><td>834.65</td><td>Calls</td><td>10</td><td>351</td>
# <td>850.0</td><td>1.84%</td><td>Feb 10, 2017</td>
# <td>18.03</td><td>17.35</td><td>17.8</td><td>151%</td>
# <td>$18,030</td><td>09:51AM</td>
# </tr><tr>
# <td>AMZN</td><td>834.65</td><td>Calls</td><td>25</td><td>1414</td>
# <td>832.5</td><td>-0.26%</td><td>Jan 27, 2017</td>
# <td>7.08</td><td>6.9</td><td>7.2</td><td>60%</td>
# <td>$17,700</td><td>09:51AM</td>
# </tr><tr>
# <td>BAC</td><td>23.3616</td><td>Calls</td><td>409</td><td>45247</td>
# <td>23.0</td><td>-1.55%</td><td>Jan 27, 2017</td>
# <td>0.41</td><td>0.4</td><td>0.42</td><td>50%</td>
# <td>$16,769</td><td>09:51AM</td>
# </tr><tr>
# <td>FB</td><td>131.1559</td><td>Puts</td><td>51</td><td>3356</td>
# <td>130.0</td><td>-0.88%</td><td>Feb 03, 2017</td>
# <td>2.96</td><td>2.95</td><td>2.98</td><td>33%</td>
# <td>$15,096</td><td>09:52AM</td>
# </tr></table>
# last update 2017-01-25 09:52:30.800287-08:00
# prev update 2017-01-25 09:51:30.780286-08:00
# update time 0:00:04.880727
# iterations 3
