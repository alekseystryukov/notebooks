# %%
from datetime import datetime as dt, timedelta as td
import requests

# %%
url = "https://query1.finance.yahoo.com/v7/finance/options/BAC"
#?formatted=true&crumb=bCkXlpLUQ.w&lang=en-US&region=US&date=1484265600&corsDomain=finance.yahoo.com

# %%
page = requests.get(url)
response = page.json()
if response['optionChain']['error']:
    print(response['optionChain']['error'])

results = response['optionChain']['result']
results
# Out:
# [{'expirationDates': [1485475200,
#    1486080000,
#    1486684800,
#    1487289600,
#    1487894400,
#    1488499200,
#    1489708800,
#    1492732800,
#    1495152000,
#    1497571200,
#    1503014400,
#    1513296000,
#    1516320000,
#    1547769600],
#   'hasMiniOptions': False,
#   'options': [{'calls': [{'ask': 7.25,
#       'bid': 7.05,
#       'change': 0.39999962,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00015500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.99609376953125,
#       'inTheMoney': True,
#       'lastPrice': 7.2,
#       'lastTradeDate': 1484929103,
#       'openInterest': 7,
#       'percentChange': 5.882347,
#       'strike': 15.5,
#       'volume': 8},
#      {'ask': 7.8,
#       'bid': 6.85,
#       'change': 0.5999999,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00016000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 3.3515641210937495,
#       'inTheMoney': True,
#       'lastPrice': 7.1,
#       'lastTradeDate': 1484321104,
#       'openInterest': 4,
#       'percentChange': 9.230768,
#       'strike': 16.0,
#       'volume': 43},
#      {'ask': 6.05,
#       'bid': 5.95,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00017000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 2.3984415039062497,
#       'inTheMoney': True,
#       'lastPrice': 6.25,
#       'lastTradeDate': 1484369490,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 17.0,
#       'volume': 39},
#      {'ask': 5.55,
#       'bid': 5.45,
#       'change': 0.4499998,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00017500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 2.2226606933593747,
#       'inTheMoney': True,
#       'lastPrice': 5.6,
#       'lastTradeDate': 1484326813,
#       'openInterest': 89,
#       'percentChange': 8.73786,
#       'strike': 17.5,
#       'volume': 82},
#      {'ask': 5.05,
#       'bid': 4.95,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00018000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 2.050786123046875,
#       'inTheMoney': True,
#       'lastPrice': 5.3,
#       'lastTradeDate': 1484369490,
#       'openInterest': 61,
#       'percentChange': 0.0,
#       'strike': 18.0,
#       'volume': 6},
#      {'ask': 4.55,
#       'bid': 4.45,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00018500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.8789068554687498,
#       'inTheMoney': True,
#       'lastPrice': 4.45,
#       'lastTradeDate': 1484369490,
#       'openInterest': 37,
#       'percentChange': 0.0,
#       'strike': 18.5,
#       'volume': 135},
#      {'ask': 4.05,
#       'bid': 3.95,
#       'change': 0.119999886,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00019000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.7109389453125,
#       'inTheMoney': True,
#       'lastPrice': 4.02,
#       'lastTradeDate': 1484339705,
#       'openInterest': 178,
#       'percentChange': 3.07692,
#       'strike': 19.0,
#       'volume': 113},
#      {'ask': 3.1,
#       'bid': 3.05,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00019500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.6953155468750001,
#       'inTheMoney': True,
#       'lastPrice': 3.15,
#       'lastTradeDate': 1485181984,
#       'openInterest': 53,
#       'percentChange': 0.0,
#       'strike': 19.5,
#       'volume': 11},
#      {'ask': 2.61,
#       'bid': 2.6,
#       'change': -0.21000004,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00020000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.6992217578125001,
#       'inTheMoney': True,
#       'lastPrice': 2.44,
#       'lastTradeDate': 1485191756,
#       'openInterest': 866,
#       'percentChange': -7.924529,
#       'strike': 20.0,
#       'volume': 144},
#      {'ask': 2.12,
#       'bid': 2.1,
#       'change': -0.08000016,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00020500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.5976602734375001,
#       'inTheMoney': True,
#       'lastPrice': 2.12,
#       'lastTradeDate': 1485196667,
#       'openInterest': 76,
#       'percentChange': -3.636371,
#       'strike': 20.5,
#       'volume': 88},
#      {'ask': 1.59,
#       'bid': 1.58,
#       'change': -0.049999952,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00021000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.4335994140625,
#       'inTheMoney': True,
#       'lastPrice': 1.57,
#       'lastTradeDate': 1485196506,
#       'openInterest': 1399,
#       'percentChange': -3.0864167,
#       'strike': 21.0,
#       'volume': 194},
#      {'ask': 1.13,
#       'bid': 1.11,
#       'change': -0.100000024,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00021500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.39453730468750003,
#       'inTheMoney': True,
#       'lastPrice': 1.12,
#       'lastTradeDate': 1485196623,
#       'openInterest': 762,
#       'percentChange': -8.196723,
#       'strike': 21.5,
#       'volume': 362},
#      {'ask': 0.66,
#       'bid': 0.65,
#       'change': -0.07000005,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00022000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.29883513671874995,
#       'inTheMoney': True,
#       'lastPrice': 0.65,
#       'lastTradeDate': 1485196764,
#       'openInterest': 6164,
#       'percentChange': -9.722229,
#       'strike': 22.0,
#       'volume': 2352},
#      {'ask': 0.29,
#       'bid': 0.28,
#       'change': -0.06999999,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00022500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.25196060546875,
#       'inTheMoney': True,
#       'lastPrice': 0.28,
#       'lastTradeDate': 1485196719,
#       'openInterest': 21673,
#       'percentChange': -19.999998,
#       'strike': 22.5,
#       'volume': 5945},
#      {'ask': 0.09,
#       'bid': 0.08,
#       'change': -0.03999999,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00023000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.23828886718749998,
#       'inTheMoney': False,
#       'lastPrice': 0.09,
#       'lastTradeDate': 1485196662,
#       'openInterest': 19760,
#       'percentChange': -30.769226,
#       'strike': 23.0,
#       'volume': 14278},
#      {'ask': 0.02,
#       'bid': 0.01,
#       'change': -0.02,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00023500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.23828886718749998,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1485195937,
#       'openInterest': 10280,
#       'percentChange': -50.0,
#       'strike': 23.5,
#       'volume': 23126},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00024000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.2890696093749999,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1485187881,
#       'openInterest': 14386,
#       'percentChange': 0.0,
#       'strike': 24.0,
#       'volume': 180},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00024500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.35938140625,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484939297,
#       'openInterest': 12041,
#       'percentChange': -50.0,
#       'strike': 24.5,
#       'volume': 705},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00025000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.437505625,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484935696,
#       'openInterest': 8910,
#       'percentChange': 0.0,
#       'strike': 25.0,
#       'volume': 33},
#      {'ask': 0.05,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00025500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.5937540625000001,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484762527,
#       'openInterest': 21251,
#       'percentChange': 0.0,
#       'strike': 25.5,
#       'volume': 10},
#      {'ask': 0.02,
#       'bid': 0.01,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00026000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.6093789062500001,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1484340958,
#       'openInterest': 2542,
#       'percentChange': -33.333336,
#       'strike': 26.0,
#       'volume': 100},
#      {'ask': 0.02,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00026500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.64062859375,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1484248624,
#       'openInterest': 594,
#       'percentChange': 0.0,
#       'strike': 26.5,
#       'volume': 574},
#      {'ask': 0.03,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00027000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.7500025,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1484333828,
#       'openInterest': 274,
#       'percentChange': 0.0,
#       'strike': 27.0,
#       'volume': 5},
#      {'ask': 0.11,
#       'bid': 0.03,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00027500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.0546922265625,
#       'inTheMoney': False,
#       'lastPrice': 0.05,
#       'lastTradeDate': 1481950428,
#       'openInterest': 50,
#       'percentChange': 0.0,
#       'strike': 27.5,
#       'volume': 50},
#      {'ask': 0.08,
#       'bid': 0.02,
#       'change': -0.040000003,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00028000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.0546922265625,
#       'inTheMoney': False,
#       'lastPrice': 0.05,
#       'lastTradeDate': 1481903951,
#       'openInterest': 15,
#       'percentChange': -44.444447,
#       'strike': 28.0,
#       'volume': 20},
#      {'ask': 0.06,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00029000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.09375453125,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484244474,
#       'openInterest': 30,
#       'percentChange': 0.0,
#       'strike': 29.0,
#       'volume': 10},
#      {'ask': 0.04,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127C00030000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.140629296875,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1481950428,
#       'openInterest': 20,
#       'percentChange': 0.0,
#       'strike': 30.0,
#       'volume': 20}],
#     'expirationDate': 1485475200,
#     'hasMiniOptions': False,
#     'puts': [{'ask': 0.03,
#       'bid': 0.0,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00015500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.4375028125,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1485184501,
#       'openInterest': 20,
#       'percentChange': 0.0,
#       'strike': 15.5,
#       'volume': 13},
#      {'ask': 0.04,
#       'bid': 0.0,
#       'change': -0.049999997,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00017000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.171879140625,
#       'inTheMoney': False,
#       'lastPrice': 0.03,
#       'lastTradeDate': 1482176705,
#       'openInterest': 521,
#       'percentChange': -62.5,
#       'strike': 17.0,
#       'volume': 7},
#      {'ask': 0.04,
#       'bid': 0.01,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00017500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.109379453125,
#       'inTheMoney': False,
#       'lastPrice': 0.06,
#       'lastTradeDate': 1481950443,
#       'openInterest': 20,
#       'percentChange': 0.0,
#       'strike': 17.5,
#       'volume': 20},
#      {'ask': 0.13,
#       'bid': 0.03,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00018000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.2578162109375,
#       'inTheMoney': False,
#       'lastPrice': 0.06,
#       'lastTradeDate': 1483024747,
#       'openInterest': 67,
#       'percentChange': 0.0,
#       'strike': 18.0,
#       'volume': 15},
#      {'ask': 0.06,
#       'bid': 0.0,
#       'change': 0.16000001,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00018500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.929688203125,
#       'inTheMoney': False,
#       'lastPrice': 0.18,
#       'lastTradeDate': 1483972213,
#       'openInterest': 201,
#       'percentChange': 800.0001,
#       'strike': 18.5,
#       'volume': 4},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00019000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.6250037500000001,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1484320177,
#       'openInterest': 123,
#       'percentChange': -50.0,
#       'strike': 19.0,
#       'volume': 30},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00019500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.5312546875,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1485190100,
#       'openInterest': 1300,
#       'percentChange': -50.0,
#       'strike': 19.5,
#       'volume': 1},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.01,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00020000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.500005,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1485182831,
#       'openInterest': 1999,
#       'percentChange': -50.0,
#       'strike': 20.0,
#       'volume': 32},
#      {'ask': 0.02,
#       'bid': 0.01,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00020500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.4687553125,
#       'inTheMoney': False,
#       'lastPrice': 0.02,
#       'lastTradeDate': 1484930919,
#       'openInterest': 2066,
#       'percentChange': 0.0,
#       'strike': 20.5,
#       'volume': 2},
#      {'ask': 0.01,
#       'bid': 0.0,
#       'change': -0.02,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00021000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.32813171874999997,
#       'inTheMoney': False,
#       'lastPrice': 0.01,
#       'lastTradeDate': 1485184406,
#       'openInterest': 11012,
#       'percentChange': -66.66667,
#       'strike': 21.0,
#       'volume': 2},
#      {'ask': 0.03,
#       'bid': 0.02,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00021500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.29688203124999996,
#       'inTheMoney': False,
#       'lastPrice': 0.03,
#       'lastTradeDate': 1485190461,
#       'openInterest': 5768,
#       'percentChange': 0.0,
#       'strike': 21.5,
#       'volume': 263},
#      {'ask': 0.07,
#       'bid': 0.06,
#       'change': -0.030000005,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00022000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.2461012890625,
#       'inTheMoney': False,
#       'lastPrice': 0.06,
#       'lastTradeDate': 1485196644,
#       'openInterest': 18644,
#       'percentChange': -33.333336,
#       'strike': 22.0,
#       'volume': 2181},
#      {'ask': 0.21,
#       'bid': 0.19,
#       'change': -0.019999996,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00022500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.22266402343749997,
#       'inTheMoney': False,
#       'lastPrice': 0.19,
#       'lastTradeDate': 1485196800,
#       'openInterest': 9755,
#       'percentChange': -9.523808,
#       'strike': 22.5,
#       'volume': 7598},
#      {'ask': 0.5,
#       'bid': 0.49,
#       'change': 0.01999998,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00023000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.187508125,
#       'inTheMoney': True,
#       'lastPrice': 0.53,
#       'lastTradeDate': 1485195860,
#       'openInterest': 3519,
#       'percentChange': 3.921565,
#       'strike': 23.0,
#       'volume': 2276},
#      {'ask': 0.93,
#       'bid': 0.91,
#       'change': 0.100000024,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00023500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 1.0,
#       'lastTradeDate': 1485193552,
#       'openInterest': 1987,
#       'percentChange': 11.1111145,
#       'strike': 23.5,
#       'volume': 904},
#      {'ask': 1.42,
#       'bid': 1.4,
#       'change': 0.14999998,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00024000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 1.55,
#       'lastTradeDate': 1485192010,
#       'openInterest': 916,
#       'percentChange': 10.714284,
#       'strike': 24.0,
#       'volume': 131},
#      {'ask': 1.9,
#       'bid': 1.86,
#       'change': -0.16999996,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00024500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 1.85,
#       'lastTradeDate': 1484943515,
#       'openInterest': 799,
#       'percentChange': -8.41584,
#       'strike': 24.5,
#       'volume': 428},
#      {'ask': 2.41,
#       'bid': 2.4,
#       'change': 0.099999905,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00025000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 2.56,
#       'lastTradeDate': 1485192157,
#       'openInterest': 409,
#       'percentChange': 4.065037,
#       'strike': 25.0,
#       'volume': 145},
#      {'ask': 2.91,
#       'bid': 2.9,
#       'change': 0.26,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00025500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 2.99,
#       'lastTradeDate': 1485190805,
#       'openInterest': 375,
#       'percentChange': 9.523809,
#       'strike': 25.5,
#       'volume': 11},
#      {'ask': 3.4,
#       'bid': 3.35,
#       'change': 0.24000001,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00026000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 3.15,
#       'lastTradeDate': 1484931404,
#       'openInterest': 326,
#       'percentChange': 8.247422,
#       'strike': 26.0,
#       'volume': 91},
#      {'ask': 3.55,
#       'bid': 3.5,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00026500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 3.3,
#       'lastTradeDate': 1484369513,
#       'openInterest': 17,
#       'percentChange': 0.0,
#       'strike': 26.5,
#       'volume': 113},
#      {'ask': 4.05,
#       'bid': 3.95,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00027000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 4.15,
#       'lastTradeDate': 1484369513,
#       'openInterest': 5,
#       'percentChange': 0.0,
#       'strike': 27.0,
#       'volume': 5},
#      {'ask': 4.55,
#       'bid': 4.45,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00027500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 4.35,
#       'lastTradeDate': 1484369513,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 27.5,
#       'volume': 100},
#      {'ask': 5.45,
#       'bid': 5.25,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00028000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 0.500005,
#       'inTheMoney': True,
#       'lastPrice': 5.2,
#       'lastTradeDate': 1484836231,
#       'openInterest': 101,
#       'percentChange': 0.0,
#       'strike': 28.0,
#       'volume': 1},
#      {'ask': 5.55,
#       'bid': 5.45,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00028500',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 5.35,
#       'lastTradeDate': 1484369513,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 28.5,
#       'volume': 200},
#      {'ask': 6.05,
#       'bid': 5.95,
#       'change': 0.0,
#       'contractSize': 'REGULAR',
#       'contractSymbol': 'BAC170127P00029000',
#       'currency': 'USD',
#       'expiration': 1485475200,
#       'impliedVolatility': 1.0000000000000003e-05,
#       'inTheMoney': True,
#       'lastPrice': 5.85,
#       'lastTradeDate': 1484369513,
#       'openInterest': 0,
#       'percentChange': 0.0,
#       'strike': 29.0,
#       'volume': 100}]}],
#   'quote': {'ask': 0.0,
#    'askSize': 0,
#    'averageDailyVolume10Day': 122838920,
#    'averageDailyVolume3Month': 120604493,
#    'bid': 0.0,
#    'bidSize': 0,
#    'bookValue': 24.187,
#    'currency': 'USD',
#    'dividendDate': 1483056000,
#    'earningsTimestamp': 1484332200,
#    'earningsTimestampEnd': 1492446600,
#    'earningsTimestampStart': 1492014600,
#    'epsForward': 1.62,
#    'epsTrailingTwelveMonths': 1.367,
#    'exchange': 'NYQ',
#    'exchangeTimezoneName': 'America/New_York',
#    'exchangeTimezoneShortName': 'EST',
#    'fiftyDayAverage': 22.609375,
#    'fiftyDayAverageChange': -0.059375763,
#    'fiftyDayAverageChangePercent': -0.0026261567,
#    'fiftyTwoWeekHigh': 23.41,
#    'fiftyTwoWeekHighChange': -0.8600006,
#    'fiftyTwoWeekHighChangePercent': -0.036736462,
#    'fiftyTwoWeekLow': 10.99,
#    'fiftyTwoWeekLowChange': 11.559999,
#    'fiftyTwoWeekLowChangePercent': 1.0518653,
#    'forwardPE': 13.919752,
#    'fullExchangeName': 'NYSE',
#    'gmtOffSetMilliseconds': -18000000,
#    'longName': 'Bank of America Corporation',
#    'market': 'us_market',
#    'marketCap': 226686124032,
#    'marketState': 'REGULAR',
#    'messageBoardId': 'finmb_19049',
#    'priceToBook': 0.932319,
#    'quoteSourceName': 'NYSE Real Time Price',
#    'quoteType': 'EQUITY',
#    'regularMarketChange': -0.09000015,
#    'regularMarketChangePercent': -0.39752716,
#    'regularMarketDayHigh': 22.76,
#    'regularMarketDayLow': 22.415,
#    'regularMarketOpen': 22.62,
#    'regularMarketPreviousClose': 22.64,
#    'regularMarketPrice': 22.55,
#    'regularMarketTime': 1485197914,
#    'regularMarketVolume': 44104704,
#    'sharesOutstanding': 10052600000,
#    'shortName': 'Bank of America Corporation Com',
#    'sourceInterval': 15,
#    'symbol': 'BAC',
#    'trailingAnnualDividendRate': 0.225,
#    'trailingPE': 16.495975,
#    'twoHundredDayAverage': 17.685328,
#    'twoHundredDayAverageChange': 4.8646717,
#    'twoHundredDayAverageChangePercent': 0.27506822},
#   'strikes': [15.5,
#    16.0,
#    17.0,
#    17.5,
#    18.0,
#    18.5,
#    19.0,
#    19.5,
#    20.0,
#    20.5,
#    21.0,
#    21.5,
#    22.0,
#    22.5,
#    23.0,
#    23.5,
#    24.0,
#    24.5,
#    25.0,
#    25.5,
#    26.0,
#    26.5,
#    27.0,
#    27.5,
#    28.0,
#    28.5,
#    29.0,
#    30.0],
#   'underlyingSymbol': 'BAC'}]

# %%
result = results[0]
dates = [dt.fromtimestamp(tm) for tm in result['expirationDates']]
# we can use these dates to get data for a specific expiration date
# an example url: https://query1.finance.yahoo.com/v7/finance/options/BAC?date=1484265600 
# the first date is default
dates
# Out:
# [datetime.datetime(2017, 1, 27, 2, 0),
#  datetime.datetime(2017, 2, 3, 2, 0),
#  datetime.datetime(2017, 2, 10, 2, 0),
#  datetime.datetime(2017, 2, 17, 2, 0),
#  datetime.datetime(2017, 2, 24, 2, 0),
#  datetime.datetime(2017, 3, 3, 2, 0),
#  datetime.datetime(2017, 3, 17, 2, 0),
#  datetime.datetime(2017, 4, 21, 3, 0),
#  datetime.datetime(2017, 5, 19, 3, 0),
#  datetime.datetime(2017, 6, 16, 3, 0),
#  datetime.datetime(2017, 8, 18, 3, 0),
#  datetime.datetime(2017, 12, 15, 2, 0),
#  datetime.datetime(2018, 1, 19, 2, 0),
#  datetime.datetime(2019, 1, 18, 2, 0)]

# %%
option = result['options'][0]
calls = option['calls']
calls[:2]
# Out:
# [{'ask': 7.25,
#   'bid': 7.05,
#   'change': 0.39999962,
#   'contractSize': 'REGULAR',
#   'contractSymbol': 'BAC170127C00015500',
#   'currency': 'USD',
#   'expiration': 1485475200,
#   'impliedVolatility': 1.99609376953125,
#   'inTheMoney': True,
#   'lastPrice': 7.2,
#   'lastTradeDate': 1484929103,
#   'openInterest': 7,
#   'percentChange': 5.882347,
#   'strike': 15.5,
#   'volume': 8},
#  {'ask': 7.8,
#   'bid': 6.85,
#   'change': 0.5999999,
#   'contractSize': 'REGULAR',
#   'contractSymbol': 'BAC170127C00016000',
#   'currency': 'USD',
#   'expiration': 1485475200,
#   'impliedVolatility': 3.3515641210937495,
#   'inTheMoney': True,
#   'lastPrice': 7.1,
#   'lastTradeDate': 1484321104,
#   'openInterest': 4,
#   'percentChange': 9.230768,
#   'strike': 16.0,
#   'volume': 43}]

# %%
puts = option['puts']
puts[-2:]
# Out:
# [{'ask': 5.55,
#   'bid': 5.45,
#   'change': 0.0,
#   'contractSize': 'REGULAR',
#   'contractSymbol': 'BAC170127P00028500',
#   'currency': 'USD',
#   'expiration': 1485475200,
#   'impliedVolatility': 1.0000000000000003e-05,
#   'inTheMoney': True,
#   'lastPrice': 5.35,
#   'lastTradeDate': 1484369513,
#   'openInterest': 0,
#   'percentChange': 0.0,
#   'strike': 28.5,
#   'volume': 200},
#  {'ask': 6.05,
#   'bid': 5.95,
#   'change': 0.0,
#   'contractSize': 'REGULAR',
#   'contractSymbol': 'BAC170127P00029000',
#   'currency': 'USD',
#   'expiration': 1485475200,
#   'impliedVolatility': 1.0000000000000003e-05,
#   'inTheMoney': True,
#   'lastPrice': 5.85,
#   'lastTradeDate': 1484369513,
#   'openInterest': 0,
#   'percentChange': 0.0,
#   'strike': 29.0,
#   'volume': 100}]

# %% [markdown]
# # Implementation

# %%
# There is a lot of data to load every minute, so we have to do this in parrallel
# 'threading' module fits well for this purpose
# I'm going to use two queues to connect our main programm and thread workers: 
# the first is for tasks, the other - for results
# You can find some examples of using 'queue'-module here
# https://docs.python.org/3/library/queue.html#queue.Queue.join
import queue
import requests
import threading


def load_data(time):
    
    num_worker_threads = 1000
    
    def worker():
        while True:
            args = q.get()
            if args is None:
                break
            get_transactions(q, r, *args)  # <-- see definition of this function below
            q.task_done()

    q = queue.Queue() # queue with arguments for the 'get_transactions' function
    r = queue.Queue() # queue with raw responses

    threads = []
    for i in range(num_worker_threads):
        t = threading.Thread(target=worker)
        t.start()
        threads.append(t)

    for stock in STOCKS:
        q.put((stock, None))

    # block until all tasks are done
    q.join()

    # stop workers
    for i in range(num_worker_threads):
        q.put(None)

    for t in threads:
        t.join()
        
    save_rows(r, time)
    
    
def get_transactions(queue, resp_queue, stock, date=None):     
    base_url = "https://query1.finance.yahoo.com/v7/finance/options/{}".format(stock)
    if date is not None:
        url = "{}?date={}".format(base_url, date)
    else:
        url = base_url
    try:
        page = requests.get(url)
    except Exception as e:
        print(e)
    else:
        response = page.json()
        if response['optionChain']['error']: # if any error
            print(response['optionChain']['error'])

        else:
            results = response['optionChain']['result']
            for result in results:
                price = result['quote']['regularMarketPrice']
                for option in result['options']:
                    resp_queue.put(
                        (stock, price, option['calls'], option['puts'])
                    )

                if date is None:
                    for tm in result['expirationDates'][1:]:
                        queue.put((stock, tm))

# %%
# Functions which take response from the response queue and put to the 'largest_transactions' list
def save_rows(q, time):
    while True:
        try:
            stock, price, calls, puts = q.get(block=False)
        except queue.Empty:
            break
        else:
            for call in calls:
                save_row(stock, price, 'Calls', time, call)
            for put in puts:
                save_row(stock, price, 'Puts', time, put)

def save_row(s, price, t, time, raw):
    contact = raw['contractSymbol']    
    previous_volume = transaction_volumes.get(contact)
    volume = raw['volume']
    transaction_volumes[contact] = volume
    
    if previous_volume is not None:        
        volume_diff = volume - previous_volume
        if volume_diff > 0:
            last_price = raw['lastPrice']
            strike = raw['strike']
            ask = raw['ask']
            bid = raw['bid']
            largest_transactions.append(
                dict(
                    stock=s,
                    price=price,
                    type=t,
                    time=time,
                    expiration=dt.fromtimestamp(raw['expiration']),
                    strike=strike,
                    contact=contact,
                    last_price=last_price,
                    bid=bid,
                    ask=ask,
                    volume=volume,
                    open_interest=raw['openInterest'],
                    implied_volatility=raw['impliedVolatility'],
                    volume_diff=volume_diff,
                    cost=volume_diff * 100 * last_price,
                    strike_div_price=(strike / price - 1) * 100,
                    last_price_position="{:.0f}".format((1 - (ask-last_price) / (ask-bid)) * 100) if ask != bid else None
                )
            )

# %%
# This function will display the table
from IPython.display import clear_output, display, HTML

headers = (
    "Stock", "Share price", "Options", "Volume", "Strike", "Strike /Share price", 
    "Expiration", "Last price", "Bid", "Ask", "Last price position",  "Value", "Time of trade",
)
row = """
<td>{stock}</td><td>{price}</td><td>{type}</td><td>{volume_diff}</td>
<td>{strike}</td><td>{strike_div_price:.2f}%</td><td>{expiration:%b %d, %Y}</td>
<td>{last_price}</td><td>{bid}</td><td>{ask}</td><td>{last_price_position}%</td>
<td>${cost:,.0f}</td><td>{time:%I:%M%p}</td>
"""

def display_data():    
    table_rows = (row.format(**row_data) for row_data in largest_transactions)           
    clear_output()
    display(
        HTML(
            '<table><tr><th>{}</th></tr><tr>{}</tr></table>'.format(
                "</th><th>".join(headers),
                "</tr><tr>".join(table_rows)
            )
        )
    )

# %%
from datetime import datetime as dt, timedelta as td
from pytz import timezone
from time import sleep
import heapq

tz = timezone('America/Los_Angeles')  # timezone produces time with PST or PDT tzname depending on the date
STOCKS = ['AAPL', 'BAC', 'NVDA', 'AMZN', 'FB']

last_time = None
count = 1
largest_transactions = []  # here we will store top entries
transaction_volumes = {}  # latest volumes for transactions

while True:    
    now = dt.now(tz=tz)
    start = now.replace(hour=6, minute=30, second=0, microsecond=0)
    stop = start.replace(hour=13, minute=0)
    
    if start <= now <= stop: # proper time for getting data
        
        if last_time: # no more often than once per minute
            diff = 60 - (now - last_time).seconds            
            if diff > 0:
                sleep(diff)  
        
        # the main functionality
        load_data(now)
        # it's efficient way to keep only top 20 entries in the 'largest_transactions' list
        largest_transactions = heapq.nlargest(20, largest_transactions, key=lambda i: i['cost'])
        display_data()
        
        # some statistics
        print("last update", now)
        print("prev update", last_time) 
        print("update time", dt.now(tz=tz) - now)
        print("iterations", count)        
        count += 1        
        last_time = now        
    else:
        largest_transactions = [] # drop transactions
        if now < start:
            diff = start - now
            print("time to start:", diff)
            
        else:
            start_tommorow = start + td(days=1)
            print("start tommorow at", start_tommorow)
            diff = start_tommorow - now
        
        sleep(diff.seconds + diff.microseconds * 0.1 ** 6)
# Out:
# <table><tr><th>Stock</th><th>Share price</th><th>Options</th><th>Volume</th><th>Strike</th><th>Strike /Share price</th><th>Expiration</th><th>Last price</th><th>Bid</th><th>Ask</th><th>Last price position</th><th>Value</th><th>Time of trade</th></tr><tr>
# <td>AMZN</td><td>813.9019</td><td>Calls</td><td>42</td>
# <td>830.0</td><td>1.98%</td><td>Feb 17, 2017</td>
# <td>19.65</td><td>19.45</td><td>19.75</td><td>67%</td>
# <td>$82,530</td><td>10:58AM</td>
# </tr><tr>
# <td>AMZN</td><td>813.9019</td><td>Puts</td><td>143</td>
# <td>740.0</td><td>-9.08%</td><td>Feb 17, 2017</td>
# <td>4.5</td><td>4.5</td><td>4.7</td><td>0%</td>
# <td>$64,350</td><td>10:58AM</td>
# </tr><tr>
# <td>AMZN</td><td>813.9019</td><td>Calls</td><td>1</td>
# <td>450.0</td><td>-44.71%</td><td>Jun 16, 2017</td>
# <td>313.4</td><td>294.05</td><td>297.1</td><td>634%</td>
# <td>$31,340</td><td>10:59AM</td>
# </tr><tr>
# <td>AAPL</td><td>120.07</td><td>Puts</td><td>393</td>
# <td>120.0</td><td>-0.06%</td><td>Jan 27, 2017</td>
# <td>0.74</td><td>0.73</td><td>0.74</td><td>100%</td>
# <td>$29,082</td><td>10:58AM</td>
# </tr><tr>
# <td>AMZN</td><td>813.9019</td><td>Calls</td><td>28</td>
# <td>810.0</td><td>-0.48%</td><td>Jan 27, 2017</td>
# <td>9.13</td><td>9.3</td><td>9.55</td><td>-68%</td>
# <td>$25,564</td><td>10:58AM</td>
# </tr><tr>
# <td>AMZN</td><td>813.9019</td><td>Calls</td><td>54</td>
# <td>820.0</td><td>0.75%</td><td>Jan 27, 2017</td>
# <td>4.6</td><td>4.5</td><td>4.75</td><td>40%</td>
# <td>$24,840</td><td>10:58AM</td>
# </tr><tr>
# <td>AMZN</td><td>813.9019</td><td>Calls</td><td>5</td>
# <td>780.0</td><td>-4.17%</td><td>Jan 27, 2017</td>
# <td>34.7</td><td>33.55</td><td>34.65</td><td>105%</td>
# <td>$17,350</td><td>10:58AM</td>
# </tr><tr>
# <td>AMZN</td><td>813.9019</td><td>Puts</td><td>7</td>
# <td>812.5</td><td>-0.17%</td><td>Feb 03, 2017</td>
# <td>23.52</td><td>23.25</td><td>23.55</td><td>90%</td>
# <td>$16,464</td><td>10:58AM</td>
# </tr><tr>
# <td>AMZN</td><td>813.9019</td><td>Calls</td><td>19</td>
# <td>812.5</td><td>-0.17%</td><td>Jan 27, 2017</td>
# <td>7.94</td><td>7.85</td><td>8.05</td><td>45%</td>
# <td>$15,086</td><td>10:58AM</td>
# </tr><tr>
# <td>AMZN</td><td>813.9019</td><td>Puts</td><td>55</td>
# <td>800.0</td><td>-1.71%</td><td>Jan 27, 2017</td>
# <td>2.34</td><td>2.25</td><td>2.39</td><td>64%</td>
# <td>$12,870</td><td>10:58AM</td>
# </tr><tr>
# <td>AMZN</td><td>813.9019</td><td>Calls</td><td>2</td>
# <td>910.0</td><td>11.81%</td><td>Jan 19, 2018</td>
# <td>57.9</td><td>57.1</td><td>58.0</td><td>89%</td>
# <td>$11,580</td><td>10:58AM</td>
# </tr><tr>
# <td>AMZN</td><td>813.9019</td><td>Puts</td><td>15</td>
# <td>812.5</td><td>-0.17%</td><td>Jan 27, 2017</td>
# <td>6.52</td><td>6.4</td><td>6.65</td><td>48%</td>
# <td>$9,780</td><td>10:58AM</td>
# </tr><tr>
# <td>FB</td><td>128.6965</td><td>Puts</td><td>11</td>
# <td>130.0</td><td>1.01%</td><td>Jun 16, 2017</td>
# <td>8.3</td><td>8.2</td><td>8.3</td><td>100%</td>
# <td>$9,130</td><td>10:58AM</td>
# </tr><tr>
# <td>NVDA</td><td>105.27</td><td>Calls</td><td>49</td>
# <td>105.0</td><td>-0.26%</td><td>Jan 27, 2017</td>
# <td>1.79</td><td>1.7</td><td>1.8</td><td>90%</td>
# <td>$8,771</td><td>10:58AM</td>
# </tr><tr>
# <td>AMZN</td><td>813.9019</td><td>Puts</td><td>1</td>
# <td>810.0</td><td>-0.48%</td><td>Jan 19, 2018</td>
# <td>86.4</td><td>85.85</td><td>86.75</td><td>61%</td>
# <td>$8,640</td><td>10:58AM</td>
# </tr><tr>
# <td>AAPL</td><td>120.07</td><td>Puts</td><td>59</td>
# <td>121.0</td><td>0.77%</td><td>Jan 27, 2017</td>
# <td>1.26</td><td>1.27</td><td>1.29</td><td>-50%</td>
# <td>$7,434</td><td>10:58AM</td>
# </tr><tr>
# <td>FB</td><td>128.6965</td><td>Calls</td><td>10</td>
# <td>150.0</td><td>16.55%</td><td>Jan 19, 2018</td>
# <td>6.55</td><td>6.45</td><td>6.55</td><td>100%</td>
# <td>$6,550</td><td>10:58AM</td>
# </tr><tr>
# <td>AMZN</td><td>813.9019</td><td>Puts</td><td>10</td>
# <td>750.0</td><td>-7.85%</td><td>Feb 17, 2017</td>
# <td>6.09</td><td>6.0</td><td>6.2</td><td>45%</td>
# <td>$6,090</td><td>10:58AM</td>
# </tr><tr>
# <td>FB</td><td>128.7</td><td>Calls</td><td>3</td>
# <td>110.0</td><td>-14.53%</td><td>Mar 17, 2017</td>
# <td>19.4</td><td>19.35</td><td>19.45</td><td>50%</td>
# <td>$5,820</td><td>10:59AM</td>
# </tr><tr>
# <td>FB</td><td>128.6965</td><td>Calls</td><td>78</td>
# <td>130.0</td><td>1.01%</td><td>Jan 27, 2017</td>
# <td>0.63</td><td>0.62</td><td>0.63</td><td>100%</td>
# <td>$4,914</td><td>10:58AM</td>
# </tr></table>
# last update 2017-01-23 10:59:52.002576-08:00
# prev update 2017-01-23 10:58:44.049948-08:00
# update time 0:00:08.116877
# iterations 3
